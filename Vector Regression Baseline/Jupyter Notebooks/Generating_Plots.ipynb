# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing the Data Files

# %% [markdown]
# 1. Testing Data

# %%
#importing samples

#679
df_679 = pd.read_csv('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/without_concat k-fold cv kernel map centering resting fmri/679/results_9.csv')
df_679.head()
mean_df_679 = df_679[['NMSE','CORR','R2','Time_Taken']].mean()
var_df_679 = df_679[['NMSE','CORR','R2','Time_Taken']].var() 

#550
df_550 = pd.read_csv('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/without_concat k-fold cv kernel map centering resting fmri/550/results_9.csv')
df_550.head()
mean_df_550 = df_550[['NMSE','CORR','R2','Time_Taken']].mean()
var_df_550 = df_550[['NMSE','CORR','R2','Time_Taken']].var() 


#450
df_450 = pd.read_csv('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/without_concat k-fold cv kernel map centering resting fmri/450/results_9.csv')
df_450.head()
mean_df_450 = df_450[['NMSE','CORR','R2','Time_Taken']].mean()
var_df_450 = df_450[['NMSE','CORR','R2','Time_Taken']].var() 

#350
df_350 = pd.read_csv('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/without_concat k-fold cv kernel map centering resting fmri/350/results_9.csv')
df_350.head()
mean_df_350 = df_350[['NMSE','CORR','R2','Time_Taken']].mean()
var_df_350 = df_350[['NMSE','CORR','R2','Time_Taken']].var() 

#250
df_250 = pd.read_csv('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/without_concat k-fold cv kernel map centering resting fmri/250/results_9.csv')
df_250.head()
mean_df_250 = df_250[['NMSE','CORR','R2','Time_Taken']].mean()
var_df_250 = df_250[['NMSE','CORR','R2','Time_Taken']].var() 

print(mean_df_250)
print(mean_df_350)
print(mean_df_450)
print(mean_df_550)
print(mean_df_679)
# Out:
# NMSE          0.639958
# CORR          0.435686
# R2            0.161498
# Time_Taken    0.723538
# dtype: float64
# NMSE          0.632665
# CORR          0.446142
# R2            0.174263
# Time_Taken    0.677026
# dtype: float64
# NMSE          0.611781
# CORR          0.474474
# R2            0.200627
# Time_Taken    0.952246
# dtype: float64
# NMSE          0.602536
# CORR          0.487957
# R2            0.215050
# Time_Taken    1.295728
# dtype: float64
# NMSE          0.576490
# CORR          0.513305
# R2            0.250355
# Time_Taken    1.643178
# dtype: float64

# %% [markdown]
# 2. Training

# %%
#importing samples

#679
Train_mean_df_679 = df_679[['Train_NMSE','Train_CORR','Train_R2']].mean()
Train_var_df_679 = df_679[['Train_NMSE','Train_CORR','Train_R2']].var() 

#550
Train_mean_df_550 = df_550[['Train_NMSE','Train_CORR','Train_R2']].mean()
Train_var_df_550 = df_550[['Train_NMSE','Train_CORR','Train_R2']].var() 


#450
Train_mean_df_450 = df_450[['Train_NMSE','Train_CORR','Train_R2']].mean()
Train_var_df_450 = df_450[['Train_NMSE','Train_CORR','Train_R2']].var() 

#350
Train_mean_df_350 = df_350[['Train_NMSE','Train_CORR','Train_R2']].mean()
Train_var_df_350 = df_350[['Train_NMSE','Train_CORR','Train_R2']].var() 

#250
Train_mean_df_250 = df_250[['Train_NMSE','Train_CORR','Train_R2']].mean()
Train_var_df_250 = df_250[['Train_NMSE','Train_CORR','Train_R2']].var() 

print(Train_mean_df_250)
print(Train_mean_df_350)
print(Train_mean_df_450)
print(Train_mean_df_550)
print(Train_mean_df_679)
# Out:
# Train_NMSE    0.116731
# Train_CORR    0.972959
# Train_R2      0.883269
# dtype: float64
# Train_NMSE    0.060005
# Train_CORR    0.985749
# Train_R2      0.939995
# dtype: float64
# Train_NMSE    0.092256
# Train_CORR    0.975028
# Train_R2      0.907744
# dtype: float64
# Train_NMSE    0.119927
# Train_CORR    0.963987
# Train_R2      0.880073
# dtype: float64
# Train_NMSE    0.098401
# Train_CORR    0.969820
# Train_R2      0.901599
# dtype: float64

# %% [markdown]
# ### Plotting Data

# %% [markdown]
# 1. Testing Data

# %%
# Prepare data for plotting
metrics = ['NMSE', 'CORR', 'R2']
sample_labels = ['250', '350', '450', '550', '679']

# Assuming mean_df_350, mean_df_450, mean_df_550, var_df_350, var_df_450, var_df_550 are defined similarly to mean_df_250 and mean_df_679
mean_values = pd.DataFrame([mean_df_250, mean_df_350, mean_df_450, mean_df_550, mean_df_679], index=sample_labels)
var_values = pd.DataFrame([var_df_250, var_df_350, var_df_450, var_df_550, var_df_679], index=sample_labels)

import matplotlib.pyplot as plt

# Plotting
fig, axes = plt.subplots(1, 3, figsize=(10, 5), sharey=True)  # 1 row, 3 columns

for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(sample_labels, mean_values[metric], marker='o', linestyle='-', label=f'Mean {metric}')
    ax.fill_between(sample_labels,
                    mean_values[metric] - var_values[metric] ** 0.5,
                    mean_values[metric] + var_values[metric] ** 0.5,
                    color='gray', alpha=0.2)
    ax.set_title(f'{metric} Mean and Variance')
    ax.set_ylabel(f'{metric}')
    ax.set_xlabel('Sample Size')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
print(mean_values)
# Out:
#          NMSE      CORR        R2  Time_Taken
# 250  0.639958  0.435686  0.161498    0.723538
# 350  0.632665  0.446142  0.174263    0.677026
# 450  0.611781  0.474474  0.200627    0.952246
# 550  0.602536  0.487957  0.215050    1.295728
# 679  0.576490  0.513305  0.250355    1.643178

# %% [markdown]
# 2. Training Data

# %%
# Prepare data for plotting
metrics = ['Train_NMSE', 'Train_CORR', 'Train_R2']
sample_labels = ['250', '350', '450', '550', '679']

# Assuming mean_df_350, mean_df_450, mean_df_550, var_df_350, var_df_450, var_df_550 are defined similarly to mean_df_250 and mean_df_679
mean_values = pd.DataFrame([Train_mean_df_250, Train_mean_df_350, Train_mean_df_450, Train_mean_df_550, Train_mean_df_679], index=sample_labels)
var_values = pd.DataFrame([Train_var_df_250, Train_var_df_350, Train_var_df_450, Train_var_df_550, Train_var_df_679], index=sample_labels)

import matplotlib.pyplot as plt

# Plotting
fig, axes = plt.subplots(1, 3, figsize=(10, 5), sharey=True)  # 1 row, 3 columns

for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.plot(sample_labels, mean_values[metric], marker='o', linestyle='-', label=f'Mean {metric}')
    ax.fill_between(sample_labels,
                    mean_values[metric] - var_values[metric] ** 0.5,
                    mean_values[metric] + var_values[metric] ** 0.5,
                    color='gray', alpha=0.2)
    ax.set_title(f'{metric} Mean and Variance')
    ax.set_ylabel(f'{metric}')
    ax.set_xlabel('Sample Size')
    ax.legend()

plt.tight_layout()
plt.show()

# %%
print(mean_values)
# Out:
#      Train_NMSE  Train_CORR  Train_R2
# 250    0.116731    0.972959  0.883269
# 350    0.060005    0.985749  0.939995
# 450    0.092256    0.975028  0.907744
# 550    0.119927    0.963987  0.880073
# 679    0.098401    0.969820  0.901599

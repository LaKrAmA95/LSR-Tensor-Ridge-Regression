# %% [markdown]
# ### Importing the Libraries

# %%
# Needed to import data
import sys
import pandas as pd
import re
import dill
import os 

#os search
import platform

# Time 
import time

# bases
import numpy as np
import scipy

#pre-processing 
from sklearn.preprocessing import StandardScaler

#k-Fold cross 
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

#Ridge 
from sklearn.linear_model import Ridge

#plotting 
import matplotlib.pyplot as plt

#reproducability 
import random
random.seed(42)
np.random.seed(42)

# %% [markdown]
# ### Setting up paths

# %%
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP')
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Vector Regression Baseline/Experimental Results/Vector_Base_Line/with k-fold cv kernel mapping before centering')

# %% [markdown]
# ### Functions Needed

# %%
#Row Wise Normalization of Samples
def normalize_rows(matrix: np.ndarray):
    """
    Normalize each row of the given matrix by the norm of the row.
    
    Parameters:
    matrix (numpy.ndarray): The input matrix to be normalized.
    
    Returns:
    numpy.ndarray: The row-normalized matrix.
    """
    # Calculate the L2 norm for each row. Adding a small epsilon to avoid division by zero.
    row_norms = np.linalg.norm(matrix, axis=1, keepdims=True)
    epsilon = 1e-10  # Small value to prevent division by zero
    row_norms[row_norms == 0] = epsilon
    
    # Normalize each row by its norm
    normalized_matrix = matrix / row_norms
    return normalized_matrix


def LRR(X_train,Y_train,X_validatioon,Y_validation,alpha,Y_train_mean = None):
    print(f'X_train inside the LRR:{X_train.shape}')
    #model 
    ridge_regression = Ridge(alpha=alpha,fit_intercept=False)
    #fitting model
    ridge_regression.fit(X_train,Y_train)
    
    #training 

    Y_train_predicted = ridge_regression.predict(X_train).flatten().reshape(-1,1) 

    #nmse
    train_nmse    = (np.linalg.norm(Y_train - Y_train_predicted)**2/(np.linalg.norm(Y_train)**2))
    #r2
    train_numerator = np.sum((Y_train - Y_train_predicted)**2)
    train_denominator = np.sum((Y_train - np.mean(Y_train))**2)
    train_r2 = 1 - (train_numerator / train_denominator)
    #correlation
    train_corr    = np.corrcoef(Y_train.flatten(), Y_train_predicted.flatten())[0,1]
    

    
    
    #testing 
    
    if Y_train_mean is not None:
        Y_predicted = ridge_regression.predict(X_validatioon).flatten().reshape(-1,1) + Y_train_mean
    else:
        Y_predicted = ridge_regression.predict(X_validatioon).flatten().reshape(-1,1) 

    #error matrices 

    #nmse
    nmse    = (np.linalg.norm(Y_validation - Y_predicted)**2/(np.linalg.norm(Y_validation)**2))
    #r2
    numerator = np.sum((Y_validation - Y_predicted)**2)
    denominator = np.sum((Y_validation - np.mean(Y_validation))**2)
    r2 = 1 - (numerator / denominator)
    #correlation
    corr    = np.corrcoef(Y_validation.flatten(), Y_predicted.flatten())[0,1]
    
    return nmse,r2,corr,train_nmse,train_r2,train_corr

# %% [markdown]
# ### Hyper Parameteres

# %%
#number of splits for K-Fild Cross Validation
n_splits = 10
# Ridge Regression coefficient grid
#the regularization coefficients to search over
alphas = [0,0.00001,0.0001, 0.001, 0.004, 0.007, 0.01, 0.04, 0.07, 0.1, 0.4, 0.7, 1, 1.5, 2, 2.5, 3,3.5, 4, 5, 10, 15, 20]
#[0.07,0.08,0.09,0.1,0.12,0.14,0.16,0.18,2.0,2.5,3.0,3.5,4.0]

#number of seeds
number_of_seeds = 10
n_samples = 250

# %% [markdown]
# ### Importing Data

# %% [markdown]
# #### 1. Data Loading

# %%
#Load fMRI Resting State Data
with open("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/fmri_rs.npy", "rb") as f:
  fmri_rs = np.load(f)

#Take the Transpose so that each Sample is a Row
fmri_rs = fmri_rs.T

#iterating over seed
columns = ['Seed','Best_lambda','NMSE','CORR','R2','Time_Taken','Train_NMSE','Train_CORR','Train_R2']
results_df = pd.DataFrame(columns = columns)


for seed in range(number_of_seeds):

    print('')
    print(f'=====================================Seed:{seed}===========================================')

    #Get Split to divide into train + test(loaded data is in the form of features * sampels so need to transpose)
    mat_file = scipy.io.loadmat("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/MMP_HCP_60_splits.mat")
    seed_1 = mat_file['folds'][f'seed_{seed+1}']
    subject_lists = seed_1[0, 0]['sub_fold'][0, 0]['subject_list']
    test_subjects = [int(item[0]) for item in subject_lists[0,0].flatten()]

    #Get HCP test subjects
    HCP_753_Subjects = []
    with open('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/MMP_HCP_753_subs.txt', 'r') as file:
        HCP_753_Subjects = [int(re.sub('\n', '', line)) for line in file.readlines()]

    #Put the HCP test subjects into a dataframe
    df = pd.read_csv("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/MMP_HCP_componentscores.csv")
    df['Subject'] = pd.to_numeric(df['Subject'], errors='coerce')
    df = df[df['Subject'].isin(HCP_753_Subjects)].reset_index(drop = True)

    #Split all our data into a Train and Test Set
    df_train, df_test = df[~df['Subject'].isin(test_subjects)], df[df['Subject'].isin(test_subjects)]

    #Create Train and Test Arrays corresponding to Training and Test Subjects
    train_subjects = df_train.index.to_list()
    test_subjects = df_test.index.to_list()

    #Reshape Labels into Column Vectors

    # Assuming fmri_rs and dMRI_streamlog are numpy arrays or can be converted to numpy arrays
    X_train_fmri = fmri_rs[train_subjects]
    Y_train_fmri = df_train["varimax_cog"].to_numpy().reshape((-1, 1))
    X_test_fmri = fmri_rs[test_subjects]
    Y_test_fmri = df_test["varimax_cog"].to_numpy().reshape((-1, 1))

    # Generate random indices
    random_indices = np.random.choice(X_train_fmri.shape[0], size=n_samples, replace=False)

    X_train = X_train_fmri[random_indices]
    X_test = X_test_fmri
    Y_train = Y_train_fmri[random_indices]
    Y_test = Y_test_fmri

        # Verify the shapes
    print("X_train_combined shape:", X_train.shape)
    print("X_test_combined shape:", X_test.shape)
    print("Y_train_combined shape:", Y_train.shape)
    print("Y_test_combined shape:", Y_test.shape)

    #Preprocess Data

    #Projecting in to the kernel space
    X_train = normalize_rows(X_train)
    X_test = normalize_rows(X_test)

    #intercept removal step

    #number of samples in train and test
    n_train = X_train.shape[0]
    n_test = X_test.shape[0]



    # Initialize StandardScaler
    scaler = StandardScaler(with_std = False) #standard scalar only

    # Fit scaler on train data and transform train data
    X_train_scaled = scaler.fit_transform(X_train)

    # Transform test data using the scaler fitted on train data
    X_test_scaled = scaler.transform(X_test)


    #average response value
    Y_train_mean = np.mean(Y_train)

    # Mean centering y_train and y_test
    Y_train = Y_train - Y_train_mean

    #printing the outcomes
    print("Sample mean for each feature (across samples):",scaler.mean_)
    print("Sample variance for each feature (across samples):",scaler.var_)
    print('Response Average:',Y_train_mean)


    # Number of folds we are using 

    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)



    k_fold_results = np.ones(shape=[n_splits,len(alphas),3])*np.inf

    #iterating over the folds
    for fold,(train_ids,validation_ids) in enumerate(kfold.split(X_train)):

        #the training and validatiion data 
        X_train_fold,Y_train_fold = X_train[train_ids],Y_train[train_ids]
        X_validation_fold,Y_validation_fold = X_train[validation_ids],Y_train[validation_ids]
        
        #iterating over the alpha values 
        for alpha_idx,alpha in enumerate(alphas):
            nmse,r2,corr,train_nmse,train_r2,train_corr = LRR(X_train_fold,Y_train_fold,X_validation_fold,Y_validation_fold,alpha)
            k_fold_results[fold,alpha_idx,0] = nmse
            k_fold_results[fold,alpha_idx,1] = r2
            k_fold_results[fold,alpha_idx,2] = corr

            print(f"fold = {fold},alpha = {alpha},nmse = {nmse},r2 = {r2}, corr = {corr}")

    #Choosing the best lambda

    #array to hold all the sums
    nmse_sum = np.zeros(len(alphas))

    # Iterate over the folds and alpha values to accumulate nmse values
    for alpha_idx in range(len(alphas)):
        for fold in range(n_splits):
            nmse_sum[alpha_idx] += k_fold_results[fold, alpha_idx, 0]

    #best lambda 

    best_alpha_idx = np.argmin(nmse_sum)
    best_alpha = alphas[best_alpha_idx]        
    print(f"The best alpha value is {best_alpha}")
    average_results = np.mean(k_fold_results, axis=0)
    print(f"The best alpha value is {best_alpha}")
    print(f'average performance metrics: {average_results[best_alpha_idx]}')

    #Choosing the best lambda

    # Iterate over the folds and alpha values to accumulate nmse values
    for alpha_idx in range(len(alphas)):
        for fold in range(n_splits):
            nmse_sum[alpha_idx] += k_fold_results[fold, alpha_idx, 0]

    best_alpha_idx = np.argmin(nmse_sum)
    best_alpha = alphas[best_alpha_idx]        
    average_results = np.mean(k_fold_results, axis=0)
    
    print(f"The best alpha value is {best_alpha}")
    print(f'average performance metrics: {average_results[best_alpha_idx]}')

    #Testing 
    start_time = time.time()
    nmse_best,r2_best,corr_best,train_nmse,train_r2,train_corr =  LRR(X_train,Y_train,X_test,Y_test,best_alpha,Y_train_mean=Y_train_mean)
    end_time = time.time()
    elapsed_time = end_time - start_time 
    
    print(f'Time to run one experiment: {elapsed_time}')
    print(f'Test Results: Seed:{seed} Best_Lambda:{best_alpha} NMSE:{nmse_best} CORR:{corr_best} R2:{r2_best}')

    #loading results 
    columns = ['Seed','Best_lambda','NMSE','CORR','R2','Time_Taken','Train_NMSE','Train_CORR','Train_R2']
    
    seed_result_df = pd.DataFrame([{
    'Seed': seed,
    'Best_lambda': best_alpha,
    'NMSE': nmse_best,
    'CORR': corr_best,
    'R2': r2_best,
    'Time_Taken': elapsed_time,
    'Train_NMSE': train_nmse,
    'Train_CORR': train_corr,
    'Train_R2': train_r2
    }], columns=columns)
    
    # concatenating results 
    results_df = pd.concat([results_df,seed_result_df],ignore_index = True)

    #saving the results 

    if platform.system() == 'Windows':
        file_path = rf'Enter file path'
    elif platform.system() == 'Darwin':
        file_path = '/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/without_concat k-fold cv kernel map centering resting fmri/250'

    results_df.to_csv(f'{file_path}/results_{seed}.csv',index = False)
# Out:
# =====================================Seed:0===========================================
# X_train_combined shape: (250, 79800)
# X_test_combined shape: (76, 79800)
# Y_train_combined shape: (250, 1)
# Y_test_combined shape: (76, 1)
# Sample mean for each feature (across samples): [0.00850705 0.00912166 0.00506027 ... 0.00103466 0.00498447 0.00741783]
# Sample variance for each feature (across samples): None
# Response Average: 1.1299052361162936
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0,nmse = 0.8192638908742711,r2 = 0.17177214324035284, corr = 0.44224753626984165
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 1e-05,nmse = 0.8192647512370138,r2 = 0.1717712734639616, corr = 0.44224323935312476
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.0001,nmse = 0.8192725374799814,r2 = 0.1717634020279113, corr = 0.44220456448330464
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.001,nmse = 0.8193545860132985,r2 = 0.1716804557615661, corr = 0.4418175720714775
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.004,nmse = 0.8196796354492598,r2 = 0.17135184980115947, corr = 0.44052516488989046
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.007,nmse = 0.8200757117576516,r2 = 0.170951439828663, corr = 0.43923084811837687
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.01,nmse = 0.8205333053269547,r2 = 0.17048883950489357, corr = 0.43793667277735143
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.04,nmse = 0.8271360882056312,r2 = 0.16381381235775572, corr = 0.42526784293247916
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.07,nmse = 0.835175178369597,r2 = 0.15568676258665703, corr = 0.4134442635892083
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.1,nmse = 0.8432917583087606,r2 = 0.1474813751869296, corr = 0.40256081660866533
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.4,nmse = 0.9006653243066296,r2 = 0.0894800570153641, corr = 0.3274089874403539
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.7,nmse = 0.9306638407725341,r2 = 0.059153312146856374, corr = 0.28088532454291953
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 1,nmse = 0.948932360507463,r2 = 0.04068490762571342, corr = 0.24657508488250338
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 1.5,nmse = 0.9672084994627025,r2 = 0.022208800518653593, corr = 0.20412077806692186
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 2,nmse = 0.9779551406153115,r2 = 0.011344575122740896, corr = 0.1728408806850598
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 2.5,nmse = 0.9848716151481332,r2 = 0.00435242406804448, corr = 0.1486838652528491
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 3,nmse = 0.9896000203766703,r2 = -0.000427716948720791, corr = 0.12944619196573887
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 3.5,nmse = 0.9929769977232832,r2 = -0.003841643451847787, corr = 0.11377151581366103
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 4,nmse = 0.9954704449442653,r2 = -0.0063623726952342086, corr = 0.10076495020204453
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 5,nmse = 0.9988239627790687,r2 = -0.009752583004589477, corr = 0.08046017868145224
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 10,nmse = 1.0042932041900043,r2 = -0.015281666053821308, corr = 0.030881245333988422
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 15,nmse = 1.0053015736869437,r2 = -0.016301068613331804, corr = 0.01130709495959858
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 20,nmse = 1.0054978054300867,r2 = -0.016499447423702795, corr = 0.0009953776969031717
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0,nmse = 0.8683298996513584,r2 = 0.09474599642749204, corr = 0.49204169501128453
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 1e-05,nmse = 0.8683138102823285,r2 = 0.09476276996682909, corr = 0.4920451929654447
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.0001,nmse = 0.8681691269458571,r2 = 0.09491360569141172, corr = 0.4920766615789014
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.001,nmse = 0.8667341814202977,r2 = 0.09640956958997482, corr = 0.49239006457606327
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.004,nmse = 0.8621025802738423,r2 = 0.1012381209072366, corr = 0.493417966985446
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.007,nmse = 0.857692654399654,r2 = 0.10583557062613969, corr = 0.49442029610583527
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.01,nmse = 0.8534905057730449,r2 = 0.11021640775886088, corr = 0.4953974090585371
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.04,nmse = 0.8205386930436053,r2 = 0.14456943465598093, corr = 0.5038847256822794
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.07,nmse = 0.7990060908671504,r2 = 0.1670176704421682, corr = 0.5103959477603356
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.1,nmse = 0.7844976262631893,r2 = 0.1821430803511198, corr = 0.5153942770225352
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.4,nmse = 0.7594734651821444,r2 = 0.20823134704993385, corr = 0.5300640450865637
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.7,nmse = 0.7769438689845316,r2 = 0.19001804702135094, corr = 0.5272199602339437
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 1,nmse = 0.7963247426300036,r2 = 0.16981303799501146, corr = 0.5219522508693502
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 1.5,nmse = 0.8238497965998914,r2 = 0.1411175326176256, corr = 0.5132973565948881
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 2,nmse = 0.8454189550462823,r2 = 0.11863118607453771, corr = 0.5059327301342127
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 2.5,nmse = 0.8625461534423098,r2 = 0.10077568561991856, corr = 0.49979261930105384
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 3,nmse = 0.8764442552411358,r2 = 0.08628659305210884, corr = 0.4946298534888206
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 3.5,nmse = 0.8879481368117604,r2 = 0.07429353044697062, corr = 0.49023271871049995
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 4,nmse = 0.8976323414069081,r2 = 0.06419752317520366, corr = 0.4864405369879188
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 5,nmse = 0.9130477843880848,r2 = 0.048126567330936676, corr = 0.4802202186150014
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 10,nmse = 0.952837089593497,r2 = 0.006645296386529664, corr = 0.4628291837951425
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 15,nmse = 0.96977308043892,r2 = -0.011010865774236933, corr = 0.45446773729022377
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 20,nmse = 0.9790833701530461,r2 = -0.020717058134441135, corr = 0.4493462643884032
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0,nmse = 0.697825381419463,r2 = 0.2814904872971926, corr = 0.5560309595684958
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 1e-05,nmse = 0.6978185647168961,r2 = 0.28149750605255763, corr = 0.5560414136568813
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.0001,nmse = 0.6977573184900905,r2 = 0.28156056766904325, corr = 0.5561354166500736
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.001,nmse = 0.6971550468860566,r2 = 0.2821806911100234, corr = 0.5570672153371169
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.004,nmse = 0.6952755248841975,r2 = 0.2841159237249833, corr = 0.560068430486915
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.007,nmse = 0.6935787478513618,r2 = 0.28586299465632203, corr = 0.5629167663140223
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.01,nmse = 0.6920479330303554,r2 = 0.2874391841162729, corr = 0.5656222679644646
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.04,nmse = 0.683268926808648,r2 = 0.29647840746688126, corr = 0.5865079245519068
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.07,nmse = 0.681471279729877,r2 = 0.2983293383171636, corr = 0.5997455622652629
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.1,nmse = 0.6830752456779111,r2 = 0.2966778294692486, corr = 0.6083674412843194
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.4,nmse = 0.7312539154363518,r2 = 0.24707110341352434, corr = 0.6181253059103353
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.7,nmse = 0.7720557800853529,r2 = 0.20505983717570642, corr = 0.6023877083857273
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 1,nmse = 0.8020489627837544,r2 = 0.17417763131326214, corr = 0.5864247630453213
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 1.5,nmse = 0.8373425560598595,r2 = 0.13783790624513315, corr = 0.5642225786333956
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 2,nmse = 0.8618181987295008,r2 = 0.11263678493899809, corr = 0.5469153450148511
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 2.5,nmse = 0.8798971194141216,r2 = 0.09402198983814258, corr = 0.5331660520957738
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 3,nmse = 0.8938539934774167,r2 = 0.07965142228774169, corr = 0.5219892607277765
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 3.5,nmse = 0.9049844692214278,r2 = 0.06819102988024284, corr = 0.5127196283326518
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 4,nmse = 0.9140849097892565,r2 = 0.058820844599118516, corr = 0.504901999982167
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 5,nmse = 0.9281050898842821,r2 = 0.04438509457295692, corr = 0.492431082554455
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 10,nmse = 0.9619690882411831,r2 = 0.009517338819945653, corr = 0.46017999660603803
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 15,nmse = 0.9754969114497661,r2 = -0.004411460447511839, corr = 0.4465938640099854
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 20,nmse = 0.9827416801805919,r2 = -0.01187097021747996, corr = 0.4392959127374666
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0,nmse = 1.0175328279228928,r2 = -0.40370622127991496, corr = 0.2568978034764563
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 1e-05,nmse = 1.0175135717783692,r2 = -0.40367965705601594, corr = 0.25690153879345523
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.0001,nmse = 1.017340430894202,r2 = -0.4034408058567285, corr = 0.25693512991993267
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.001,nmse = 1.0156251529709006,r2 = -0.40107454677781806, corr = 0.2572684117148264
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.004,nmse = 1.0101119984603777,r2 = -0.39346904347322575, corr = 0.25834566835685363
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.007,nmse = 1.0048949578723674,r2 = -0.38627203505335084, corr = 0.25937328044880725
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.01,nmse = 0.9999520870049754,r2 = -0.37945324906714895, corr = 0.2603539480135991
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.04,nmse = 0.9620539117444111,r2 = -0.32717198311821183, corr = 0.2680668536043991
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.07,nmse = 0.937963815239051,r2 = -0.2939392289427667, corr = 0.2730903896632066
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.1,nmse = 0.9219097797883012,r2 = -0.27179237645755716, corr = 0.2764411196583368
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.4,nmse = 0.8902954720906746,r2 = -0.22817982737921083, corr = 0.28183645101730626
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.7,nmse = 0.9025347769283617,r2 = -0.24506418518403272, corr = 0.2778158984252486
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 1,nmse = 0.9170351471555858,r2 = -0.2650677264362262, corr = 0.27333780945469593
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 1.5,nmse = 0.9372600970570653,r2 = -0.2929684360966056, corr = 0.26649938815559543
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 2,nmse = 0.9524858243244757,r2 = -0.3139726214184724, corr = 0.2605138972649137
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 2.5,nmse = 0.9640905063167463,r2 = -0.3299815047306476, corr = 0.2552532398530282
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 3,nmse = 0.973157032061651,r2 = -0.34248895239648447, corr = 0.25060498460454805
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 3.5,nmse = 0.9804080007836042,r2 = -0.3524918040254479, corr = 0.24647850511191946
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 4,nmse = 0.9863246415966307,r2 = -0.36065392449017786, corr = 0.24279883602788122
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 5,nmse = 0.9953694825270053,r2 = -0.373131457534857, corr = 0.2365390875268435
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 10,nmse = 1.016268652890475,r2 = -0.4019622673660015, corr = 0.21806354091874675
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 15,nmse = 1.0237004905121576,r2 = -0.41221463114122536, corr = 0.20925935650171582
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 20,nmse = 1.0271180822745347,r2 = -0.41692926509405503, corr = 0.2042450048940231
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0,nmse = 1.0476948041386294,r2 = -0.0479442112639874, corr = 0.27211762405198453
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 1e-05,nmse = 1.0476662612582957,r2 = -0.04791566158892868, corr = 0.2721268393605799
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.0001,nmse = 1.0474096331574536,r2 = -0.04765897239694006, corr = 0.2722097384857001
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.001,nmse = 1.0448686263364737,r2 = -0.045117360681095287, corr = 0.27303492778352123
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.004,nmse = 1.036717898044453,r2 = -0.03696469208193065, corr = 0.2757368742465691
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.007,nmse = 1.0290271497253705,r2 = -0.029272112955420093, corr = 0.2783670082201401
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.01,nmse = 1.0217593834819265,r2 = -0.02200261659679459, corr = 0.2809290070237752
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.04,nmse = 0.9664908032535551,r2 = 0.03327912049525794, corr = 0.30340673450445943
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.07,nmse = 0.9314368623472131,r2 = 0.06834140610522899, corr = 0.32147655088659177
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.1,nmse = 0.9077345912166899,r2 = 0.09204931963779883, corr = 0.336348404524584
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.4,nmse = 0.8477111191015985,r2 = 0.15208708053391196, corr = 0.4072074939041939
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.7,nmse = 0.8509641043032383,r2 = 0.14883332094865898, corr = 0.4310666033715977
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 1,nmse = 0.861041366977386,r2 = 0.13875365934964778, corr = 0.4423308395779447
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 1.5,nmse = 0.8777886484251268,r2 = 0.12200239115757361, corr = 0.45123649956410744
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 2,nmse = 0.8916433730416037,r2 = 0.10814436837924113, corr = 0.45525767649918747
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 2.5,nmse = 0.902813739459923,r2 = 0.09697134281918829, corr = 0.45724841388902165
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 3,nmse = 0.9119122245798396,r2 = 0.08787069177556028, corr = 0.4582551978167409
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 3.5,nmse = 0.9194403957583679,r2 = 0.08034072849161566, corr = 0.45874148700012796
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 4,nmse = 0.9257654372677878,r2 = 0.07401418128567594, corr = 0.4589382142842175
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 5,nmse = 0.9357973686507116,r2 = 0.06397986176914872, corr = 0.4589075620200783
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 10,nmse = 0.9614552769332774,r2 = 0.03831584553880829, corr = 0.45763242736947357
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 15,nmse = 0.9723435658378221,r2 = 0.02742496464199151, corr = 0.4573578375975101
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 20,nmse = 0.9783918822045214,r2 = 0.02137520845408436, corr = 0.4578326636755461
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0,nmse = 0.9096765721466578,r2 = -0.003350819419373874, corr = 0.3758738891760134
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 1e-05,nmse = 0.9096465487686961,r2 = -0.0033177043740908463, corr = 0.375880805335478
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.0001,nmse = 0.9093766607611309,r2 = -0.00302002455927175, corr = 0.3759429906377471
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.001,nmse = 0.906709366864029,r2 = -7.80651868605986e-05, corr = 0.3765589422963628
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.004,nmse = 0.8982165037940731,r2 = 0.009289353279625656, corr = 0.37853724119302806
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.007,nmse = 0.8902947863272715,r2 = 0.01802681223470004, corr = 0.380406908301774
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.01,nmse = 0.8828952507107686,r2 = 0.02618831748993733, corr = 0.3821758033858244
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.04,nmse = 0.8299024148130218,r2 = 0.08463810827204887, corr = 0.3956118713560191
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.07,nmse = 0.8002372194208345,r2 = 0.1173580870165255, corr = 0.40395633489874705
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.1,nmse = 0.7827366885447481,r2 = 0.1366607408744337, corr = 0.4093638401223526
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.4,nmse = 0.7673456436632343,r2 = 0.15363668371656458, corr = 0.41826998192697595
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.7,nmse = 0.7917077558906709,r2 = 0.1267658748877708, corr = 0.41304927377611006
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 1,nmse = 0.8142403806899964,r2 = 0.101912945562877, corr = 0.4072871513465501
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 1.5,nmse = 0.8437309188220287,r2 = 0.06938560946795269, corr = 0.3989592909978358
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 2,nmse = 0.8655855813523678,r2 = 0.04528045580195894, corr = 0.39223385183867926
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 2.5,nmse = 0.8823250416407904,r2 = 0.026817244028358278, corr = 0.38673857017233926
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 3,nmse = 0.8955501770577649,r2 = 0.01223024589753885, corr = 0.38216530756107703
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 3.5,nmse = 0.9062684282530141,r2 = 0.00040827922413266826, corr = 0.3782936854721339
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 4,nmse = 0.9151368797264532,r2 = -0.009373403986481454, corr = 0.37496666562326275
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 5,nmse = 0.9289723021771226,r2 = -0.024633533661069018, corr = 0.3695206053514909
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 10,nmse = 0.9631615921976177,r2 = -0.062343477181412865, corr = 0.3540774850275054
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 15,nmse = 0.9770765032226947,r2 = -0.07769128079276921, corr = 0.3461408773171491
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 20,nmse = 0.984566073909426,r2 = -0.08595209250950742, corr = 0.3408384472751842
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0,nmse = 1.3727390477835495,r2 = -0.5292762387649872, corr = 0.12179409952687287
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 1e-05,nmse = 1.3727212122644992,r2 = -0.5292563694128827, corr = 0.12179458711788949
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.0001,nmse = 1.3725608607254962,r2 = -0.5290777325489837, corr = 0.12179897096627884
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.001,nmse = 1.370973813439853,r2 = -0.5273097099174073, corr = 0.12184236343299451
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.004,nmse = 1.365891009556469,r2 = -0.5216472999949149, corr = 0.12198099206911603
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.007,nmse = 1.3611051885799064,r2 = -0.5163157387529904, corr = 0.12211004889522364
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.01,nmse = 1.356590359427808,r2 = -0.5112860712750116, corr = 0.12222926463856593
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.04,nmse = 1.322288851483721,r2 = -0.4730730684924378, corr = 0.12289529986827136
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.07,nmse = 1.2999813879350028,r2 = -0.44822182381687314, corr = 0.12279661601907371
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.1,nmse = 1.2839294437231994,r2 = -0.4303394324703693, corr = 0.12222752266353669
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.4,nmse = 1.2117989650663525,r2 = -0.3499837179019194, corr = 0.11304035780284259
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.7,nmse = 1.1763134439496299,r2 = -0.31045168568383796, corr = 0.10694895668817658
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 1,nmse = 1.1525541819702543,r2 = -0.2839830900288096, corr = 0.102961985701819
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 1.5,nmse = 1.1263931250035149,r2 = -0.2548388161299877, corr = 0.09859865614902996
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 2,nmse = 1.1094045466988158,r2 = -0.23591298374128855, corr = 0.09575338832177663
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 2.5,nmse = 1.0975080708399232,r2 = -0.22265992017802705, corr = 0.0937708680631701
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 3,nmse = 1.0887280074749341,r2 = -0.21287864215536945, corr = 0.09233613704341069
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 3.5,nmse = 1.081991318299273,r2 = -0.20537374987382617, corr = 0.09127164379307774
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 4,nmse = 1.0766650627693268,r2 = -0.19944012684715662, corr = 0.09046785612067508
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 5,nmse = 1.0687896917696977,r2 = -0.19066670573654032, corr = 0.08937905368841918
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 10,nmse = 1.0513793196629582,r2 = -0.1712709812440496, corr = 0.08791813097616447
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 15,nmse = 1.0447939430014923,r2 = -0.16393465605685686, corr = 0.08813664068404402
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 20,nmse = 1.0410769231879557,r2 = -0.15979377430002328, corr = 0.08862127207297538
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0,nmse = 0.7828647169562376,r2 = 0.20755980291798826, corr = 0.4650249378407309
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 1e-05,nmse = 0.7828570163319579,r2 = 0.20756759773117817, corr = 0.46502916111964404
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.0001,nmse = 0.7827878264002112,r2 = 0.20763763394811585, corr = 0.46506711762586317
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.001,nmse = 0.782107247239177,r2 = 0.20832653750043906, corr = 0.46544148823301523
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.004,nmse = 0.7799806324150036,r2 = 0.21047916366162, corr = 0.46662385379040616
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.007,nmse = 0.7780559871836992,r2 = 0.21242734987230782, corr = 0.46771206721700287
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.01,nmse = 0.7763139526463697,r2 = 0.21419069181656103, corr = 0.46871408744695775
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.04,nmse = 0.7659584093369254,r2 = 0.22467289723888817, corr = 0.4752708300886702
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.07,nmse = 0.7629232370521941,r2 = 0.22774519373072877, corr = 0.4780312437890343
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.1,nmse = 0.7632737663419941,r2 = 0.2273903769999761, corr = 0.4788892717571175
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.4,nmse = 0.7965956933319149,r2 = 0.19366087837892443, corr = 0.46648272268664476
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.7,nmse = 0.8251832352209902,r2 = 0.16472367270596056, corr = 0.45255502811140963
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 1,nmse = 0.8463405177324071,r2 = 0.14330760839761825, corr = 0.44119761724393025
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 1.5,nmse = 0.871602979560963,r2 = 0.11773615295122752, corr = 0.4264582038078071
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 2,nmse = 0.8894355302427954,r2 = 0.09968548637919494, corr = 0.4152446569768542
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 2.5,nmse = 0.9028040112379161,r2 = 0.08615349102289738, corr = 0.4063828569307614
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 3,nmse = 0.9132527867443143,r2 = 0.0755769130494407, corr = 0.39917965764190066
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 3.5,nmse = 0.9216737080189555,r2 = 0.06705299267091913, corr = 0.39319557545933087
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 4,nmse = 0.9286218594237091,r2 = 0.06001985610302574, corr = 0.38813652024204753
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 5,nmse = 0.9394479681703428,r2 = 0.04906132960029974, corr = 0.38003042285963345
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 10,nmse = 0.9663302672018426,r2 = 0.021850224180498645, corr = 0.3585863776963067
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 15,nmse = 0.9774405293185988,r2 = 0.010604068732765537, corr = 0.34893986146588857
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 20,nmse = 0.9835098573067722,r2 = 0.004460504764519646, corr = 0.3432791213716864
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0,nmse = 1.2370249224425687,r2 = -0.24801748812359614, corr = 0.05920860254796814
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 1e-05,nmse = 1.2370075971412404,r2 = -0.24800000886456752, corr = 0.05920539438380681
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.0001,nmse = 1.236851817070592,r2 = -0.24784284448659544, corr = 0.05917655269754768
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.001,nmse = 1.2353084736670072,r2 = -0.2462857864816117, corr = 0.058891255406571794
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.004,nmse = 1.2303458574671013,r2 = -0.24127907102102197, corr = 0.05797982815626594
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.007,nmse = 1.225643341173496,r2 = -0.23653476679066165, corr = 0.05712577496223578
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.01,nmse = 1.2211778160578983,r2 = -0.23202955971131156, corr = 0.05632492890758549
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.04,nmse = 1.1860124190206278,r2 = -0.19655167265899043, corr = 0.05056674948800135
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.07,nmse = 1.1615117302005287,r2 = -0.17183326354385176, corr = 0.047524336944716666
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.1,nmse = 1.1428933330880358,r2 = -0.15304941790286053, corr = 0.04606818137365988
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.4,nmse = 1.0596917674369197,r2 = -0.06910849877665148, corr = 0.05473774909343283
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.7,nmse = 1.0303075298469502,r2 = -0.039463144247294135, corr = 0.06675514562272851
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 1,nmse = 1.0158550709111627,r2 = -0.024882256529497493, corr = 0.07556183075884197
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 1.5,nmse = 1.0041550625369389,r2 = -0.013078278454915493, corr = 0.084927993076052
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 2,nmse = 0.9987536820831121,r2 = -0.007628899752767593, corr = 0.0903188985729796
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 2.5,nmse = 0.9959875377305603,r2 = -0.004838174631528691, corr = 0.09349482352988915
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 3,nmse = 0.9944965418368196,r2 = -0.003333929311689632, corr = 0.09537627619461375
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 3.5,nmse = 0.993682434674042,r2 = -0.0025125877542799824, corr = 0.09646916207957441
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 4,nmse = 0.9932509556745067,r2 = -0.0020772745060109177, corr = 0.0970660732802286
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 5,nmse = 0.9929772161288528,r2 = -0.0018011024305992773, corr = 0.09741236098262625
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 10,nmse = 0.9941186044975729,r2 = -0.0029526335105800605, corr = 0.09493313069040947
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 15,nmse = 0.9952426242738993,r2 = -0.004086641655769441, corr = 0.09241949068197026
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 20,nmse = 0.9960058453358389,r2 = -0.0048566449235485365, corr = 0.09065428402755848
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0,nmse = 0.9051048962987851,r2 = 0.09238085406354968, corr = 0.32859823508142777
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 1e-05,nmse = 0.9050959512605435,r2 = 0.09238982394980533, corr = 0.3286055441950128
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.0001,nmse = 0.9050155525364282,r2 = 0.09247044600987175, corr = 0.32867126564134314
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.001,nmse = 0.9042220046318565,r2 = 0.0932661982749986, corr = 0.32932253066712674
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.004,nmse = 0.9017081020767329,r2 = 0.095787084085449, corr = 0.3314177060560645
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.007,nmse = 0.8993817371939965,r2 = 0.09811991127116004, corr = 0.33340249691747126
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.01,nmse = 0.8972259645427143,r2 = 0.10028167234503227, corr = 0.33528426792965094
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.04,nmse = 0.8824270523848863,r2 = 0.11512169372642411, corr = 0.3496770013298601
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.07,nmse = 0.8749732277527301,r2 = 0.12259622399828818, corr = 0.3586544559121547
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.1,nmse = 0.8712301148229028,r2 = 0.12634973475091604, corr = 0.3644447841867032
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.4,nmse = 0.8776503874738683,r2 = 0.11991162751718265, corr = 0.3740966086475935
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.7,nmse = 0.8906066850851665,r2 = 0.10691933919728525, corr = 0.3710831745847471
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 1,nmse = 0.900966155850226,r2 = 0.09653109133056126, corr = 0.3687393196241106
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 1.5,nmse = 0.9140624681106772,r2 = 0.08339839942119853, corr = 0.3666841155671196
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 2,nmse = 0.9238568213648076,r2 = 0.07357683887958011, corr = 0.3658651422844688
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 2.5,nmse = 0.9315409070140561,r2 = 0.06587140795903923, corr = 0.36562007848130174
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 3,nmse = 0.937766070746352,r2 = 0.05962895162814852, corr = 0.3656596895923327
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 3.5,nmse = 0.9429282136513745,r2 = 0.054452469041635254, corr = 0.3658493783519093
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 4,nmse = 0.9472864580041637,r2 = 0.05008211812050256, corr = 0.3661215759785672
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 5,nmse = 0.9542554178546597,r2 = 0.043093799514076436, corr = 0.36678471163128423
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 10,nmse = 0.9724693521375182,r2 = 0.024829269573345858, corr = 0.3703859106689177
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 15,nmse = 0.9803629051593369,r2 = 0.01691378941036803, corr = 0.3736242044740391
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 20,nmse = 0.9847771207755639,r2 = 0.01248731174577622, corr = 0.3765215383745904
# The best alpha value is 0.4
# The best alpha value is 0.4
# average performance metrics: [0.88424818 0.05168067 0.35912697]
# The best alpha value is 0.4
# average performance metrics: [0.88424818 0.05168067 0.35912697]
# X_train inside the LRR:(250, 79800)
# Time to run one experiment: 0.39693403244018555
# Test Results: Seed:0 Best_Lambda:0.4 NMSE:0.8012009232275991 CORR:0.4336142784871614 R2:0.1410605784685255
#
# =====================================Seed:1===========================================
# /var/folders/r8/5wc8dngx7j55w_gyx0q8q2x80000gn/T/ipykernel_7798/3543411863.py:181: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df,seed_result_df],ignore_index = True)
# X_train_combined shape: (250, 79800)
# X_test_combined shape: (77, 79800)
# Y_train_combined shape: (250, 1)
# Y_test_combined shape: (77, 1)
# Sample mean for each feature (across samples): [0.00850138 0.00932469 0.00524118 ... 0.00129316 0.00516818 0.00787391]
# Sample variance for each feature (across samples): None
# Response Average: 1.1345997023731629
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0,nmse = 0.7657614637406955,r2 = 0.22124737659146665, corr = 0.4803908447207568
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 1e-05,nmse = 0.7657592207963373,r2 = 0.22124965758742376, corr = 0.48038972836328586
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.0001,nmse = 0.7657391186113549,r2 = 0.22127010080640608, corr = 0.48037965357063117
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.001,nmse = 0.7655463326202226,r2 = 0.22146615741601539, corr = 0.4802762059753617
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.004,nmse = 0.7650062992373818,r2 = 0.22201535247678672, corr = 0.4798974572627453
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.007,nmse = 0.7646104463582777,r2 = 0.22241792100848112, corr = 0.47947031791576605
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.01,nmse = 0.7643428794306396,r2 = 0.2226900272147896, corr = 0.4789993010466892
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.04,nmse = 0.7663508137856755,r2 = 0.22064802821032403, corr = 0.47259245570827163
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.07,nmse = 0.7726776768918809,r2 = 0.2142138297357291, corr = 0.4644855858597785
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.1,nmse = 0.7805311794334916,r2 = 0.20622709235494097, corr = 0.4557075803319917
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.4,nmse = 0.8522553271430946,r2 = 0.1332861429400347, corr = 0.3720298925871627
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 0.7,nmse = 0.8969834162235324,r2 = 0.08779924086835211, corr = 0.3062138250976834
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 1,nmse = 0.9262080694841129,r2 = 0.05807879073795941, corr = 0.2538718727295889
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 1.5,nmse = 0.9567068888816133,r2 = 0.027062558214786647, corr = 0.18729577650493237
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 2,nmse = 0.975020765617464,r2 = 0.008437986167042832, corr = 0.13826687424043213
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 2.5,nmse = 0.9867930138464616,r2 = -0.003533978505826596, corr = 0.10091614630226749
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 3,nmse = 0.9947201063237381,r2 = -0.011595554277118225, corr = 0.07165553198933182
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 3.5,nmse = 1.000239550006052,r2 = -0.017208635439966313, corr = 0.04819044716160226
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 4,nmse = 1.0041789408864275,r2 = -0.021214858171177964, corr = 0.02899827388906847
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 5,nmse = 1.009153427246121,r2 = -0.026273736798730907, corr = -0.0004330347052250328
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 10,nmse = 1.0148905129734223,r2 = -0.03210815230853026, corr = -0.06959412142213312
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 15,nmse = 1.0142773526550135,r2 = -0.031484589712159616, corr = -0.09600919806881046
# X_train inside the LRR:(225, 79800)
# fold = 0,alpha = 20,nmse = 1.0131227939688585,r2 = -0.030310443913113883, corr = -0.1098453716275974
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0,nmse = 1.045220038852516,r2 = -0.04524584386062358, corr = 0.10296017479732412
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 1e-05,nmse = 1.0452065375283337,r2 = -0.04523234220311201, corr = 0.10297173274125994
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.0001,nmse = 1.0450851319401617,r2 = -0.04511093361760743, corr = 0.1030757118033457
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.001,nmse = 1.043881495041983,r2 = -0.04390726700333181, corr = 0.10411133271116095
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.004,nmse = 1.0400007906347788,r2 = -0.04002646678701138, corr = 0.10751021875211068
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.007,nmse = 1.03630895725122,r2 = -0.03633454225729471, corr = 0.11083118515643554
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.01,nmse = 1.0327903644178875,r2 = -0.0328158625548689, corr = 0.11407886041713475
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.04,nmse = 1.0047237847155683,r2 = -0.004748589928295299, corr = 0.143263731160397
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.07,nmse = 0.9850525517257862,r2 = 0.014923128716476275, corr = 0.16794546366082755
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.1,nmse = 0.9703539263054524,r2 = 0.029622117025134287, corr = 0.18935024919326518
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.4,nmse = 0.9175761985129748,r2 = 0.0824011478252491, corr = 0.31036579676921816
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 0.7,nmse = 0.9111291025928797,r2 = 0.0888484029150467, corr = 0.3576992144202686
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 1,nmse = 0.9137063371985521,r2 = 0.08627110468108823, corr = 0.3780139051798349
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 1.5,nmse = 0.9219755131038772,r2 = 0.07800172462147659, corr = 0.38739684204307134
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 2,nmse = 0.9301984176202455,r2 = 0.06977861709319699, corr = 0.38436820275832734
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 2.5,nmse = 0.9372845333870894,r2 = 0.06269232638015243, corr = 0.37689734917017603
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 3,nmse = 0.9432322776045646,r2 = 0.05674443532126383, corr = 0.36804256433248217
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 3.5,nmse = 0.9482232613161925,r2 = 0.05175332838928948, corr = 0.3590697684438693
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 4,nmse = 0.9524418555242329,r2 = 0.047534630030109715, corr = 0.350503679869047
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 5,nmse = 0.9591408175679661,r2 = 0.04083550259845481, corr = 0.335235996929932
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 10,nmse = 0.9760142452714968,r2 = 0.023961658313800482, corr = 0.28930939042220066
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 15,nmse = 0.982961040616439,r2 = 0.017014691462282072, corr = 0.2681859764857054
# X_train inside the LRR:(225, 79800)
# fold = 1,alpha = 20,nmse = 0.9867552775514673,r2 = 0.013220360852897017, corr = 0.25645741718778586
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0,nmse = 0.9325767802715083,r2 = -0.07273130834618047, corr = 0.3597414416219975
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 1e-05,nmse = 0.9325727797360273,r2 = -0.07272670658067337, corr = 0.3597416013617074
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.0001,nmse = 0.9325367981086309,r2 = -0.07268531736849226, corr = 0.3597430461816998
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.001,nmse = 0.932179257524616,r2 = -0.07227404294413264, corr = 0.3597581926384484
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.004,nmse = 0.9310163324112825,r2 = -0.0709363448535032, corr = 0.3598173046105293
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.007,nmse = 0.9298954011337659,r2 = -0.06964695174257174, corr = 0.35988833306225276
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.01,nmse = 0.9288136805566624,r2 = -0.06840266220578606, corr = 0.3599696847243537
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.04,nmse = 0.9197452768376846,r2 = -0.05797139178187716, corr = 0.3611067702439807
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.07,nmse = 0.913080149712235,r2 = -0.05030458011249883, corr = 0.3623979154826293
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.1,nmse = 0.9081484248167446,r2 = -0.0446316791659378, corr = 0.36357422546748586
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.4,nmse = 0.8983525602766013,r2 = -0.03336361973444446, corr = 0.36704868462931955
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 0.7,nmse = 0.9066540131789921,r2 = -0.04291267630709861, corr = 0.36479230055652156
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 1,nmse = 0.916144332415805,r2 = -0.05382927082981914, corr = 0.3617478428895073
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 1.5,nmse = 0.9296222504276034,r2 = -0.06933274993034932, corr = 0.35704755024111196
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 2,nmse = 0.940041173543301,r2 = -0.0813175057830604, corr = 0.35316718819397125
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 2.5,nmse = 0.9481905598555429,r2 = -0.09069164207498503, corr = 0.3499884417314015
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 3,nmse = 0.9547199646268242,r2 = -0.09820233403214407, corr = 0.3473521567327251
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 3.5,nmse = 0.9600716412345393,r2 = -0.1043583001366919, corr = 0.3451341304825766
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 4,nmse = 0.9645440950509138,r2 = -0.10950290735344104, corr = 0.3432432496811691
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 5,nmse = 0.9716146111876323,r2 = -0.11763603288956737, corr = 0.3401922030627957
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 10,nmse = 0.9897596485441237,r2 = -0.13850804050887833, corr = 0.3321489825194709
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 15,nmse = 0.997496718048734,r2 = -0.14740789397727538, corr = 0.3287273381569471
# X_train inside the LRR:(225, 79800)
# fold = 2,alpha = 20,nmse = 1.0017155406935414,r2 = -0.15226075245626003, corr = 0.326897462452136
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0,nmse = 0.806204333325553,r2 = 0.0757295075931701, corr = 0.48199841645874597
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 1e-05,nmse = 0.8061901206578729,r2 = 0.07574580166256673, corr = 0.4819989070736623
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.0001,nmse = 0.8060623535572046,r2 = 0.07589227986439051, corr = 0.48200331077583214
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.001,nmse = 0.8047990821920219,r2 = 0.07734055345766755, corr = 0.4820461870341337
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.004,nmse = 0.8007699959400882,r2 = 0.08195968706944456, corr = 0.482174402943601
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.007,nmse = 0.7970025612972643,r2 = 0.08627885099414034, corr = 0.4822813443481861
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.01,nmse = 0.7934753344637542,r2 = 0.09032262941045244, corr = 0.48236863279439235
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.04,nmse = 0.7680075808867257,r2 = 0.11952005761334772, corr = 0.4824297408727731
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.07,nmse = 0.7537112947175281,r2 = 0.13590999117111935, corr = 0.48157474785904975
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.1,nmse = 0.7454725425832696,r2 = 0.14535528335968662, corr = 0.480265871743613
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.4,nmse = 0.7485916015450169,r2 = 0.14177944775169793, corr = 0.4654678080528746
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 0.7,nmse = 0.7743857091233394,r2 = 0.11220787200207494, corr = 0.45595258967968966
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 1,nmse = 0.7978898018086076,r2 = 0.08526167682327035, corr = 0.44984589066582215
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 1.5,nmse = 0.8291502902557265,r2 = 0.04942318544390256, corr = 0.44325901573772497
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 2,nmse = 0.8527226219534302,r2 = 0.022398757857979734, corr = 0.4387803852747225
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 2.5,nmse = 0.8709921089097055,r2 = 0.0014537604087064837, corr = 0.43532135251258064
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 3,nmse = 0.8855458529648199,r2 = -0.015231334955016385, corr = 0.4324474336195919
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 3.5,nmse = 0.8974135441160114,r2 = -0.028837013181524318, corr = 0.42995907334459127
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 4,nmse = 0.9072806155904659,r2 = -0.04014908709793308, corr = 0.42775250606832055
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 5,nmse = 0.9227597652890634,r2 = -0.05789511093155153, corr = 0.42396418405420333
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 10,nmse = 0.9615113560193032,r2 = -0.10232175361411278, corr = 0.412012517763412
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 15,nmse = 0.9775323808101243,r2 = -0.12068900849004782, corr = 0.4056670723747213
# X_train inside the LRR:(225, 79800)
# fold = 3,alpha = 20,nmse = 0.9862148023711403,r2 = -0.1306429441360919, corr = 0.40173835916414147
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0,nmse = 0.9061633521877389,r2 = 0.09373827151002967, corr = 0.4316265259633002
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 1e-05,nmse = 0.9061404491753889,r2 = 0.09376117700881159, corr = 0.4316357654187563
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.0001,nmse = 0.9059345520712047,r2 = 0.09396709646591495, corr = 0.4317188550556335
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.001,nmse = 0.9038981125162752,r2 = 0.09600375710393338, corr = 0.43254332158630676
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.004,nmse = 0.8973938303906307,r2 = 0.10250874535747723, corr = 0.4352096975474968
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.007,nmse = 0.891296489372816,r2 = 0.10860674832422357, corr = 0.43775667801419055
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.01,nmse = 0.8855709915602135,r2 = 0.1143328677171428, corr = 0.4401921525846671
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.04,nmse = 0.8432933600504523,r2 = 0.1566150890362853, corr = 0.4597437910331096
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.07,nmse = 0.8178185012329767,r2 = 0.18209271349464007, corr = 0.47337405104289043
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.1,nmse = 0.8013531182860293,r2 = 0.19855988398186397, corr = 0.4834507869608787
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.4,nmse = 0.7676305152008057,r2 = 0.2322861481122901, corr = 0.523196306499729
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 0.7,nmse = 0.7769745288053368,r2 = 0.2229411200885547, corr = 0.5367987060013666
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 1,nmse = 0.7900028930595278,r2 = 0.20991134142900747, corr = 0.5447833149552108
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 1.5,nmse = 0.8103001097263828,r2 = 0.18961192122443882, corr = 0.5532735957517372
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 2,nmse = 0.8273372081281314,r2 = 0.1725729732149589, corr = 0.5588159659197957
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 2.5,nmse = 0.8415288430143166,r2 = 0.1583797976346385, corr = 0.5627459375465105
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 3,nmse = 0.8534809528661498,r2 = 0.14642639021943737, corr = 0.5656686044948049
# X_train inside the LRR:(225, 79800)
# fold = 4,alpha = 3.5,nmse = 0.8636802143022964,r2 = 0.13622602151535368, corr = 0.5679150467671908
# X_train inside the LRR:(225, 79800)
# ...
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0,nmse = 0.5817143943138042,r2 = 0.41594942501044707, corr = 0.6497847461076622
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 1e-05,nmse = 0.5817082150183236,r2 = 0.4159556291221448, corr = 0.6497866517909935
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.0001,nmse = 0.581652713142189,r2 = 0.41601135389530886, corr = 0.6498037772741746
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.001,nmse = 0.5811086426221381,r2 = 0.41655760941722253, corr = 0.6499725107489721
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.004,nmse = 0.5794328961749692,r2 = 0.41824008570725857, corr = 0.6505028486098721
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.007,nmse = 0.5779544734664372,r2 = 0.4197244458012086, corr = 0.6509863291294438
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.01,nmse = 0.5766560162344573,r2 = 0.42102811767240556, corr = 0.6514260432507369
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.04,nmse = 0.5708514623080969,r2 = 0.4268559828436769, corr = 0.6539462166819376
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.07,nmse = 0.5728696022722649,r2 = 0.4248297379750552, corr = 0.6541944402954365
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.1,nmse = 0.5787419637066777,r2 = 0.4189337929789526, corr = 0.6531412395228952
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.4,nmse = 0.6665398752489637,r2 = 0.33078328265912027, corr = 0.6248167469952008
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 0.7,nmse = 0.731332734393814,r2 = 0.2657302136467813, corr = 0.5949151960539412
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 1,nmse = 0.7755895348654516,r2 = 0.2212956766724148, corr = 0.5688720604617358
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 1.5,nmse = 0.823969469165624,r2 = 0.17272144725300376, corr = 0.5332336643659096
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 2,nmse = 0.8551128710126892,r2 = 0.14145297266528878, corr = 0.5050347982136537
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 2.5,nmse = 0.8768265570231688,r2 = 0.11965208390694393, corr = 0.48224462083514474
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 3,nmse = 0.8928317216027851,r2 = 0.1035826421552849, corr = 0.46346884536629857
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 3.5,nmse = 0.9051200949238584,r2 = 0.09124491839597326, corr = 0.447744309418011
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 4,nmse = 0.9148532950002821,r2 = 0.08147262952588352, corr = 0.43438954031484084
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 5,nmse = 0.9292971780686798,r2 = 0.06697073943404463, corr = 0.41293996037492947
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 10,nmse = 0.9615016217020451,r2 = 0.034636961887636986, corr = 0.3568355901216798
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 15,nmse = 0.9734094518829899,r2 = 0.022681309539954064, corr = 0.33271639161888383
# X_train inside the LRR:(225, 79800)
# fold = 5,alpha = 20,nmse = 0.9796324991372213,r2 = 0.01643327036033515, corr = 0.3193154293905978
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0,nmse = 0.7330571837784513,r2 = 0.18056577725546363, corr = 0.5453004558547814
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 1e-05,nmse = 0.7330578958425602,r2 = 0.18056498128795617, corr = 0.5452946093373319
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.0001,nmse = 0.7330643280526593,r2 = 0.18055779116254733, corr = 0.545242016025276
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.001,nmse = 0.7331309462758867,r2 = 0.1804833232312878, corr = 0.5447185821717806
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.004,nmse = 0.7333810146202401,r2 = 0.1802037890231487, corr = 0.5430060959126808
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.007,nmse = 0.7336690478065123,r2 = 0.1798818165285868, corr = 0.5413418701565148
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.01,nmse = 0.7339892947725414,r2 = 0.17952383446456588, corr = 0.5397240306586073
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.04,nmse = 0.7382015099010608,r2 = 0.17481528879275343, corr = 0.5257089543950493
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.07,nmse = 0.7431241130426807,r2 = 0.16931264920542732, corr = 0.5146339372159232
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.1,nmse = 0.7481710153351353,r2 = 0.1636710641438518, corr = 0.5055247499604028
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.4,nmse = 0.7923805957294199,r2 = 0.11425221395057483, corr = 0.45629486883006726
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 0.7,nmse = 0.8242288403242758,r2 = 0.07865125111593341, corr = 0.43268327283579466
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 1,nmse = 0.8477601245650678,r2 = 0.052347246409716774, corr = 0.41775150715063586
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 1.5,nmse = 0.8758497778568658,r2 = 0.020947754362334647, corr = 0.40148242866295947
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 2,nmse = 0.8956063596364443,r2 = -0.0011367700006799097, corr = 0.39052565196606137
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 2.5,nmse = 0.9103332546637692,r2 = -0.017598953370815407, corr = 0.38236812628724637
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 3,nmse = 0.9217686212797365,r2 = -0.030381763446360788, corr = 0.3759183008467022
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 3.5,nmse = 0.93092200122292,r2 = -0.0406136975235456, corr = 0.3706158844341128
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 4,nmse = 0.9384233726293847,r2 = -0.048998964845108794, corr = 0.3661377680885457
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 5,nmse = 0.9500004929853877,r2 = -0.06194023168004148, corr = 0.3589093275742588
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 10,nmse = 0.977940454887831,r2 = -0.09317239401563371, corr = 0.33891278436476213
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 15,nmse = 0.9889776099846221,r2 = -0.10551007081382391, corr = 0.32924883049781584
# X_train inside the LRR:(225, 79800)
# fold = 6,alpha = 20,nmse = 0.9947823166003459,r2 = -0.11199875322383535, corr = 0.3233148101422386
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0,nmse = 0.9802075996767234,r2 = 0.018573266675359856, corr = 0.3125726421096712
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 1e-05,nmse = 0.9801988005503814,r2 = 0.01858207674561929, corr = 0.312572899281205
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.0001,nmse = 0.9801196857540976,r2 = 0.01866128994096694, corr = 0.31257520200220146
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.001,nmse = 0.9793361127550023,r2 = 0.01944583750933626, corr = 0.3125970788843302
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.004,nmse = 0.9768195819724548,r2 = 0.021965498228189495, corr = 0.3126558916726943
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.007,nmse = 0.9744397394739375,r2 = 0.024348300656896416, corr = 0.3126953909818452
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.01,nmse = 0.9721848480792118,r2 = 0.026605996573820012, corr = 0.31271828866766926
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.04,nmse = 0.9547246165243599,r2 = 0.044087944299609494, corr = 0.31240250281661136
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.07,nmse = 0.9431954863305527,r2 = 0.055631413854338674, corr = 0.311655622101868
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.1,nmse = 0.9351205271725218,r2 = 0.06371641624649527, corr = 0.3107735188312012
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.4,nmse = 0.9154191376139329,r2 = 0.08344230941730824, corr = 0.3007415871107658
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 0.7,nmse = 0.9206000810886175,r2 = 0.07825492214182073, corr = 0.29088358195431224
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 1,nmse = 0.9280843985234631,r2 = 0.0707612960837617, corr = 0.28218867785264407
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 1.5,nmse = 0.9390539154835471,r2 = 0.05977813578196911, corr = 0.2703545409870118
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 2,nmse = 0.9474699021632926,r2 = 0.05135168171496318, corr = 0.261163424981538
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 2.5,nmse = 0.9539298401919717,r2 = 0.04488370913542283, corr = 0.2538844328851742
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 3,nmse = 0.95900046147382,r2 = 0.039806781266048974, corr = 0.24799533673346516
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 3.5,nmse = 0.9630743130200572,r2 = 0.0357278628650981, corr = 0.24313825204715397
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 4,nmse = 0.9664155597367234,r2 = 0.032382460471308105, corr = 0.23906533061851493
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 5,nmse = 0.9715683231759846,r2 = 0.027223288280175728, corr = 0.2326186739959313
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 10,nmse = 0.9839811488838699,r2 = 0.014795024114670707, corr = 0.21624398809523196
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 15,nmse = 0.9889372560358494,r2 = 0.00983275280216711, corr = 0.2094197586302509
# X_train inside the LRR:(225, 79800)
# fold = 7,alpha = 20,nmse = 0.9916113245569493,r2 = 0.0071553584071278875, corr = 0.20572257021565132
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0,nmse = 0.5510035175485702,r2 = 0.42761962817833754, corr = 0.6747415474298578
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 1e-05,nmse = 0.5509978677186507,r2 = 0.4276254972003074, corr = 0.6747505176375251
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.0001,nmse = 0.5509471226474758,r2 = 0.42767821098848136, corr = 0.6748311575295941
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.001,nmse = 0.5504497981313183,r2 = 0.4281948298165077, corr = 0.6756285379908873
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.004,nmse = 0.548919480303977,r2 = 0.4297845181925747, corr = 0.678172445709959
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.007,nmse = 0.5475714869797661,r2 = 0.4311848085637825, corr = 0.6805518673998614
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.01,nmse = 0.5463896127184275,r2 = 0.43241253508023225, corr = 0.6827798026223316
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.04,nmse = 0.5411700519154699,r2 = 0.4378345951179512, corr = 0.6988033930664937
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.07,nmse = 0.5430856940102365,r2 = 0.43584463334899903, corr = 0.707552204284775
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.1,nmse = 0.5484825539463805,r2 = 0.4302383956417287, corr = 0.7122388066352492
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.4,nmse = 0.6290566312431527,r2 = 0.3465383486302346, corr = 0.7002993218157649
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 0.7,nmse = 0.6902839991829631,r2 = 0.28293559018874914, corr = 0.6750141056807031
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 1,nmse = 0.7336520901835317,r2 = 0.2378849811426592, corr = 0.653677130491825
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 1.5,nmse = 0.7831846730132157,r2 = 0.18643072127971227, corr = 0.6266614432670092
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 2,nmse = 0.8166944363335991,r2 = 0.1516209057737956, corr = 0.6069969568530407
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 2.5,nmse = 0.841061832705379,r2 = 0.12630814650565592, corr = 0.5920532919412197
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 3,nmse = 0.8596784753252101,r2 = 0.10696924850330192, corr = 0.580287100964849
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 3.5,nmse = 0.8744188950056264,r2 = 0.09165695624240877, corr = 0.5707615400797598
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 4,nmse = 0.88640989043366,r2 = 0.07920075550498784, corr = 0.5628783454836975
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 5,nmse = 0.9047935211884872,r2 = 0.060103909347463236, corr = 0.5505612369640106
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 10,nmse = 0.9489229367291975,r2 = 0.014262439246071401, corr = 0.519888624255739
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 15,nmse = 0.9665408825153807,r2 = -0.004039016259501871, corr = 0.5072597990625252
# X_train inside the LRR:(225, 79800)
# fold = 8,alpha = 20,nmse = 0.9760067699061543,r2 = -0.013872144310041579, corr = 0.5004243507476862
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0,nmse = 0.6476393567089712,r2 = 0.2898773665122759, corr = 0.6425845446598778
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 1e-05,nmse = 0.6476396003484258,r2 = 0.2898770993668509, corr = 0.6425877758533579
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.0001,nmse = 0.6476418501530992,r2 = 0.2898746325043867, corr = 0.6426168262488695
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.001,nmse = 0.6476699117459666,r2 = 0.28984386357099756, corr = 0.6429043631962408
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.004,nmse = 0.6478323042996121,r2 = 0.289665803626587, corr = 0.6438257187529535
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.007,nmse = 0.6480903735571565,r2 = 0.28938283623294225, corr = 0.6446945535596218
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.01,nmse = 0.6484322743722849,r2 = 0.2890079493383838, corr = 0.645516168008964
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.04,nmse = 0.6547403440878495,r2 = 0.28209128648854753, corr = 0.6519236198633014
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.07,nmse = 0.6633776705361331,r2 = 0.2726206436991463, corr = 0.6564392952580154
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.1,nmse = 0.6725156980088022,r2 = 0.2626009929991794, corr = 0.6600092074949746
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.4,nmse = 0.7444036702347276,r2 = 0.1837773767004771, corr = 0.680354794996264
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 0.7,nmse = 0.7878507961856288,r2 = 0.13613853700038914, corr = 0.6906022823712008
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 1,nmse = 0.8175333412375074,r2 = 0.10359226438352864, corr = 0.6959939573391453
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 1.5,nmse = 0.8513615486057904,r2 = 0.06650036214861155, corr = 0.6991209835721299
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 2,nmse = 0.8744993988519698,r2 = 0.0411302067066146, corr = 0.6984836300241708
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 2.5,nmse = 0.8915360874262873,r2 = 0.022449843892065946, corr = 0.6961013361173404
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 3,nmse = 0.9046928575477639,r2 = 0.008023728261396634, corr = 0.6929382343472714
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 3.5,nmse = 0.9152019294785931,r2 = -0.0034992432160543263, corr = 0.6894778334892336
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 4,nmse = 0.9238113865520707,r2 = -0.012939327835038927, corr = 0.6859687101173694
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 5,nmse = 0.9371141145686984,r2 = -0.02752548316034531, corr = 0.67925128046136
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 10,nmse = 0.9694790803555386,r2 = -0.06301297245389503, corr = 0.6553924859419199
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 15,nmse = 0.982471825319506,r2 = -0.07725923802511003, corr = 0.6421872430310219
# X_train inside the LRR:(225, 79800)
# fold = 9,alpha = 20,nmse = 0.9894017393134688,r2 = -0.08485773975953692, corr = 0.6339279531629788
# The best alpha value is 0.04
# The best alpha value is 0.04
# average performance metrics: [0.70167699 0.2742365  0.55608847]
# The best alpha value is 0.04
# average performance metrics: [0.70167699 0.2742365  0.55608847]
# X_train inside the LRR:(250, 79800)
# Time to run one experiment: 2.568690299987793
# Test Results: Seed:9 Best_Lambda:0.04 NMSE:0.5967170851186047 CORR:0.28205159509288596 R2:-0.015251722894092046

# %% [markdown]
# ### Importing the Libraries

# %%
# Needed to import data
import sys
import pandas as pd
import re
import dill
import os 

#os search
import platform

# Time 
import time

# bases
import numpy as np
import scipy

#pre-processing 
from sklearn.preprocessing import StandardScaler

#k-Fold cross 
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score

#Ridge 
from sklearn.linear_model import Ridge

#plotting 
import matplotlib.pyplot as plt

#reproducability 
import random
random.seed(42)
np.random.seed(42)

# %% [markdown]
# ### Setting up paths

# %%
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP')
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Vector Regression Baseline/Experimental Results/Vector_Base_Line/with k-fold cv kernel mapping before centering')

# %% [markdown]
# ### Functions Needed

# %%
#Row Wise Normalization of Samples
def normalize_rows(matrix: np.ndarray):
    """
    Normalize each row of the given matrix by the norm of the row.
    
    Parameters:
    matrix (numpy.ndarray): The input matrix to be normalized.
    
    Returns:
    numpy.ndarray: The row-normalized matrix.
    """
    # Calculate the L2 norm for each row. Adding a small epsilon to avoid division by zero.
    row_norms = np.linalg.norm(matrix, axis=1, keepdims=True)
    epsilon = 1e-10  # Small value to prevent division by zero
    row_norms[row_norms == 0] = epsilon
    
    # Normalize each row by its norm
    normalized_matrix = matrix / row_norms
    return normalized_matrix


def LRR(X_train,Y_train,X_validatioon,Y_validation,alpha,Y_train_mean = None):
    print(f'X_train inside the LRR:{X_train.shape}')
    #model 
    ridge_regression = Ridge(alpha=alpha,fit_intercept=False)
    #fitting model
    ridge_regression.fit(X_train,Y_train)
    #testing 
    
    if Y_train_mean is not None:
        Y_predicted = ridge_regression.predict(X_validatioon).flatten().reshape(-1,1) + Y_train_mean
    else:
        Y_predicted = ridge_regression.predict(X_validatioon).flatten().reshape(-1,1) 

    #error matrices 

    #nmse
    nmse    = (np.linalg.norm(Y_validation - Y_predicted)**2/(np.linalg.norm(Y_validation)**2))
    #r2
    numerator = np.sum((Y_validation - Y_predicted)**2)
    denominator = np.sum((Y_validation - np.mean(Y_validation))**2)
    r2 = 1 - (numerator / denominator)
    #correlation
    corr    = np.corrcoef(Y_validation.flatten(), Y_predicted.flatten())[0,1]
    
    return nmse,r2,corr

# %% [markdown]
# ### Hyper Parameteres

# %%
#number of splits for K-Fild Cross Validation
n_splits = 10
# Ridge Regression coefficient grid
#the regularization coefficients to search over
alphas = [0,0.00001,0.0001, 0.001, 0.004, 0.007, 0.01, 0.04, 0.07, 0.1, 0.4, 0.7, 1, 1.5, 2, 2.5, 3,3.5, 4, 5, 10, 15, 20]
#[0.07,0.08,0.09,0.1,0.12,0.14,0.16,0.18,2.0,2.5,3.0,3.5,4.0]

#number of seeds
number_of_seeds = 30
n_samples = 550

# %% [markdown]
# ### Importing Data

# %% [markdown]
# #### 1. Data Loading

# %%
#Load fMRI Resting State Data
with open("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/fmri_rs.npy", "rb") as f:
  fmri_rs = np.load(f)

#Loading Structural FMRI data 
fMRI_language  = (scipy.io.loadmat("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/features_lang.mat")['features_lang'])

#Take the Transpose so that each Sample is a Row
fmri_rs = fmri_rs.T
fMRI_language = fMRI_language.T

#iterating over seeds



columns = ['Seed','Best_lambda','NMSE','CORR','R2','Time_Taken']
results_df = pd.DataFrame(columns = columns)


for seed in range(number_of_seeds):

    print('')
    print(f'=====================================Seed:{seed}===========================================')

    #Get Split to divide into train + test(loaded data is in the form of features * sampels so need to transpose)
    mat_file = scipy.io.loadmat("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/MMP_HCP_60_splits.mat")
    seed_1 = mat_file['folds'][f'seed_{seed+1}']
    subject_lists = seed_1[0, 0]['sub_fold'][0, 0]['subject_list']
    test_subjects = [int(item[0]) for item in subject_lists[0,0].flatten()]

    #Get HCP test subjects
    HCP_753_Subjects = []
    with open('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/MMP_HCP_753_subs.txt', 'r') as file:
        HCP_753_Subjects = [int(re.sub('\n', '', line)) for line in file.readlines()]

    #Put the HCP test subjects into a dataframe
    df = pd.read_csv("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/HCP/Resting State FMRI/MMP_HCP_componentscores.csv")
    df['Subject'] = pd.to_numeric(df['Subject'], errors='coerce')
    df = df[df['Subject'].isin(HCP_753_Subjects)].reset_index(drop = True)

    #Split all our data into a Train and Test Set
    df_train, df_test = df[~df['Subject'].isin(test_subjects)], df[df['Subject'].isin(test_subjects)]

    #Create Train and Test Arrays corresponding to Training and Test Subjects
    train_subjects = df_train.index.to_list()
    test_subjects = df_test.index.to_list()

    #Reshape Labels into Column Vectors

    # Assuming fmri_rs and dMRI_streamlog are numpy arrays or can be converted to numpy arrays
    X_train_fmri = fmri_rs[train_subjects]
    Y_train_fmri = df_train["varimax_cog"].to_numpy().reshape((-1, 1))
    X_test_fmri = fmri_rs[test_subjects]
    Y_test_fmri = df_test["varimax_cog"].to_numpy().reshape((-1, 1))

    X_train_fmri_language  = fMRI_language[train_subjects]
    X_test_fmri_language   = fMRI_language[test_subjects]

    #concatanating the vectors from different feature sets

    # Check if number of samples match
    assert X_train_fmri.shape[0] == X_train_fmri_language.shape[0], "Number of training samples do not match"
    assert X_test_fmri.shape[0] == X_test_fmri_language.shape[0], "Number of testing samples do not match"

    # Concatenate along the features axis (axis=1)
    X_train_combined = np.concatenate((X_train_fmri, X_train_fmri_language), axis=1)
    X_test_combined = np.concatenate((X_test_fmri, X_test_fmri_language), axis=1)

    # The target variables remain the same
    Y_train_combined = Y_train_fmri
    Y_test_combined = Y_test_fmri


    X_train = X_train_combined[:n_samples]
    X_test = X_test_combined
    Y_train = Y_train_combined[:n_samples]
    Y_test = Y_test_combined

        # Verify the shapes
    print("X_train_combined shape:", X_train.shape)
    print("X_test_combined shape:", X_test.shape)
    print("Y_train_combined shape:", Y_train.shape)
    print("Y_test_combined shape:", Y_test.shape)

    #Preprocess Data

    #Projecting in to the kernel space
    X_train = normalize_rows(X_train)
    X_test = normalize_rows(X_test)

    #intercept removal step

    #number of samples in train and test
    n_train = X_train.shape[0]
    n_test = X_test.shape[0]



    # Initialize StandardScaler
    scaler = StandardScaler(with_std = False) #standard scalar only

    # Fit scaler on train data and transform train data
    X_train_scaled = scaler.fit_transform(X_train)

    # Transform test data using the scaler fitted on train data
    X_test_scaled = scaler.transform(X_test)


    #average response value
    Y_train_mean = np.mean(Y_train)

    # Mean centering y_train and y_test
    Y_train = Y_train - Y_train_mean

    #printing the outcomes
    print("Sample mean for each feature (across samples):",scaler.mean_)
    print("Sample variance for each feature (across samples):",scaler.var_)
    print('Response Average:',Y_train_mean)


    # Number of folds we are using 

    kfold = KFold(n_splits=n_splits, shuffle=True, random_state=42)



    k_fold_results = np.ones(shape=[n_splits,len(alphas),3])*np.inf

    #iterating over the folds
    for fold,(train_ids,validation_ids) in enumerate(kfold.split(X_train)):

        #the training and validatiion data 
        X_train_fold,Y_train_fold = X_train[train_ids],Y_train[train_ids]
        X_validation_fold,Y_validation_fold = X_train[validation_ids],Y_train[validation_ids]
        
        #iterating over the alpha values 
        for alpha_idx,alpha in enumerate(alphas):
            nmse,r2,corr = LRR(X_train_fold,Y_train_fold,X_validation_fold,Y_validation_fold,alpha)
            k_fold_results[fold,alpha_idx,0] = nmse
            k_fold_results[fold,alpha_idx,1] = r2
            k_fold_results[fold,alpha_idx,2] = corr

            print(f"fold = {fold},alpha = {alpha},nmse = {nmse},r2 = {r2}, corr = {corr}")

    #Choosing the best lambda

    #array to hold all the sums
    nmse_sum = np.zeros(len(alphas))

    # Iterate over the folds and alpha values to accumulate nmse values
    for alpha_idx in range(len(alphas)):
        for fold in range(n_splits):
            nmse_sum[alpha_idx] += k_fold_results[fold, alpha_idx, 0]

    #best lambda 

    best_alpha_idx = np.argmin(nmse_sum)
    best_alpha = alphas[best_alpha_idx]        
    print(f"The best alpha value is {best_alpha}")
    average_results = np.mean(k_fold_results, axis=0)
    print(f"The best alpha value is {best_alpha}")
    print(f'average performance metrics: {average_results[best_alpha_idx]}')

    #Choosing the best lambda

    # Iterate over the folds and alpha values to accumulate nmse values
    for alpha_idx in range(len(alphas)):
        for fold in range(n_splits):
            nmse_sum[alpha_idx] += k_fold_results[fold, alpha_idx, 0]

    best_alpha_idx = np.argmin(nmse_sum)
    best_alpha = alphas[best_alpha_idx]        
    average_results = np.mean(k_fold_results, axis=0)
    
    print(f"The best alpha value is {best_alpha}")
    print(f'average performance metrics: {average_results[best_alpha_idx]}')

    #Testing 
    start_time = time.time()
    nmse_best,r2_best,corr_best =  LRR(X_train,Y_train,X_test,Y_test,best_alpha,Y_train_mean=Y_train_mean)
    end_time = time.time()
    elapsed_time = end_time - start_time 
    
    print(f'Time to run one experiment: {elapsed_time}')
    print(f'Test Results: Seed:{seed} Best_Lambda:{best_alpha} NMSE:{nmse_best} CORR:{corr_best} R2:{r2_best}')

    #loading results 
    columns = ['Seed','Best_lambda','NMSE','CORR','R2','Time_Taken']
    
    seed_result_df = pd.DataFrame([{
        'Seed' : seed,
        'Best_lambda' : best_alpha,
        'NMSE' : nmse_best,
        'CORR' : corr_best,
        'R2' :  r2_best,
        'Time_Taken' : elapsed_time 
    }])

    # concatenating results 
    results_df = pd.concat([results_df,seed_result_df],ignore_index = True)

    #saving the results 

    if platform.system() == 'Windows':
        file_path = rf'Enter file path'
    elif platform.system() == 'Darwin':
        file_path = '/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression_All_Data/Vector Regression Baseline/Experimental Results/Vector_Base_Line/with concat k-fold cv kernel map centering fmri/Iterating over seeds_550_samples'

    results_df.to_csv(f'{file_path}/results_{seed}.csv',index = False)
# Out:
# =====================================Seed:0===========================================
# X_train_combined shape: (550, 159600)
# X_test_combined shape: (76, 159600)
# Y_train_combined shape: (550, 1)
# Y_test_combined shape: (76, 1)
# Sample mean for each feature (across samples): [0.00544843 0.00588438 0.00332152 ... 0.00192157 0.00090728 0.00326901]
# Sample variance for each feature (across samples): None
# Response Average: 1.1069732851651208
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0,nmse = 0.4760259114257704,r2 = 0.5239500351502048, corr = 0.7411585401563535
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 1e-05,nmse = 0.47602568517402377,r2 = 0.5239502614133837, corr = 0.741159442763182
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.0001,nmse = 0.4760236562364787,r2 = 0.5239522904534504, corr = 0.7411675607674307
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.001,nmse = 0.47600408900019525,r2 = 0.5239718586784594, corr = 0.7412482026421103
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.004,nmse = 0.47594817512994897,r2 = 0.524027775374014, corr = 0.7415100503604565
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.007,nmse = 0.475906140095155,r2 = 0.5240698125328238, corr = 0.7417614738897377
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.01,nmse = 0.4758774284194947,r2 = 0.524098525659275, corr = 0.7420028277187217
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.04,nmse = 0.47621841035626433,r2 = 0.5237575264928065, corr = 0.7439311622446055
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.07,nmse = 0.4774393554913712,r2 = 0.5225365196637659, corr = 0.7451548604352826
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.1,nmse = 0.4792674839127345,r2 = 0.5207082988677083, corr = 0.7458651281813271
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.4,nmse = 0.5079675747558232,r2 = 0.4920067578189943, corr = 0.7419731378824941
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.7,nmse = 0.5365785605963537,r2 = 0.463394326275283, corr = 0.7340803786473529
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 1,nmse = 0.5611035774043398,r2 = 0.4388680702267127, corr = 0.7268909627385743
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 1.5,nmse = 0.5946213339409403,r2 = 0.40534862004951233, corr = 0.7172671120516386
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 2,nmse = 0.6216801714885363,r2 = 0.37828841522824985, corr = 0.7099632652964507
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 2.5,nmse = 0.6443152735889328,r2 = 0.35565216938400335, corr = 0.7042712105866585
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 3,nmse = 0.6637447668217984,r2 = 0.3362216943855907, corr = 0.6997144920577266
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 3.5,nmse = 0.680738600017334,r2 = 0.3192270024975643, corr = 0.6959827282349135
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 4,nmse = 0.695812363428194,r2 = 0.3041524774146728, corr = 0.6928686223797069
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 5,nmse = 0.7215536371414958,r2 = 0.27840990300374757, corr = 0.6879627083236644
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 10,nmse = 0.8020698049128634,r2 = 0.19788966677837838, corr = 0.6756129578718497
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 15,nmse = 0.8456201091467866,r2 = 0.15433716196270308, corr = 0.6705489243701188
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 20,nmse = 0.8732304469829658,r2 = 0.12672542898573957, corr = 0.6678653089073006
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0,nmse = 0.535604771002837,r2 = 0.4639657962988656, corr = 0.681311167193259
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 1e-05,nmse = 0.5356014860478118,r2 = 0.4639690838876743, corr = 0.6813136239798905
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.0001,nmse = 0.5355719474670595,r2 = 0.4639986461516221, corr = 0.6813357228490857
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.001,nmse = 0.5352791222629598,r2 = 0.4642917061346562, corr = 0.6815555082061883
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.004,nmse = 0.534335902931403,r2 = 0.4652356817126928, corr = 0.6822726074806009
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.007,nmse = 0.533441302676348,r2 = 0.46613099923283274, corr = 0.682966559437872
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.01,nmse = 0.5325929250125575,r2 = 0.4669800571017465, corr = 0.6836382692532509
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.04,nmse = 0.5262195774284423,r2 = 0.4733585146550001, corr = 0.6893000398217551
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.07,nmse = 0.5226754087285588,r2 = 0.47690552496871974, corr = 0.6934538588160577
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.1,nmse = 0.520999273701729,r2 = 0.47858300387302455, corr = 0.6965170147041313
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.4,nmse = 0.5380530085189824,r2 = 0.4615155958553909, corr = 0.7022789161525256
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.7,nmse = 0.5647383301690393,r2 = 0.4348088786720945, corr = 0.6955918427262727
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 1,nmse = 0.5887084231421859,r2 = 0.41081956715896994, corr = 0.6874521450809006
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 1.5,nmse = 0.6217359605355655,r2 = 0.37776554922383865, corr = 0.6750097900718118
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 2,nmse = 0.6482394198827703,r2 = 0.35124084015542567, corr = 0.664755056399034
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 2.5,nmse = 0.6701952738292827,r2 = 0.32926738262859767, corr = 0.6564022523015762
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 3,nmse = 0.6888672948939111,r2 = 0.3105803908676231, corr = 0.6495380283789978
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 3.5,nmse = 0.7050691873586215,r2 = 0.2943655081855443, corr = 0.6438249227850756
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 4,nmse = 0.7193466357962777,r2 = 0.28007661249510174, corr = 0.6390092289032342
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 5,nmse = 0.7435493841643652,r2 = 0.25585445905054616, corr = 0.6313634890955914
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 10,nmse = 0.8182776369107025,r2 = 0.18106629131286933, corr = 0.6121073667913532
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 15,nmse = 0.8583946342214073,r2 = 0.1409171293327378, corr = 0.6043828815141333
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 20,nmse = 0.8837954110111214,r2 = 0.11549598692138219, corr = 0.6003928433528876
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0,nmse = 0.7962609920581629,r2 = 0.2005563348613686, corr = 0.45914819784754635
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 1e-05,nmse = 0.7962571396894889,r2 = 0.20056020262804664, corr = 0.45915071241717553
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.0001,nmse = 0.7962224990893509,r2 = 0.2005949816874416, corr = 0.4591733237606909
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.001,nmse = 0.795879112847549,r2 = 0.20093974045176966, corr = 0.4593974914471181
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.004,nmse = 0.7947730590356877,r2 = 0.2020502151855743, corr = 0.4601198195234966
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.007,nmse = 0.793723582997998,r2 = 0.20310388600257268, corr = 0.4608055047337376
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.01,nmse = 0.7927273216292072,r2 = 0.20410412945044465, corr = 0.46145658299799147
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.04,nmse = 0.785108382986973,r2 = 0.21175352116166035, corr = 0.4664222742971605
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.07,nmse = 0.7804655252873213,r2 = 0.21641493646788135, corr = 0.4693857295995223
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.1,nmse = 0.7776591537428961,r2 = 0.21923252514243963, corr = 0.47108238202310554
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.4,nmse = 0.7798721716613203,r2 = 0.2170106617416604, corr = 0.46655780473222885
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.7,nmse = 0.7908471127510246,r2 = 0.2059918535657692, corr = 0.4561477739880418
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 1,nmse = 0.8008741335393776,r2 = 0.19592475454997715, corr = 0.44704943057611857
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 1.5,nmse = 0.8146390245054702,r2 = 0.1821048450053402, corr = 0.4351509250237648
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 2,nmse = 0.8257028116737383,r2 = 0.17099683563111268, corr = 0.42620292775020135
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 2.5,nmse = 0.8349470758877428,r2 = 0.16171562188528865, corr = 0.41922825027762645
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 3,nmse = 0.8429026799912015,r2 = 0.15372821905343348, corr = 0.41362600266304356
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 3.5,nmse = 0.8498962346769775,r2 = 0.14670671097240506, corr = 0.4090181277852087
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 4,nmse = 0.8561399387488956,r2 = 0.14043805067499004, corr = 0.4051556534174876
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 5,nmse = 0.866917671185999,r2 = 0.12961723939911596, corr = 0.39903248946405423
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 10,nmse = 0.9019125185813843,r2 = 0.09448251681221542, corr = 0.38331813211500115
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 15,nmse = 0.9218053719518672,r2 = 0.07451015125973748, corr = 0.37662155424330274
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 20,nmse = 0.9347920957939162,r2 = 0.06147151919062799, corr = 0.37290049156809757
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0,nmse = 0.7374710776432672,r2 = 0.2604577270004922, corr = 0.5342855635515884
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 1e-05,nmse = 0.7374683306341336,r2 = 0.2604604817246302, corr = 0.5342861335346498
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.0001,nmse = 0.7374436206120509,r2 = 0.2604852611450723, corr = 0.5342912621018305
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.001,nmse = 0.7371978059192459,r2 = 0.26073176621105354, corr = 0.5343424211708169
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.004,nmse = 0.7363949251852088,r2 = 0.2615369018441619, corr = 0.5345112972614425
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.007,nmse = 0.7356164671740129,r2 = 0.2623175461629522, corr = 0.5346776513875808
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.01,nmse = 0.7348612503716718,r2 = 0.26307488399970613, corr = 0.5348415146373173
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.04,nmse = 0.7283789853575933,r2 = 0.2695753545239422, corr = 0.5363507748332075
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.07,nmse = 0.7233677215054659,r2 = 0.2746006925638367, corr = 0.5376507295639057
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.1,nmse = 0.7193843595023913,r2 = 0.2785952418814147, corr = 0.538777017588711
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.4,nmse = 0.7036434104463932,r2 = 0.29438039956006423, corr = 0.5448936105983712
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.7,nmse = 0.7031704412558499,r2 = 0.29485469708960366, corr = 0.5468966421227143
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 1,nmse = 0.7072986481895966,r2 = 0.29071489604282674, corr = 0.5472197572732601
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 1.5,nmse = 0.7176089203192695,r2 = 0.2803756674043444, corr = 0.5460908619886655
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 2,nmse = 0.7289992572376481,r2 = 0.268953340603723, corr = 0.5441262167484937
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 2.5,nmse = 0.7402190450776079,r2 = 0.25770204187041856, corr = 0.5419317983557932
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 3,nmse = 0.7508788943135408,r2 = 0.24701225433465956, corr = 0.5397484147914338
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 3.5,nmse = 0.7608716634998047,r2 = 0.23699142034997578, corr = 0.5376720016313707
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 4,nmse = 0.7701930095147522,r2 = 0.2276438952357177, corr = 0.5357366433397766
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 5,nmse = 0.786969948167585,r2 = 0.210819838372445, corr = 0.5323042021240584
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 10,nmse = 0.8447044016461748,r2 = 0.15292323706790656, corr = 0.5213947543346134
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 15,nmse = 0.8783010304512556,r2 = 0.11923225177390606, corr = 0.5156965696279133
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 20,nmse = 0.9002153342757525,r2 = 0.09725640139430658, corr = 0.512136819290799
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0,nmse = 0.36691453369982535,r2 = 0.6329807864685186, corr = 0.7989844064889666
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 1e-05,nmse = 0.3669121631155116,r2 = 0.6329831577291543, corr = 0.7989869707236901
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.0001,nmse = 0.36689086232822665,r2 = 0.6330044645935025, corr = 0.7990100299848591
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.001,nmse = 0.3666812407138908,r2 = 0.6332141460123795, corr = 0.7992387685041764
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.004,nmse = 0.3660256237800474,r2 = 0.633869949992153, corr = 0.7999775052777119
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.007,nmse = 0.36543294894960104,r2 = 0.6344627939112992, corr = 0.8006813211270404
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.01,nmse = 0.3648990872673622,r2 = 0.6349968079029886, corr = 0.8013521461525137
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.04,nmse = 0.3620902757172727,r2 = 0.6378064208002399, corr = 0.8065828668224488
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.07,nmse = 0.36236400032750565,r2 = 0.6375326180970358, corr = 0.809879409694728
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.1,nmse = 0.3644172381407178,r2 = 0.6354787945000269, corr = 0.8119230448422134
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.4,nmse = 0.4079709306537021,r2 = 0.5919126762235978, corr = 0.8088264292036182
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.7,nmse = 0.45024539432685173,r2 = 0.5496261517479064, corr = 0.7967332468101802
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 1,nmse = 0.485356871367313,r2 = 0.5145046574877161, corr = 0.7847402786749214
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 1.5,nmse = 0.5320319977189499,r2 = 0.4678162148350874, corr = 0.7674384635501792
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 2,nmse = 0.5686674154926846,r2 = 0.43117034506500773, corr = 0.7533541452892967
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 2.5,nmse = 0.5985812365735603,r2 = 0.40124798964311437, corr = 0.7417971151629464
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 3,nmse = 0.6237165621899485,r2 = 0.37610549297894114, corr = 0.7321745428812944
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 3.5,nmse = 0.6452909489783331,r2 = 0.35452495107003223, corr = 0.7240474444478723
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 4,nmse = 0.6641132582928936,r2 = 0.33569727179601394, corr = 0.7170952421929319
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 5,nmse = 0.695599254329112,r2 = 0.3042022928810544, corr = 0.7058276243455877
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 10,nmse = 0.7894506717617064,r2 = 0.21032409986538747, corr = 0.6756615707901248
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 15,nmse = 0.8379204212979812,r2 = 0.16184052202645394, corr = 0.6623077719171866
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 20,nmse = 0.8680303810924974,r2 = 0.13172197193301816, corr = 0.6547578861630501
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0,nmse = 0.4843603991763345,r2 = 0.49002228217824284, corr = 0.7380477299230395
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 1e-05,nmse = 0.4843612652119982,r2 = 0.49002137033885207, corr = 0.7380479131396508
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.0001,nmse = 0.4843690725597314,r2 = 0.490013150068603, corr = 0.738049550204153
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.001,nmse = 0.48444842227844576,r2 = 0.4899296036256473, corr = 0.7380647544537614
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.004,nmse = 0.4847290004223008,r2 = 0.48963418599506225, corr = 0.7381006387289577
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.007,nmse = 0.4850326088553498,r2 = 0.4893145200271981, corr = 0.7381150720294091
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.01,nmse = 0.4853571948690788,r2 = 0.48897276699619074, corr = 0.7381096467336199
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.04,nmse = 0.4894190322273477,r2 = 0.4846961032770767, corr = 0.7372329484602901
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.07,nmse = 0.4942829382773365,r2 = 0.47957495028585195, corr = 0.7354312076402905
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.1,nmse = 0.4994213917915087,r2 = 0.47416472930010056, corr = 0.7331771127350368
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.4,nmse = 0.5449879044807199,r2 = 0.4261882510622912, corr = 0.709071147643485
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.7,nmse = 0.5779918750551349,r2 = 0.39143873474919333, corr = 0.6907569886171846
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 1,nmse = 0.6035828578469163,r2 = 0.3644942714463266, corr = 0.6768619041078126
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 1.5,nmse = 0.6367359844990752,r2 = 0.3295877103453885, corr = 0.6596978997463502
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 2,nmse = 0.6627004341453974,r2 = 0.30225002791378086, corr = 0.647160165537262
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 2.5,nmse = 0.6841297015591815,r2 = 0.27968738879452615, corr = 0.6375229906037194
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 3,nmse = 0.7024079118048896,r2 = 0.2604424629855131, corr = 0.6298482454083417
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 3.5,nmse = 0.7183497573990106,r2 = 0.24365746972887625, corr = 0.6235725262739061
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 4,nmse = 0.7324771473417225,r2 = 0.22878289679926878, corr = 0.618333478180759
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 5,nmse = 0.7566127432389529,r2 = 0.20337079429281124, corr = 0.6100576852715371
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 10,nmse = 0.8325349862254051,r2 = 0.12343310269791263, corr = 0.5887457513011373
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 15,nmse = 0.8738975373642246,r2 = 0.0798829291723071, corr = 0.5792813116132827
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 20,nmse = 0.9001457282228464,r2 = 0.052246498750264214, corr = 0.5736396121231967
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0,nmse = 0.5205163565409802,r2 = 0.4790787251494222, corr = 0.6973980229131805
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 1e-05,nmse = 0.5205142786285564,r2 = 0.4790808046782885, corr = 0.6974001110374204
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.0001,nmse = 0.5204955925567485,r2 = 0.47909950528630174, corr = 0.6974188930839302
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.001,nmse = 0.5203102213203795,r2 = 0.47928502072603085, corr = 0.6976056235031747
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.004,nmse = 0.519711397079489,r2 = 0.4798843108022337, corr = 0.6982140543950873
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.007,nmse = 0.5191407072584385,r2 = 0.4804554445723641, corr = 0.6988017347817913
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.01,nmse = 0.518596656956855,r2 = 0.48099991809970355, corr = 0.6993696464849263
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.04,nmse = 0.5143579503902043,r2 = 0.4852419220265164, corr = 0.7041392944135791
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.07,nmse = 0.511709765890499,r2 = 0.48789216659287993, corr = 0.7076718405189543
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.1,nmse = 0.5101076059179269,r2 = 0.48949557291227597, corr = 0.7103646747235717
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.4,nmse = 0.5147297052596722,r2 = 0.4848698779627678, corr = 0.7198433536006379
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.7,nmse = 0.5286793013949821,r2 = 0.4709094302051877, corr = 0.7206073409899091
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 1,nmse = 0.5437095952773635,r2 = 0.45586744400782864, corr = 0.7196201641346972
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 1.5,nmse = 0.5678492593415427,r2 = 0.4317090012984748, corr = 0.7170949031040161
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 2,nmse = 0.5899603406271858,r2 = 0.4095807194358565, corr = 0.7145064227043195
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 2.5,nmse = 0.6100221116597336,r2 = 0.38950334201877923, corr = 0.7121410264108881
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 3,nmse = 0.6282379873098157,r2 = 0.3712732959368107, corr = 0.7100390918489528
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 3.5,nmse = 0.6448311052690835,r2 = 0.3546672699157877, corr = 0.7081824177778167
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 4,nmse = 0.6600029635403332,r2 = 0.33948360920427356, corr = 0.70654018644254
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 5,nmse = 0.6867514328662583,r2 = 0.31271433180027775, corr = 0.7037802328868049
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 10,nmse = 0.7750945023147626,r2 = 0.22430253881235718, corr = 0.6958270928433102
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 15,nmse = 0.8245117642180311,r2 = 0.17484683440117654, corr = 0.6920313917692567
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 20,nmse = 0.8560857966295856,r2 = 0.14324824002596648, corr = 0.689790255337335
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0,nmse = 0.5330930960723318,r2 = 0.41794428903948366, corr = 0.7139927568177672
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 1e-05,nmse = 0.5330931642788426,r2 = 0.417944214568459, corr = 0.7139930547622598
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.0001,nmse = 0.5330937867672348,r2 = 0.4179435349068268, corr = 0.7139957311496711
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.001,nmse = 0.5331008597958429,r2 = 0.41793581224689114, corr = 0.7140219919928918
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.004,nmse = 0.5331352572576078,r2 = 0.41789825550640725, corr = 0.7141030839835747
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.007,nmse = 0.5331854980889518,r2 = 0.41784340024187183, corr = 0.7141746728708454
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.01,nmse = 0.533250599969299,r2 = 0.41777231899634526, corr = 0.7142372632337786
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.04,nmse = 0.5345478344259665,r2 = 0.4163559383875529, corr = 0.7144576251447085
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.07,nmse = 0.5366403430011027,r2 = 0.4140712406952256, corr = 0.7141443230478628
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.1,nmse = 0.5391892567104782,r2 = 0.411288218757372, corr = 0.7134864738764243
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.4,nmse = 0.568963439875531,r2 = 0.37877938778940934, corr = 0.7011329302653546
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.7,nmse = 0.5945457593048838,r2 = 0.3508474276248932, corr = 0.6882710587283914
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 1,nmse = 0.6153499868518524,r2 = 0.32813240928184517, corr = 0.6772445531095774
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 1.5,nmse = 0.6428523006607154,r2 = 0.29810411040681173, corr = 0.6625612548041963
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 2,nmse = 0.6646134013460728,r2 = 0.2743443336923511, corr = 0.6512967324623814
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 2.5,nmse = 0.682696506078698,r2 = 0.25460036315686785, corr = 0.6424110042025368
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 3,nmse = 0.6982281983881237,r2 = 0.23764214277061801, corr = 0.6352256267270325
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 3.5,nmse = 0.71187577136558,r2 = 0.22274109105787743, corr = 0.6292938164567097
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 4,nmse = 0.7240634867762924,r2 = 0.20943397939082975, corr = 0.6243120617034142
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 5,nmse = 0.7451211754579399,r2 = 0.18644222045212766, corr = 0.6164068105013296
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 10,nmse = 0.8136813897041294,r2 = 0.11158500594178122, corr = 0.5961563707141909
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 15,nmse = 0.8526755109496619,r2 = 0.06900941992862186, corr = 0.5875686449561681
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 20,nmse = 0.8780765776673323,r2 = 0.041275359862116834, corr = 0.5828087804096395
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0,nmse = 0.5648739205453502,r2 = 0.4106534855327062, corr = 0.6800947347984978
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 1e-05,nmse = 0.5648707782493205,r2 = 0.41065676396554796, corr = 0.6800965669247544
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.0001,nmse = 0.5648425287991167,r2 = 0.41068623729474174, corr = 0.6801130395488311
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.001,nmse = 0.5645631030138298,r2 = 0.410977768920865, corr = 0.6802761413942937
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.004,nmse = 0.5636708841468047,r2 = 0.41190864227206436, corr = 0.6807990117188983
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.007,nmse = 0.5628361890527374,r2 = 0.41277949969075445, corr = 0.6812912262615608
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.01,nmse = 0.5620556122468776,r2 = 0.4135938942008839, corr = 0.6817544447854984
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.04,nmse = 0.5566317390029768,r2 = 0.4192527512926032, corr = 0.6850880121984224
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.07,nmse = 0.5542165878409048,r2 = 0.4217725364473236, corr = 0.6867390280655589
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.1,nmse = 0.5536284054700722,r2 = 0.42238620122722104, corr = 0.6873357712988418
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.4,nmse = 0.5750745016070882,r2 = 0.40001097456588297, corr = 0.6767126071098688
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.7,nmse = 0.6005234647303253,r2 = 0.373459460736024, corr = 0.6633304519843088
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 1,nmse = 0.6221382412787508,r2 = 0.3509082457542706, corr = 0.652262384916638
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 1.5,nmse = 0.6513442953869508,r2 = 0.32043686875496924, corr = 0.6380775121735954
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 2,nmse = 0.674782551399389,r2 = 0.2959831738972092, corr = 0.6275111669667802
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 2.5,nmse = 0.6943797368255366,r2 = 0.275536960141901, corr = 0.6193146045573565
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 3,nmse = 0.7112363604932948,r2 = 0.2579500402241093, corr = 0.6127556064005287
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 3.5,nmse = 0.7260276824128892,r2 = 0.242517899173482, corr = 0.6073799244299793
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 4,nmse = 0.7391968830433154,r2 = 0.22877815618380848, corr = 0.6028898654205748
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 5,nmse = 0.7618143630413071,r2 = 0.20518079663500643, corr = 0.5958096217521593
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 10,nmse = 0.8337921341828146,r2 = 0.13008466102226968, corr = 0.5780021484247613
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 15,nmse = 0.8734839066136706,r2 = 0.08867328251045892, corr = 0.5707498414520805
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 20,nmse = 0.8988464741929462,r2 = 0.062211907224525076, corr = 0.5669308494308755
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0,nmse = 0.5593243893258255,r2 = 0.41804513243171726, corr = 0.6588220761168035
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 1e-05,nmse = 0.5593269201562491,r2 = 0.4180424992029289, corr = 0.6588204798772158
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.0001,nmse = 0.559349700822144,r2 = 0.41801879682259846, corr = 0.6588061124658797
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.001,nmse = 0.5595778174780324,r2 = 0.41778145047975856, corr = 0.6586623166130811
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.004,nmse = 0.5603419732469308,r2 = 0.41698637667683214, corr = 0.6581815255150085
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.007,nmse = 0.5611111662484518,r2 = 0.4161860618329286, corr = 0.6576987887741177
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.01,nmse = 0.5618844930787696,r2 = 0.4153814459039381, corr = 0.6572144881516738
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.04,nmse = 0.5697014816899967,r2 = 0.4072481789503679, corr = 0.6523475089071411
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.07,nmse = 0.5773994373050017,r2 = 0.3992387611134729, corr = 0.6475584222618491
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.1,nmse = 0.5847945193235831,r2 = 0.3915444712542958, corr = 0.6429344156283394
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.4,nmse = 0.6407878585568056,r2 = 0.3332856201474229, corr = 0.6068039006825605
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.7,nmse = 0.6763726237701307,r2 = 0.2962610817536474, corr = 0.5829413464500341
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 1,nmse = 0.7018671302415219,r2 = 0.26973505782116636, corr = 0.5655814018178579
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 1.5,nmse = 0.7325057520014641,r2 = 0.2378567857324536, corr = 0.5446774797099863
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 2,nmse = 0.7548318895117074,r2 = 0.21462732417840646, corr = 0.5296464177737585
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 2.5,nmse = 0.7722861098972876,r2 = 0.1964668993751162, corr = 0.5181766029532358
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 3,nmse = 0.7865572687594046,r2 = 0.18161832397925404, corr = 0.5090769704612261
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 3.5,nmse = 0.7985915852060632,r2 = 0.16909709449660693, corr = 0.5016531472788882
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 4,nmse = 0.8089692397750984,r2 = 0.15829955606337032, corr = 0.49546606822411443
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 5,nmse = 0.8261570631627275,r2 = 0.14041630678223127, corr = 0.48571420667095877
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 10,nmse = 0.8770626644425008,r2 = 0.08745104544799498, corr = 0.46087837200674303
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 15,nmse = 0.9036459551299255,r2 = 0.059792184674596016, corr = 0.4502419948708802
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 20,nmse = 0.9203732455356977,r2 = 0.04238810171550922, corr = 0.4442176931481206
# The best alpha value is 0.07
# The best alpha value is 0.07
# average performance metrics: [0.55405611 0.43305399 0.67470694]
# The best alpha value is 0.07
# average performance metrics: [0.55405611 0.43305399 0.67470694]
# X_train inside the LRR:(550, 159600)
# Time to run one experiment: 0.8223650455474854
# Test Results: Seed:0 Best_Lambda:0.07 NMSE:0.6290806546128309 CORR:0.5967875486052422 R2:0.3255846843098431
#
# =====================================Seed:1===========================================
# /var/folders/r8/5wc8dngx7j55w_gyx0q8q2x80000gn/T/ipykernel_6598/1950958019.py:200: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df,seed_result_df],ignore_index = True)
# X_train_combined shape: (550, 159600)
# X_test_combined shape: (77, 159600)
# Y_train_combined shape: (550, 1)
# Y_test_combined shape: (77, 1)
# Sample mean for each feature (across samples): [0.00544711 0.00588224 0.00330302 ... 0.00187339 0.00091658 0.00321099]
# Sample variance for each feature (across samples): None
# Response Average: 1.0917109373968865
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0,nmse = 0.5429642051412691,r2 = 0.4342414520077277, corr = 0.7200423503909972
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 1e-05,nmse = 0.5429651812713199,r2 = 0.4342404348984691, corr = 0.7200416208006691
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.0001,nmse = 0.5429739776311158,r2 = 0.43423126925605915, corr = 0.7200350498673275
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.001,nmse = 0.5430630379808717,r2 = 0.4341384700370968, corr = 0.7199688874092739
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.004,nmse = 0.5433737496285717,r2 = 0.4338147143106923, corr = 0.7197426142496878
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.007,nmse = 0.5437043547295798,r2 = 0.43347022997796103, corr = 0.7195080755279
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.01,nmse = 0.5440531578701235,r2 = 0.433106783628348, corr = 0.7192659417349618
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.04,nmse = 0.5482597072161125,r2 = 0.4287236378748901, corr = 0.7165406835841307
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.07,nmse = 0.5531919117460917,r2 = 0.4235843729899129, corr = 0.7135034708707038
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.1,nmse = 0.5583874456844445,r2 = 0.41817072378583287, corr = 0.7103527871696249
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.4,nmse = 0.6049392356055694,r2 = 0.36966462923515364, corr = 0.6818337039218496
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 0.7,nmse = 0.6386280752467669,r2 = 0.3345614883310687, corr = 0.6605494248472403
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 1,nmse = 0.6642938930268726,r2 = 0.30781818617079293, corr = 0.6441658904940019
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 1.5,nmse = 0.6966443413785837,r2 = 0.27410962396161176, corr = 0.6236686269676942
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 2,nmse = 0.7211551856031935,r2 = 0.24856978264744622, corr = 0.6085525913226203
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 2.5,nmse = 0.7408206753281615,r2 = 0.22807871011079528, corr = 0.5968763981997927
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 3,nmse = 0.7572073858469146,r2 = 0.21100406419183015, corr = 0.5875580416917527
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 3.5,nmse = 0.7712300601083162,r2 = 0.1963926998440918, corr = 0.5799362909810167
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 4,nmse = 0.78346608046955,r2 = 0.18364299544880036, corr = 0.5735803584011672
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 5,nmse = 0.8040093345556217,r2 = 0.16223730886261345, corr = 0.5635745158718245
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 10,nmse = 0.86658715287006,r2 = 0.09703239242269945, corr = 0.5384101767931109
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 15,nmse = 0.8999838644861541,r2 = 0.06223364345779847, corr = 0.5280021118110516
# X_train inside the LRR:(495, 159600)
# fold = 0,alpha = 20,nmse = 0.9210819875512538,r2 = 0.040249793771855336, corr = 0.5223441635300133
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0,nmse = 0.5005220637522039,r2 = 0.47650001157893385, corr = 0.704210244430658
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 1e-05,nmse = 0.5005229569405372,r2 = 0.47649907738618613, corr = 0.7042108181072094
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.0001,nmse = 0.500531008915568,r2 = 0.47649065576176486, corr = 0.7042159684703534
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.001,nmse = 0.500612831681841,r2 = 0.47640507668284204, corr = 0.7042662201203616
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.004,nmse = 0.5009020881560464,r2 = 0.47610254104682637, corr = 0.7044176896885953
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.007,nmse = 0.5012152401585608,r2 = 0.475775012888604, corr = 0.7045455257653472
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.01,nmse = 0.5015504492214454,r2 = 0.47542441507634536, corr = 0.7046510137290295
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.04,nmse = 0.5058008528933201,r2 = 0.4709788842313496, corr = 0.7047106405763653
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.07,nmse = 0.5110101684916651,r2 = 0.4655304198120762, corr = 0.703509164751708
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.1,nmse = 0.516612955157212,r2 = 0.4596704208890485, corr = 0.7015645579634086
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.4,nmse = 0.5673757001210743,r2 = 0.40657726411272743, corr = 0.6748420536778754
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 0.7,nmse = 0.603199220585477,r2 = 0.36910916049362097, corr = 0.6533453871248561
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 1,nmse = 0.6300986949268362,r2 = 0.3409747873539668, corr = 0.6373199250571678
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 1.5,nmse = 0.6639966986009824,r2 = 0.3055205969874494, corr = 0.6179349593197994
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 2,nmse = 0.6899480725883663,r2 = 0.2783778495128203, corr = 0.6039822616656837
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 2.5,nmse = 0.7110335804898715,r2 = 0.2563243498937605, corr = 0.5933267142138254
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 3,nmse = 0.7287995775210947,r2 = 0.2377427529699162, corr = 0.5848662990853517
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 3.5,nmse = 0.7441371348165271,r2 = 0.2217010803883429, corr = 0.577960501807925
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 4,nmse = 0.7576100405960005,r2 = 0.20760966158718452, corr = 0.5722048281755495
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 5,nmse = 0.7803781295162839,r2 = 0.1837963371619119, corr = 0.5631406373929707
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 10,nmse = 0.8501610460845368,r2 = 0.1108098323481016, corr = 0.5403109627387132
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 15,nmse = 0.8872137317919682,r2 = 0.07205613507170572, corr = 0.5309274047787799
# X_train inside the LRR:(495, 159600)
# fold = 1,alpha = 20,nmse = 0.910458032072551,r2 = 0.04774473741518781, corr = 0.5259130039182822
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0,nmse = 0.8579385723913321,r2 = 0.09590754130613666, corr = 0.4445565856094164
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 1e-05,nmse = 0.857933537892748,r2 = 0.0959128466419148, corr = 0.4445571499764214
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.0001,nmse = 0.8578882561607767,r2 = 0.09596056436170175, corr = 0.44456222301304105
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.001,nmse = 0.8574382671197643,r2 = 0.09643476113005522, corr = 0.4446123377933794
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.004,nmse = 0.8559744993832398,r2 = 0.09797727409596924, corr = 0.4447715475468763
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.007,nmse = 0.8545640216989543,r2 = 0.09946363020415094, corr = 0.4449193143258623
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.01,nmse = 0.8532039059346308,r2 = 0.10089691510944221, corr = 0.44505639018685
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.04,nmse = 0.8418619123643103,r2 = 0.11284906551212115, corr = 0.4459682515229101
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.07,nmse = 0.8334903029352911,r2 = 0.12167103621663289, corr = 0.4463249050655122
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.1,nmse = 0.8270642482842827,r2 = 0.12844278857290936, corr = 0.4463661639991657
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.4,nmse = 0.8022600065288668,r2 = 0.15458140576106594, corr = 0.4428270811068438
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 0.7,nmse = 0.7981803758219917,r2 = 0.15888050534119225, corr = 0.4391728172149739
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 1,nmse = 0.7993166004186681,r2 = 0.15768315611096217, corr = 0.43614700356692393
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 1.5,nmse = 0.8050489437918119,r2 = 0.15164243410465594, corr = 0.431981468472629
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 2,nmse = 0.8122419249325872,r2 = 0.144062497481949, corr = 0.4285236624419642
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 2.5,nmse = 0.8196121158693426,r2 = 0.1362958178390441, corr = 0.4255677777719963
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 3,nmse = 0.8267364578245691,r2 = 0.12878821293334142, corr = 0.4230036441493112
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 3.5,nmse = 0.8334732376616558,r2 = 0.12168901953816147, corr = 0.4207577426093313
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 4,nmse = 0.8397865409761939,r2 = 0.11503608411854116, corr = 0.4187754249939248
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 5,nmse = 0.8511847873525218,r2 = 0.10302465471929023, corr = 0.415439645238696
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 10,nmse = 0.8904178258558272,r2 = 0.061681025485301744, corr = 0.40574633751245376
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 15,nmse = 0.9131549542594742,r2 = 0.03772072461574871, corr = 0.40109768136535034
# X_train inside the LRR:(495, 159600)
# fold = 2,alpha = 20,nmse = 0.9279534411817507,r2 = 0.02212613444687661, corr = 0.3983699715475581
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0,nmse = 0.6556904357065834,r2 = 0.33481804030067686, corr = 0.589664177517715
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 1e-05,nmse = 0.6556865706174592,r2 = 0.33482196133935305, corr = 0.589667254260003
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.0001,nmse = 0.6556518144658999,r2 = 0.33485722060767054, corr = 0.5896949246827201
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.001,nmse = 0.6553071683151385,r2 = 0.33520685572430786, corr = 0.5899696362636703
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.004,nmse = 0.6541956088071659,r2 = 0.33633450574262624, corr = 0.5908598334697361
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.007,nmse = 0.6531387816922869,r2 = 0.33740663108265967, corr = 0.5917124623896391
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.01,nmse = 0.6521335227332439,r2 = 0.33842644178595427, corr = 0.5925295763513139
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.04,nmse = 0.6443678997730703,r2 = 0.34630447693430577, corr = 0.5991087798815502
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.07,nmse = 0.6395472519167957,r2 = 0.3511949066453959, corr = 0.6036067557595678
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.1,nmse = 0.6365910908675393,r2 = 0.3541938599514819, corr = 0.6067630022312083
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.4,nmse = 0.6406721307504976,r2 = 0.3500537444958828, corr = 0.6131489415713728
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 0.7,nmse = 0.6571756755608013,r2 = 0.33331130068232695, corr = 0.608886895377451
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 1,nmse = 0.6736575843300966,r2 = 0.31659080610483525, corr = 0.6033173505568343
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 1.5,nmse = 0.6978850652725592,r2 = 0.29201261741352225, corr = 0.5943187949454262
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 2,nmse = 0.7182085560957664,r2 = 0.27139493150943583, corr = 0.5864415073185303
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 2.5,nmse = 0.735450524354692,r2 = 0.2539033751118096, corr = 0.5796943044791967
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 3,nmse = 0.7503092145527773,r2 = 0.23882959619679967, corr = 0.573914302859009
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 3.5,nmse = 0.7632966010241004,r2 = 0.22565420928566116, corr = 0.5689340835534361
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 4,nmse = 0.774784756388009,r2 = 0.21399975577810004, corr = 0.5646114207516457
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 5,nmse = 0.7942952683421384,r2 = 0.19420681711429333, corr = 0.557501550445259
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 10,nmse = 0.8542501170728996,r2 = 0.13338408492173448, corr = 0.5380315182368421
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 15,nmse = 0.8860821630418598,r2 = 0.10109125042880074, corr = 0.52932464842214
# X_train inside the LRR:(495, 159600)
# fold = 3,alpha = 20,nmse = 0.906115852461066,r2 = 0.08076756098301141, corr = 0.5244213247000287
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0,nmse = 0.5304818124708214,r2 = 0.45928830427752554, corr = 0.6945729588724373
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 1e-05,nmse = 0.530476166190394,r2 = 0.45929405944159063, corr = 0.6945751700352959
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.0001,nmse = 0.5304253890291855,r2 = 0.45934581579646583, corr = 0.6945950586309615
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.001,nmse = 0.5299214895665555,r2 = 0.4598594325247062, corr = 0.694792776089616
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.004,nmse = 0.5282914076198897,r2 = 0.46152094919281395, corr = 0.6954368295495212
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.007,nmse = 0.5267343921856045,r2 = 0.46310799032400185, corr = 0.6960586636001816
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.01,nmse = 0.5252465036078939,r2 = 0.4646245715469336, corr = 0.6966593411384568
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.04,nmse = 0.5134764769353863,r2 = 0.47662157301084407, corr = 0.701691651746532
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.07,nmse = 0.5057964906093555,r2 = 0.48444966123526734, corr = 0.705387312424507
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.1,nmse = 0.5007775272256147,r2 = 0.48956541098991246, corr = 0.7081570251619949
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.4,nmse = 0.5007485305969255,r2 = 0.4895949667935242, corr = 0.7154207305919517
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 0.7,nmse = 0.5204011298112631,r2 = 0.4695633841893174, corr = 0.7120419667554408
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 1,nmse = 0.5407554735544332,r2 = 0.44881652451956555, corr = 0.7069462406714081
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 1.5,nmse = 0.5711003861089003,r2 = 0.4178864365539606, corr = 0.6986094590036486
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 2,nmse = 0.5968939421453905,r2 = 0.3915954740829891, corr = 0.6914821554148698
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 2.5,nmse = 0.6190752791300604,r2 = 0.36898638918616766, corr = 0.6855571394326258
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 3,nmse = 0.6384536817571176,r2 = 0.3492342908134356, corr = 0.6806167118790293
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 3.5,nmse = 0.6556148728753808,r2 = 0.33174216095708153, corr = 0.6764558635560263
# X_train inside the LRR:(495, 159600)
# fold = 4,alpha = 4,nmse = 0.6709805007358872,r2 = 0.3160802202439832, corr = 0.6729121090437862
# X_train inside the LRR:(495, 159600)
# ...
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0,nmse = 0.5362715910609288,r2 = 0.4637028940088511, corr = 0.6955640830154683
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 1e-05,nmse = 0.5362703123489293,r2 = 0.4637041727816895, corr = 0.6955660274046167
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.0001,nmse = 0.5362588215558806,r2 = 0.4637156641214515, corr = 0.6955835133253765
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.001,nmse = 0.5361456438778234,r2 = 0.4638288471843186, corr = 0.6957570377123277
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.004,nmse = 0.5357904128969053,r2 = 0.464184095066549, corr = 0.696318420717746
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.007,nmse = 0.5354673230325224,r2 = 0.4645072003030223, corr = 0.6968548565997924
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.01,nmse = 0.5351742560879093,r2 = 0.464800281191284, corr = 0.6973678710092186
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.04,nmse = 0.5335358139901525,r2 = 0.4664388012434513, corr = 0.7014710687588039
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.07,nmse = 0.5334807515374206,r2 = 0.46649386631596546, corr = 0.7042734847912341
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.1,nmse = 0.5343559441221275,r2 = 0.4656186320910184, corr = 0.7062686164278643
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.4,nmse = 0.5566262845230733,r2 = 0.44334723210349236, corr = 0.7118093378625241
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 0.7,nmse = 0.5805108028305709,r2 = 0.41946157740945467, corr = 0.7112066043904468
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 1,nmse = 0.6016947893784006,r2 = 0.3982765829619942, corr = 0.7095380894697803
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 1.5,nmse = 0.6315701044260983,r2 = 0.36839984649538937, corr = 0.70632916293082
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 2,nmse = 0.6562933744400359,r2 = 0.34367540018846965, corr = 0.7032588369556658
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 2.5,nmse = 0.677260902537252,r2 = 0.32270687449036395, corr = 0.7005035858590202
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 3,nmse = 0.6953926165956874,r2 = 0.3045742977544592, corr = 0.6980695076938993
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 3.5,nmse = 0.7113097479112291,r2 = 0.28865640912769397, corr = 0.6959228285599822
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 4,nmse = 0.7254488157692697,r2 = 0.2745166685557976, corr = 0.6940236517291156
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 5,nmse = 0.7495871299684246,r2 = 0.250377205894907, corr = 0.6908261984128831
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 10,nmse = 0.8244543443911981,r2 = 0.1755064294118195, corr = 0.6815296472518376
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 15,nmse = 0.8643036010064516,r2 = 0.135655276833739, corr = 0.6770281939396331
# X_train inside the LRR:(495, 159600)
# fold = 5,alpha = 20,nmse = 0.8892959852306417,r2 = 0.11066170351255011, corr = 0.6743432372338004
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0,nmse = 0.7558338857939392,r2 = 0.24167038853484213, corr = 0.5261325312328669
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 1e-05,nmse = 0.7558310714128512,r2 = 0.24167321220887572, corr = 0.5261324923372898
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.0001,nmse = 0.7558057652873205,r2 = 0.24169860189396664, corr = 0.5261321377802978
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.001,nmse = 0.7555549946424855,r2 = 0.24195020057092287, corr = 0.5261281501327383
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.004,nmse = 0.7547483305440847,r2 = 0.24275952823381375, corr = 0.5261092113216016
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.007,nmse = 0.7539845186484585,r2 = 0.24352586219810035, corr = 0.5260819885802549
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.01,nmse = 0.7532609657611803,r2 = 0.24425180422080817, corr = 0.5260469764033839
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.04,nmse = 0.7477926017630591,r2 = 0.24973822448323046, corr = 0.5253557745754668
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.07,nmse = 0.7445583603958555,r2 = 0.25298314515359643, corr = 0.5242425578325827
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.1,nmse = 0.7426955477436542,r2 = 0.25485210871996555, corr = 0.5228891661881423
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.4,nmse = 0.7464826970472702,r2 = 0.25105245443884694, corr = 0.5075882493036518
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 0.7,nmse = 0.7567390311813286,r2 = 0.24076225440267418, corr = 0.49511693366678455
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 1,nmse = 0.7663161980532436,r2 = 0.2311534642049612, corr = 0.4852928941628998
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 1.5,nmse = 0.780019469603332,r2 = 0.21740494513788533, corr = 0.4726995698328148
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 2,nmse = 0.7915236175730982,r2 = 0.20586281104715587, corr = 0.4631320490982583
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 2.5,nmse = 0.8014556674725117,r2 = 0.19589796601594478, corr = 0.45553878562843775
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 3,nmse = 0.8102210427140999,r2 = 0.18710364794390222, corr = 0.4493316166290307
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 3.5,nmse = 0.8180821025138331,r2 = 0.17921663131805432, corr = 0.44414604952062653
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 4,nmse = 0.8252159016124259,r2 = 0.17205927677179178, corr = 0.4397400767679154
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 5,nmse = 0.8377683869548925,r2 = 0.15946534375081345, corr = 0.432638640858532
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 10,nmse = 0.8802740193926907,r2 = 0.11681935984156055, corr = 0.4136879517752403
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 15,nmse = 0.9053531961299723,r2 = 0.0916573729175797, corr = 0.40522016526258486
# X_train inside the LRR:(495, 159600)
# fold = 6,alpha = 20,nmse = 0.9219731537475996,r2 = 0.07498253703151214, corr = 0.4003591310429762
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0,nmse = 0.5206309338181522,r2 = 0.4575189823611854, corr = 0.6969077649977289
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 1e-05,nmse = 0.5206303712206455,r2 = 0.4575195685700487, corr = 0.6969092650571547
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.0001,nmse = 0.5206253238413532,r2 = 0.45752482778012826, corr = 0.6969227522362502
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.001,nmse = 0.5205764214448728,r2 = 0.4575757825353769, corr = 0.6970563111652478
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.004,nmse = 0.5204334155978485,r2 = 0.4577247901190278, corr = 0.6974847445975223
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.007,nmse = 0.5203195837628706,r2 = 0.4578433993019775, corr = 0.6978885963062412
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.01,nmse = 0.5202329848901607,r2 = 0.45793363259689457, corr = 0.6982693372316582
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.04,nmse = 0.5205336037003949,r2 = 0.4576203972750873, corr = 0.701059491774993
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.07,nmse = 0.5222423845281441,r2 = 0.45583990153012466, corr = 0.7025567174008245
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.1,nmse = 0.5247464820354869,r2 = 0.4532307108812176, corr = 0.7032528784683034
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.4,nmse = 0.5585054587416248,r2 = 0.4180549215678854, corr = 0.6968518957916305
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 0.7,nmse = 0.5888212033402119,r2 = 0.386466871546132, corr = 0.6868119792383978
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 1,nmse = 0.6139605441925524,r2 = 0.36027247101688875, corr = 0.677744503107595
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 1.5,nmse = 0.6476726854943249,r2 = 0.3251454827181933, corr = 0.6652257325267527
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 2,nmse = 0.6744546890224408,r2 = 0.2972394794736507, corr = 0.6552666707239984
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 2.5,nmse = 0.6965428717556187,r2 = 0.274224289502108, corr = 0.647167886760588
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 3,nmse = 0.7152462404153582,r2 = 0.25473596907250917, corr = 0.6404471287468584
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 3.5,nmse = 0.7313931039049124,r2 = 0.237911446424095, corr = 0.6347747654494229
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 4,nmse = 0.7455408141708506,r2 = 0.22316997840174757, corr = 0.6299193823593148
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 5,nmse = 0.7693070669884337,r2 = 0.19840629231150275, corr = 0.622034007029461
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 10,nmse = 0.8404646301152419,r2 = 0.12426235511853512, corr = 0.6007381121396863
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 15,nmse = 0.8771264900867505,r2 = 0.08606185297007363, corr = 0.5911945216794084
# X_train inside the LRR:(495, 159600)
# fold = 7,alpha = 20,nmse = 0.8998050659476338,r2 = 0.062431491974451414, corr = 0.5857673379897665
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0,nmse = 0.5510081671161821,r2 = 0.4437929936803169, corr = 0.6685451386989311
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 1e-05,nmse = 0.5510082669140852,r2 = 0.44379289294080637, corr = 0.6685454072991748
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.0001,nmse = 0.5510091800636893,r2 = 0.4437919711755083, corr = 0.6685478136433183
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.001,nmse = 0.5510197803664356,r2 = 0.44378127085742103, corr = 0.6685707913026041
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.004,nmse = 0.5510737381226568,r2 = 0.4437268040022153, corr = 0.6686335815887671
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.007,nmse = 0.5511546736776163,r2 = 0.44364510480896313, corr = 0.6686762897895516
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.01,nmse = 0.5512605629466956,r2 = 0.44353821645980473, corr = 0.6687003131664272
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.04,nmse = 0.5533513775871471,r2 = 0.44142767469048494, corr = 0.6681505860182533
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.07,nmse = 0.55660233897624,r2 = 0.43814604002551794, corr = 0.666673356211635
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.1,nmse = 0.560419775256034,r2 = 0.43429258569994444, corr = 0.6647013403119023
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.4,nmse = 0.5999648910513002,r2 = 0.39437435620043026, corr = 0.6412061282719439
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 0.7,nmse = 0.6309428382185134,r2 = 0.363104127764466, corr = 0.6217539255110158
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 1,nmse = 0.6554705179404435,r2 = 0.3383450259502343, corr = 0.6061844265237257
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 1.5,nmse = 0.6874379077382168,r2 = 0.3060760193539588, corr = 0.5858766822541562
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 2,nmse = 0.7122912010060918,r2 = 0.28098823178438714, corr = 0.5701950822853018
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 2.5,nmse = 0.7324820322407284,r2 = 0.26060689723012953, corr = 0.5576039666714165
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 3,nmse = 0.7493782383610387,r2 = 0.24355127303943314, corr = 0.5472215510258167
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 3.5,nmse = 0.7638261333335354,r2 = 0.22896706015501844, corr = 0.5384894839504973
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 4,nmse = 0.7763865467413609,r2 = 0.21628813748810416, corr = 0.5310305420324237
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 5,nmse = 0.7972993600058553,r2 = 0.19517800890245185, corr = 0.5189364163714023
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 10,nmse = 0.8589223595333654,r2 = 0.13297358774655144, corr = 0.4862841943529831
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 15,nmse = 0.8904309460409925,r2 = 0.10116771331370178, corr = 0.47154805283067663
# X_train inside the LRR:(495, 159600)
# fold = 8,alpha = 20,nmse = 0.9099589621334033,r2 = 0.08145544765533785, corr = 0.4630553305753773
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0,nmse = 0.5632037194586886,r2 = 0.4347263678247235, corr = 0.6597126183520704
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 1e-05,nmse = 0.5632043202269769,r2 = 0.43472576484846337, corr = 0.6597119698851466
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.0001,nmse = 0.5632097432918245,r2 = 0.4347203218525135, corr = 0.6597061272174963
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.001,nmse = 0.5632655558579949,r2 = 0.43466430416138313, corr = 0.6596470674892534
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.004,nmse = 0.5634715122660161,r2 = 0.4344575908127144, corr = 0.6594422440676115
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.007,nmse = 0.5637059559100726,r2 = 0.434222285530385, corr = 0.6592260685236943
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.01,nmse = 0.5639663079189974,r2 = 0.4339609766635498, corr = 0.6589996094070497
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.04,nmse = 0.5675743008850219,r2 = 0.4303397234326092, corr = 0.6563439940621695
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.07,nmse = 0.5721707082129703,r2 = 0.4257264231729381, corr = 0.6533259371173314
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.1,nmse = 0.5771156297956277,r2 = 0.4207633277826287, corr = 0.650211470203114
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.4,nmse = 0.6205569184249377,r2 = 0.3771623816925245, corr = 0.6238492152018296
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 0.7,nmse = 0.6502354936991368,r2 = 0.3473747303269431, corr = 0.606133890383693
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 1,nmse = 0.672063784973894,r2 = 0.3254662146926338, corr = 0.5934670968596935
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 1.5,nmse = 0.6990529999522314,r2 = 0.2983778076859698, corr = 0.5786421268776059
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 2,nmse = 0.7194583416312734,r2 = 0.277897471338447, corr = 0.5683213550922225
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 2.5,nmse = 0.7359995399411352,r2 = 0.2612954800409928, corr = 0.5606389947407671
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 3,nmse = 0.7499876225191331,r2 = 0.2472559878060473, corr = 0.5546568806558108
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 3.5,nmse = 0.7621452964999358,r2 = 0.2350536313717957, corr = 0.5498454999478374
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 4,nmse = 0.772912080983969,r2 = 0.22424727629660635, corr = 0.5458802486209555
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 5,nmse = 0.7913379872603261,r2 = 0.20575365026557035, corr = 0.5397084186266649
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 10,nmse = 0.8500163133937761,r2 = 0.14685966679667417, corr = 0.5244434846934287
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 15,nmse = 0.8826151187920629,r2 = 0.11414105274033326, corr = 0.5182159950321295
# X_train inside the LRR:(495, 159600)
# fold = 9,alpha = 20,nmse = 0.9035824926319787,r2 = 0.0930966186249873, corr = 0.5148729834278626
# The best alpha value is 0.07
# The best alpha value is 0.07
# average performance metrics: [0.57841016 0.41606825 0.66277105]
# The best alpha value is 0.07
# average performance metrics: [0.57841016 0.41606825 0.66277105]
# X_train inside the LRR:(550, 159600)
# Time to run one experiment: 0.9464278221130371
# Test Results: Seed:29 Best_Lambda:0.07 NMSE:0.4370329147867356 CORR:0.6636772377736769 R2:0.31320702785867616

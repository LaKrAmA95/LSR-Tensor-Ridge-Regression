# %% [markdown]
# # Analyze LSR BCD Regression Results

# %%
#Installing the libraries
# %pip install dill
# %pip install path
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Vector Regression Baseline/Experimental Results/Vector_Base_Line/Stochastic Solver")
sys.path.append("/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Vector Regression Baseline/Code Files")
#Import Standard Data Analysis Libraries
import datetime
import numpy as np
import pandas as pd
import re
import scipy.io
import matplotlib.pyplot as plt

#Import dill library to save variables generated
import dill
import pickle
import path
import os

# %%
pkl_file = "/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Vector Regression Baseline/Experimental Results/Vector_Base_Line/Stochastic Solver/Comparison with Stochastic Solver/n_train_1100,intercept_82.84294891357422,n_test_400, p1_32, p2_32, d1_4, d2_4, S_2,ExecutionTime_2024-05-09 21:41:10.pkl"

n_train = 1100
n_test = 100

file= open(pkl_file, 'rb')
data = pickle.load(file)
file.close()

p_star = data[0]
lambda1 = data[1]
error_matrics = data[2]
W_estimated = data[3]
b_estimated = data[4]
losses = data[5]
gap_to_optimality = data[6]
validation_nee = data[7]
validation_nmse_losses = data[8]
validation_correlations = data[9]
validation_R2_scores = data[10]
objective_function_information = data[10]

# %%
print("Best Lambda: ", lambda1)
# Out:
# Best Lambda:  0.1

# %%
#gap_to_optimality
plt.plot(range(1, len(gap_to_optimality)+1), gap_to_optimality)
plt.title('Gap to Optimality')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Gap to Optimality')
plt.grid(True)
plt.show()

# %%
print(gap_to_optimality)
# Out:
# [4716521.278245213, 4623911.778245213, 4550221.278245213, 4478316.778245213, 4386065.778245213, 4313618.778245213, 4237283.778245213, 4159843.0282452134, 4104077.0282452134, 4036464.5282452134, 3971959.5282452134, 3899890.5282452134, 3839650.2782452134, 3768504.0282452134, 3701971.0282452134, 3629568.0282452134, 3562495.5282452134, 3503812.5282452134, 3434230.2782452134, 3372717.7782452134, 3313096.5282452134, 3261236.2782452134, 3201334.0282452134, 3145230.0282452134, 3088233.0282452134, 3032091.2782452134, 2981972.7782452134, 2933981.0282452134, 2889229.0282452134, 2844613.7782452134, 2804005.2782452134, 2749375.5282452134, 2709349.2782452134, 2663929.5282452134, 2599001.0282452134, 2561623.7782452134, 2518428.7782452134, 2473123.0282452134, 2431586.0282452134, 2381607.5282452134, 2341722.2782452134, 2294413.2782452134, 2263660.2782452134, 2231351.0282452134, 2195278.5282452134, 2159435.7782452134, 2110791.7782452134, 2082844.7782452134, 2038958.0282452134, 2009411.5282452134, 1979
# ...

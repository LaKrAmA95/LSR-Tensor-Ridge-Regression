# %% [markdown]
# # Tensor Pipeline

# %% [markdown]
# ## Setting Path

# %%
import sys
sys.path.append('../Code Files')
sys.path.append('../Data')

# %% [markdown]
# ## Import Libraries

# %%
import datetime
import numpy as np
import dill
from KFoldCV_PyTorch import KFoldCV
from train_test_PyTorch import train_test
from DataGenerationB_PyTorch import *
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Data

# %%
import pickle
pkl_file = "../Data/Bounded_Var_Time_2024-03-31 20_19_12, intercept_5,n_train_5000, n_test_1000, tensor_dimensions_[32 32], tensor_mode_ranks_[4 4], separation_rank_2.pkl"
file= open(pkl_file, 'rb')
data = pickle.load(file)
file.close()

X_train_Full = data[0]
print(data[0].shape)

Y_train_Full = data[1]
print(data[1].shape)

X_test_Full = data[2]
print(data[2].shape)

Y_test_Full = data[3]
print(data[3].shape)

B_tensored = data[4]
print(data[4].shape)
# Out:
# (5000, 32, 32)
# (5000,)
# (1000, 32, 32)
# (1000,)
# (32, 32)

# %% [markdown]
# ## Subset Data

# %%
n_train_all = [1000]
n_test = 100

tensor_dimensions = np.array([32, 32])
tensor_mode_ranks = np.array([4, 4])
separation_rank = 2

# %%
for i,n_train in enumerate(n_train_all):
  print('Number of Samples:',n_train,'---------------------------------------------------------------------------------------------------------------------------')

  #Subset X_train and Y_train
  X_train = X_train_Full[0:(n_train),:,:]
  Y_train = Y_train_Full[0:(n_train)]
  

  #Subset X_test and Y_test
  X_test = X_test_Full[0:(n_test),:,:]
  Y_test = Y_test_Full[0:(n_test)]

  #Preprocessing

  # Reshape the 3D array to a 2D array where each row represents a sample
  # The shape of the original 3D array is (n_samples, n_features_per_sample, n_dimensions)
  # We reshape it to (n_samples, n_features_per_sample * n_dimensions)


  X_train_2D = X_train.reshape(n_train, -1)
  X_test_2D = X_test.reshape(n_test,-1)


  # Initialize StandardScaler
  scaler = StandardScaler(with_std = False) #standard scalar only

  # Fit scaler on train data and transform train data
  X_train_scaled = scaler.fit_transform(X_train_2D)
  # Transform test data using the scaler fitted on train data
  X_test_scaled = scaler.transform(X_test_2D)

  # Reshape the scaled data back to 3D
  X_train = X_train_scaled.reshape(n_train, tensor_dimensions[0],tensor_dimensions[1])
  X_test  = X_test_scaled.reshape(n_test, tensor_dimensions[0],tensor_dimensions[1])

  #average response value
  Y_train_mean = np.mean(Y_train)
  # Mean centering y_train and y_test
  Y_train = Y_train - Y_train_mean


  print("Sample mean for each feature (across samples):",scaler.mean_)
  print("Sample variance for each feature (across samples):",scaler.var_)
  print('Response Average:',Y_train_mean)

  #For now, define finite alpha set that we are searching over
  alphas = [0,0.1,0.3, 0.5, 0.7, 0.9, 1, 1.5, 2, 2.5, 3, 5, 4,10,15,20,50,100]

  #Define Number of Folds we want
  k_folds = 5
  hypers = {'max_iter': 100, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank}
  lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information = KFoldCV(X_train, Y_train, B_tensored, alphas, k_folds, hypers,Y_train_mean)

  hypers = {'max_iter': 100, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank}
  normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values = train_test(X_train, Y_train, X_test, Y_test, B_tensored, lambda1, hypers, Y_train_mean)

  #Get current time and store in variable
  formatted_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  max_iter = hypers['max_iter']
  pkl_file = f"/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Closed_Form_Solver/Experimental Results/ExecutionTime_intercept_5_{formatted_time}, n_train_{n_train},n_test_{n_test}, tensor_dimensions:{tensor_dimensions}, tensor_mode_= ranks:{tensor_mode_ranks}, separation_rank:{separation_rank}, max_iter={max_iter}.pkl"

  print("Error Record on Training _ After K-Fold CV")
  print("Validation Normalized Estimation Error: ", validation_normalized_estimation_error)
  print("Validation NMSE Losses: ", validation_nmse_losses)
  print("Validation Correlations: ", validation_correlations)
  print("Validation R2 Scores: ", validation_R2_scores)

  print("Error Report on Testing _ With best Lambda")
  print("Alpha chosen for model: ", lambda1)
  print("Test Normalized Estimation Error: ", normalized_estimation_error)
  print("Test NMSE Loss: ", test_nmse_loss)
  print("Test R2 Loss: ", test_R2_loss)
  print("Test Correlation: ", test_correlation)

  with open(pkl_file, "wb") as file:
    dill.dump((X_train_Full, Y_train_Full, X_test_Full, Y_test_Full, B_tensored, lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information, normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values), file)
# Out:
# Number of Samples: 1000 ---------------------------------------------------------------------------------------------------------------------------
# Sample mean for each feature (across samples): [-0.02231123  0.0239631   0.016219   ... -0.0093375   0.00688489
#  -0.002867  ]
# Sample variance for each feature (across samples): None
# Response Average: 4.543979727602281
# Fold = 0, Alpha = 0, Normalized Estimation Error: 0.45410423855833876, NMSE: 0.46484455977699113, Correlation: 0.7932527610916743, R^2 Score: 0.5259265264729518
# Fold = 0, Alpha = 0.1, Normalized Estimation Error: 0.6256045408745446, NMSE: 0.6425515509291342, Correlation: 0.6897409771841013, R^2 Score: 0.34469138282417167
# Fold = 0, Alpha = 0.3, Normalized Estimation Error: 0.5555235291127534, NMSE: 0.6725220241910288, Correlation: 0.6491609163213877, R^2 Score: 0.31412588288730625
# Fold = 0, Alpha = 0.5, Normalized Estimation Error: 0.6542304955688716, NMSE: 0.7642114830818021, Correlation: 0.6032428245981134, R^2 Score: 0.22061604320451433
# Fold = 0, Alpha = 0.7, Normalized Estimation Error: 0.5307613730452582, NMSE: 0.5639356779635037, Correlation: 0.713814226469136, R^2 Score: 0.424868076704504
# Fold = 0, Alpha = 0.9, Normalized Estimation Error: 0.6325555250458392, NMSE: 0.6564207395098897, Correlation: 0.6629312655831576, R^2 Score: 0.3305468386594841
# Fold = 0, Alpha = 1, Normalized Estimation Error: 0.5563916994025494, NMSE: 0.7433088534954917, Correlation: 0.6454336872402893, R^2 Score: 0.24193366864598542
# Fold = 0, Alpha = 1.5, Normalized Estimation Error: 0.5249410176152819, NMSE: 0.6608117159194625, Correlation: 0.6826424888416873, R^2 Score: 0.32606868484466867
# Fold = 0, Alpha = 2, Normalized Estimation Error: 0.5541628694632492, NMSE: 0.7319622665123265, Correlation: 0.5933820009022576, R^2 Score: 0.25350552807866655
# Fold = 0, Alpha = 2.5, Normalized Estimation Error: 0.7186079563934245, NMSE: 0.7990908567007788, Correlation: 0.5864834880442027, R^2 Score: 0.18504418276598666
# Fold = 0, Alpha = 3, Normalized Estimation Error: 0.6003673394268636, NMSE: 0.6889528485432308, Correlation: 0.6582881109861506, R^2 Score: 0.29736884484151693
# Fold = 0, Alpha = 5, Normalized Estimation Error: 0.5208762618449032, NMSE: 0.6235473448748272, Correlation: 0.6698763745290592, R^2 Score: 0.3640728938826454
# Fold = 0, Alpha = 4, Normalized Estimation Error: 0.7166492638763612, NMSE: 0.7924823311703901, Correlation: 0.5918061737804512, R^2 Score: 0.191783912396439
# Fold = 0, Alpha = 10, Normalized Estimation Error: 0.5754311447940419, NMSE: 0.6308704198369367, Correlation: 0.6924754387762542, R^2 Score: 0.35660442832535943
# Fold = 0, Alpha = 15, Normalized Estimation Error: 0.7022434938789235, NMSE: 0.7244138955273047, Correlation: 0.5944823295751572, R^2 Score: 0.2612037626327224
# Fold = 0, Alpha = 20, Normalized Estimation Error: 0.4103548707142327, NMSE: 0.4986996142106141, Correlation: 0.7365202424508208, R^2 Score: 0.49139932181018275
# Fold = 0, Alpha = 50, Normalized Estimation Error: 0.4703827543294581, NMSE: 0.6226890772332095, Correlation: 0.6779925762469626, R^2 Score: 0.36494820136666273
# Fold = 0, Alpha = 100, Normalized Estimation Error: 0.547687601208363, NMSE: 0.6387786956265874, Correlation: 0.6552166688032574, R^2 Score: 0.34853914350195914
# Fold = 1, Alpha = 0, Normalized Estimation Error: 0.529495938900372, NMSE: 0.5838390067829333, Correlation: 0.6727289001675293, R^2 Score: 0.41413484559985625
# Fold = 1, Alpha = 0.1, Normalized Estimation Error: 0.7448594382503686, NMSE: 0.7741790672667269, Correlation: 0.5505373155167069, R^2 Score: 0.22313423134091503
# Fold = 1, Alpha = 0.3, Normalized Estimation Error: 0.4709186952080787, NMSE: 0.47718689020526744, Correlation: 0.7420557860893429, R^2 Score: 0.5211570863545021
# Fold = 1, Alpha = 0.5, Normalized Estimation Error: 0.4419292955788798, NMSE: 0.536342031781335, Correlation: 0.7063819041383684, R^2 Score: 0.4617966535119079
# Fold = 1, Alpha = 0.7, Normalized Estimation Error: 0.6233256690583047, NMSE: 0.6107464251568929, Correlation: 0.6605637380403865, R^2 Score: 0.38713404805631346
# Fold = 1, Alpha = 0.9, Normalized Estimation Error: 0.7485754324641639, NMSE: 0.9049318197807615, Correlation: 0.4243085241714304, R^2 Score: 0.09192771610312922
# Fold = 1, Alpha = 1, Normalized Estimation Error: 0.5282282597918031, NMSE: 0.5239058728561017, Correlation: 0.725719677648089, R^2 Score: 0.4742759707281785
# Fold = 1, Alpha = 1.5, Normalized Estimation Error: 0.37496116996738194, NMSE: 0.446552277318853, Correlation: 0.7651398475856945, R^2 Score: 0.5518980132199122
# Fold = 1, Alpha = 2, Normalized Estimation Error: 0.5456883379733444, NMSE: 0.5476693960813833, Correlation: 0.7050082195659941, R^2 Score: 0.45042997886787917
# Fold = 1, Alpha = 2.5, Normalized Estimation Error: 0.5170062837505233, NMSE: 0.552289928574095, Correlation: 0.710781273313716, R^2 Score: 0.4457934113367553
# Fold = 1, Alpha = 3, Normalized Estimation Error: 0.5618393758713515, NMSE: 0.6344406422855202, Correlation: 0.6617793443736146, R^2 Score: 0.36335760281168317
# Fold = 1, Alpha = 5, Normalized Estimation Error: 0.541361128676313, NMSE: 0.5111978872984505, Correlation: 0.7098384465847115, R^2 Score: 0.4870280579206263
# Fold = 1, Alpha = 4, Normalized Estimation Error: 0.5981928894063403, NMSE: 0.6766413711653968, Correlation: 0.6091220431311933, R^2 Score: 0.32101042104792743
# Fold = 1, Alpha = 10, Normalized Estimation Error: 0.4500455395237629, NMSE: 0.49713019936482633, Correlation: 0.7351367062246521, R^2 Score: 0.501144566183237
# Fold = 1, Alpha = 15, Normalized Estimation Error: 0.5739492121873697, NMSE: 0.5360004037186634, Correlation: 0.7075154769381308, R^2 Score: 0.4621394671563531
# Fold = 1, Alpha = 20, Normalized Estimation Error: 0.4546618202039956, NMSE: 0.5358153392095842, Correlation: 0.708050522637058, R^2 Score: 0.4623251739109995
# Fold = 1, Alpha = 50, Normalized Estimation Error: 0.6360279129289858, NMSE: 0.6472469445369373, Correlation: 0.6275863376793531, R^2 Score: 0.3505068577284399
# Fold = 1, Alpha = 100, Normalized Estimation Error: 0.9042079913749368, NMSE: 0.9147093434499411, Correlation: 0.39866945991605224, R^2 Score: 0.0821162606375907
# Fold = 2, Alpha = 0, Normalized Estimation Error: 0.6914964847455249, NMSE: 0.7272254458248326, Correlation: 0.5573071517535653, R^2 Score: 0.27243247244889524
# Fold = 2, Alpha = 0.1, Normalized Estimation Error: 0.608934465917442, NMSE: 0.6802676393624197, Correlation: 0.6160293932446204, R^2 Score: 0.31941236753264124
# Fold = 2, Alpha = 0.3, Normalized Estimation Error: 0.6332435772375405, NMSE: 0.6069750655743382, Correlation: 0.6670303860253353, R^2 Score: 0.39273941763107223
# Fold = 2, Alpha = 0.5, Normalized Estimation Error: 0.45550258565516993, NMSE: 0.5339404873154701, Correlation: 0.7145245909716287, R^2 Score: 0.4658083508410107
# Fold = 2, Alpha = 0.7, Normalized Estimation Error: 0.4510397047319819, NMSE: 0.5136736051050229, Correlation: 0.7432557814619445, R^2 Score: 0.4860847664500656
# Fold = 2, Alpha = 0.9, Normalized Estimation Error: 0.34477181842203325, NMSE: 0.40646256913709833, Correlation: 0.791650152494697, R^2 Score: 0.593346233733987
# Fold = 2, Alpha = 1, Normalized Estimation Error: 0.4715791506658439, NMSE: 0.5560025013853147, Correlation: 0.7032173032242826, R^2 Score: 0.4437359589551787
# Fold = 2, Alpha = 1.5, Normalized Estimation Error: 0.7056527576730203, NMSE: 0.7058672654506045, Correlation: 0.57891887077661, R^2 Score: 0.2938006995606989
# Fold = 2, Alpha = 2, Normalized Estimation Error: 0.49747555753399275, NMSE: 0.6150145317834618, Correlation: 0.6732790267256358, R^2 Score: 0.3846961697136836
# Fold = 2, Alpha = 2.5, Normalized Estimation Error: 0.414186678940164, NMSE: 0.48305857346711945, Correlation: 0.7593944697039202, R^2 Score: 0.5167141991831627
# Fold = 2, Alpha = 3, Normalized Estimation Error: 0.440960365500344, NMSE: 0.5528372809364726, Correlation: 0.715495572948558, R^2 Score: 0.44690266830142056
# Fold = 2, Alpha = 5, Normalized Estimation Error: 0.4384194786224116, NMSE: 0.4336618072876319, Correlation: 0.794487570060707, R^2 Score: 0.5661342012534514
# Fold = 2, Alpha = 4, Normalized Estimation Error: 0.6815522439250594, NMSE: 0.7034585095605438, Correlation: 0.6139735018594973, R^2 Score: 0.2962105885125601
# Fold = 2, Alpha = 10, Normalized Estimation Error: 0.558945148589916, NMSE: 0.6154093595280433, Correlation: 0.6683243756013982, R^2 Score: 0.38430115624491257
# Fold = 2, Alpha = 15, Normalized Estimation Error: 0.7253363663864665, NMSE: 0.9182025450775697, Correlation: 0.4415646262728466, R^2 Score: 0.08136553891414022
# Fold = 2, Alpha = 20, Normalized Estimation Error: 0.5281860402607944, NMSE: 0.5409960388443483, Correlation: 0.7114811698673441, R^2 Score: 0.458749480430401
# Fold = 2, Alpha = 50, Normalized Estimation Error: 0.5738972019399854, NMSE: 0.7024891611634143, Correlation: 0.5945710154585448, R^2 Score: 0.2971803928843464
# Fold = 2, Alpha = 100, Normalized Estimation Error: 0.421327080379143, NMSE: 0.4918867233397238, Correlation: 0.7443110502513498, R^2 Score: 0.5078818966110543
# Fold = 3, Alpha = 0, Normalized Estimation Error: 0.4760205861967556, NMSE: 0.4723678775192959, Correlation: 0.7541480732713954, R^2 Score: 0.5233890363687457
# Fold = 3, Alpha = 0.1, Normalized Estimation Error: 0.5155620208707995, NMSE: 0.5885362475033181, Correlation: 0.6802550921306135, R^2 Score: 0.4061771737579245
# Fold = 3, Alpha = 0.3, Normalized Estimation Error: 0.6483120916970638, NMSE: 0.529737705965401, Correlation: 0.7043712988998083, R^2 Score: 0.4655038783799047
# Fold = 3, Alpha = 0.5, Normalized Estimation Error: 0.49274459734538, NMSE: 0.4827519021939573, Correlation: 0.7593790214385937, R^2 Score: 0.5129117362768085
# Fold = 3, Alpha = 0.7, Normalized Estimation Error: 0.5254328198431709, NMSE: 0.496317409231552, Correlation: 0.743292720192778, R^2 Score: 0.4992243758760784
# Fold = 3, Alpha = 0.9, Normalized Estimation Error: 0.4590610210115165, NMSE: 0.512198330979758, Correlation: 0.735129559119287, R^2 Score: 0.4832008023479316
# Fold = 3, Alpha = 1, Normalized Estimation Error: 0.44249929595666365, NMSE: 0.43135583491796925, Correlation: 0.7811611602291577, R^2 Score: 0.5647694732590713
# Fold = 3, Alpha = 1.5, Normalized Estimation Error: 0.4059569331037441, NMSE: 0.3893383215143303, Correlation: 0.8101682915495044, R^2 Score: 0.607164412681851
# Fold = 3, Alpha = 2, Normalized Estimation Error: 0.6826237811204872, NMSE: 0.6445431766465737, Correlation: 0.6242475950566744, R^2 Score: 0.3496671574350978
# Fold = 3, Alpha = 2.5, Normalized Estimation Error: 0.5857985612033716, NMSE: 0.532089291080274, Correlation: 0.7140508758785774, R^2 Score: 0.46313116994438086
# Fold = 3, Alpha = 3, Normalized Estimation Error: 0.6344194573836135, NMSE: 0.6438978194353772, Correlation: 0.6510514293183793, R^2 Score: 0.3503183116243498
# Fold = 3, Alpha = 5, Normalized Estimation Error: 0.4844208307492748, NMSE: 0.48465797218725226, Correlation: 0.7554231004390531, R^2 Score: 0.5109885448417265
# Fold = 3, Alpha = 4, Normalized Estimation Error: 0.36397254659826006, NMSE: 0.3344274287874674, Correlation: 0.8415573618039601, R^2 Score: 0.6625685473445292
# Fold = 3, Alpha = 10, Normalized Estimation Error: 0.445197971448564, NMSE: 0.4365680124386368, Correlation: 0.7776215754773228, R^2 Score: 0.5595104768942285
# Fold = 3, Alpha = 15, Normalized Estimation Error: 0.5140315638779427, NMSE: 0.5167459118366378, Correlation: 0.7264017552315755, R^2 Score: 0.4786123724450114
# Fold = 3, Alpha = 20, Normalized Estimation Error: 0.5157850155136413, NMSE: 0.5372978907437602, Correlation: 0.7037805648771578, R^2 Score: 0.4578757835751369
# Fold = 3, Alpha = 50, Normalized Estimation Error: 0.6255061254718607, NMSE: 0.5498149328233499, Correlation: 0.7016912497003266, R^2 Score: 0.44524630606134785
# Fold = 3, Alpha = 100, Normalized Estimation Error: 0.5730166752526714, NMSE: 0.5806483099544469, Correlation: 0.6808885994706793, R^2 Score: 0.41413596540136577
# Fold = 4, Alpha = 0, Normalized Estimation Error: 0.4925284028118709, NMSE: 0.3941395398985234, Correlation: 0.7921552928563607, R^2 Score: 0.6052822901275479
# Fold = 4, Alpha = 0.1, Normalized Estimation Error: 0.4414772164984113, NMSE: 0.3941202197018931, Correlation: 0.808148659945399, R^2 Score: 0.6053016386653023
# Fold = 4, Alpha = 0.3, Normalized Estimation Error: 0.7170440265577614, NMSE: 0.7458530143552855, Correlation: 0.5539713753948534, R^2 Score: 0.25305288121161074
# Fold = 4, Alpha = 0.5, Normalized Estimation Error: 0.564527398628871, NMSE: 0.5134950568624557, Correlation: 0.7422457739477839, R^2 Score: 0.4857516885320432
# Fold = 4, Alpha = 0.7, Normalized Estimation Error: 0.4225538758771965, NMSE: 0.37300930227048695, Correlation: 0.81781594113574, R^2 Score: 0.6264435240594357
# Fold = 4, Alpha = 0.9, Normalized Estimation Error: 0.6322338473066824, NMSE: 0.6299544968289892, Correlation: 0.6551894092144591, R^2 Score: 0.3691214122383891
# Fold = 4, Alpha = 1, Normalized Estimation Error: 0.5103358467406894, NMSE: 0.45312890524012545, Correlation: 0.7650426944428118, R^2 Score: 0.5462063922857293
# Fold = 4, Alpha = 1.5, Normalized Estimation Error: 0.6165403259574834, NMSE: 0.6256114045659538, Correlation: 0.6648853537318624, R^2 Score: 0.3734708754571048
# Fold = 4, Alpha = 2, Normalized Estimation Error: 0.462797705147445, NMSE: 0.4254038929364103, Correlation: 0.7794440377227188, R^2 Score: 0.5739720748800855
# Fold = 4, Alpha = 2.5, Normalized Estimation Error: 0.7223620394344779, NMSE: 0.6721378934044837, Correlation: 0.6252920029339246, R^2 Score: 0.32687613612321553
# Fold = 4, Alpha = 3, Normalized Estimation Error: 0.5503374499516724, NMSE: 0.5202455212245857, Correlation: 0.729933221642101, R^2 Score: 0.4789913217992825
# Fold = 4, Alpha = 5, Normalized Estimation Error: 0.7133525592661782, NMSE: 0.7525169691296614, Correlation: 0.5439658115359519, R^2 Score: 0.24637915096898533
# Fold = 4, Alpha = 4, Normalized Estimation Error: 0.5050958570244035, NMSE: 0.4214136705542493, Correlation: 0.7761570505956503, R^2 Score: 0.5779681505871153
# Fold = 4, Alpha = 10, Normalized Estimation Error: 0.4654749491399141, NMSE: 0.46237439658031165, Correlation: 0.7467501088212861, R^2 Score: 0.5369473385775337
# Fold = 4, Alpha = 15, Normalized Estimation Error: 0.7089935061255439, NMSE: 0.7112129885822354, Correlation: 0.5879275123216756, R^2 Score: 0.2877437210258079
# Fold = 4, Alpha = 20, Normalized Estimation Error: 0.6380741094012343, NMSE: 0.6483556806507539, Correlation: 0.6448598156944298, R^2 Score: 0.3506932354080742
# Fold = 4, Alpha = 50, Normalized Estimation Error: 0.526625272501799, NMSE: 0.4235583271062686, Correlation: 0.7829772493396421, R^2 Score: 0.575820348002036
# Fold = 4, Alpha = 100, Normalized Estimation Error: 0.6014887668729887, NMSE: 0.6543287820992619, Correlation: 0.6525717962809101, R^2 Score: 0.34471137191577417
# Y_test_predicted: [-2.83812423e+01  1.55114121e-01  3.20688129e+01  2.32206364e+01
#  -9.16708806e+00 -1.02552752e+01  3.10563083e+00 -2.46456971e+01
#  -3.03645374e+01 -1.17501846e+00 -7.04852200e+00 -2.54051258e+01
#  -4.04745834e+00  3.12334688e+00 -1.90289986e+01  1.68383139e+00
#  -7.96556606e+00 -5.54716913e+01 -2.48022300e+01 -2.63851050e+00
#   3.40388262e+01  3.46387550e+01  5.42591536e+00 -1.17212483e+01
#   9.72313157e+00  5.35413363e+00  2.26309622e+00  3.81642676e+01
#   1.33570550e+01  1.65146650e+01 -5.86594827e+00 -9.23462362e+00
#   2.27128668e+01  7.64644245e+00  1.07636326e+01  7.49641509e+00
#   3.87153172e+01 -2.69228227e+01 -1.11086078e+01 -1.56435816e+01
#   2.90853647e+01 -4.71927843e+01  2.39989576e+01 -2.42816465e+01
#   4.59519946e+00 -3.93115424e+00  3.75928297e+00 -1.55699459e+01
#  -3.91538012e+00 -2.42615397e+00  4.67662178e+00 -1.75929898e+01
#  -4.06979659e+01  1.42196156e+01  2.46390022e+01  7.88140580e+00
#  -9.65026794e+00 -1.13104164e+01  2.93017453e+01 -4.14401553e-01
#  -1.91610845e+01  1.18760167e+01 -2.21113891e+01  8.90299016e+00
#  -8.69164771e+00 -7.91238815e+00  4.40699031e+00  6.92320117e+00
#  -2.56959173e+01  1.44226478e+01 -4.23076400e+00  7.60615306e+00
#  -2.26051242e+01  2.91683512e+01  4.60417550e+00 -3.81944400e+01
#   3.45551665e+01  1.80962042e+01 -2.98907432e+01 -3.30952848e+00
#   1.82323433e+01  2.52770465e+01 -1.91854913e+01  3.19285438e-02
#   3.63509034e+01 -5.74988310e+00  8.23404827e+00 -2.33413959e+01
#  -5.34286505e+00 -1.16771506e+00  9.92248539e+00  2.22100897e+01
#   6.16528151e+00  3.92752411e+01  3.20972967e+01 -1.83988410e+01
#  -1.00688561e+01  1.17879256e+01  2.12588131e+01  3.50074070e+01], Y_test: [-24.66984294  10.30899253  25.98403502  10.07270401   6.07910526
#   -7.78811435  13.67545107 -19.37328264 -47.38066567  19.3926741
#   -0.30559555 -29.1350389    0.34353028  18.6573794  -13.43036135
#    4.21691961  26.37560878 -46.33377353 -23.22958149 -32.81563591
#   18.53445885  29.40143063   6.82563359 -11.03690163  -9.64122775
#   13.25011246  23.00625967  50.05458491   3.06389478  -1.30724111
#  -15.48790758  12.81859564  40.6720175    9.04618287   2.1990855
#   10.83228665  62.35105161 -15.17947404   6.00072072   4.42178105
#   31.91162618 -24.23652521  -3.92222566 -33.85418959   3.36360452
#   -1.91648264   1.22748295 -17.74520078   1.81941103  -7.78737137
#   -9.5554251   -3.21056095 -38.76095074  27.34741468   1.15432916
#   -2.73697809  -1.83561864 -22.53420268  18.14890676  23.89468541
#  -35.61739112  23.06689808 -26.65744368  15.74103076  -0.69075609
#   -6.30282077 -22.73051187  -4.92825512  -8.34163207   0.18393588
#  -10.19350758   5.49393097 -46.26103553  42.28823793   7.93187692
#  -18.23037377  35.10131198  18.31652802  -1.9984986   -2.97307442
#    1.1136995   40.58371278 -37.83706692   6.9232108   41.65625912
#  -17.42358958   4.95033603  17.25954943  19.48716371  -6.79137796
#  -13.55865869  13.48423693  10.31685054  25.0970362   20.26969135
#   -9.62980971   2.98785207  -1.75605593  10.31144522  33.05930937]
# Y Test Predicted:  [-2.83812423e+01  1.55114121e-01  3.20688129e+01  2.32206364e+01
#  -9.16708806e+00 -1.02552752e+01  3.10563083e+00 -2.46456971e+01
#  -3.03645374e+01 -1.17501846e+00 -7.04852200e+00 -2.54051258e+01
#  -4.04745834e+00  3.12334688e+00 -1.90289986e+01  1.68383139e+00
#  -7.96556606e+00 -5.54716913e+01 -2.48022300e+01 -2.63851050e+00
#   3.40388262e+01  3.46387550e+01  5.42591536e+00 -1.17212483e+01
#   9.72313157e+00  5.35413363e+00  2.26309622e+00  3.81642676e+01
#   1.33570550e+01  1.65146650e+01 -5.86594827e+00 -9.23462362e+00
#   2.27128668e+01  7.64644245e+00  1.07636326e+01  7.49641509e+00
#   3.87153172e+01 -2.69228227e+01 -1.11086078e+01 -1.56435816e+01
#   2.90853647e+01 -4.71927843e+01  2.39989576e+01 -2.42816465e+01
#   4.59519946e+00 -3.93115424e+00  3.75928297e+00 -1.55699459e+01
#  -3.91538012e+00 -2.42615397e+00  4.67662178e+00 -1.75929898e+01
#  -4.06979659e+01  1.42196156e+01  2.46390022e+01  7.88140580e+00
#  -9.65026794e+00 -1.13104164e+01  2.93017453e+01 -4.14401553e-01
#  -1.91610845e+01  1.18760167e+01 -2.21113891e+01  8.90299016e+00
#  -8.69164771e+00 -7.91238815e+00  4.40699031e+00  6.92320117e+00
#  -2.56959173e+01  1.44226478e+01 -4.23076400e+00  7.60615306e+00
#  -2.26051242e+01  2.91683512e+01  4.60417550e+00 -3.81944400e+01
#   3.45551665e+01  1.80962042e+01 -2.98907432e+01 -3.30952848e+00
#   1.82323433e+01  2.52770465e+01 -1.91854913e+01  3.19285438e-02
#   3.63509034e+01 -5.74988310e+00  8.23404827e+00 -2.33413959e+01
#  -5.34286505e+00 -1.16771506e+00  9.92248539e+00  2.22100897e+01
#   6.16528151e+00  3.92752411e+01  3.20972967e+01 -1.83988410e+01
#  -1.00688561e+01  1.17879256e+01  2.12588131e+01  3.50074070e+01]
# Y Test Actual:  [-24.66984294  10.30899253  25.98403502  10.07270401   6.07910526
#   -7.78811435  13.67545107 -19.37328264 -47.38066567  19.3926741
#   -0.30559555 -29.1350389    0.34353028  18.6573794  -13.43036135
#    4.21691961  26.37560878 -46.33377353 -23.22958149 -32.81563591
#   18.53445885  29.40143063   6.82563359 -11.03690163  -9.64122775
#   13.25011246  23.00625967  50.05458491   3.06389478  -1.30724111
#  -15.48790758  12.81859564  40.6720175    9.04618287   2.1990855
#   10.83228665  62.35105161 -15.17947404   6.00072072   4.42178105
#   31.91162618 -24.23652521  -3.92222566 -33.85418959   3.36360452
#   -1.91648264   1.22748295 -17.74520078   1.81941103  -7.78737137
#   -9.5554251   -3.21056095 -38.76095074  27.34741468   1.15432916
#   -2.73697809  -1.83561864 -22.53420268  18.14890676  23.89468541
#  -35.61739112  23.06689808 -26.65744368  15.74103076  -0.69075609
#   -6.30282077 -22.73051187  -4.92825512  -8.34163207   0.18393588
#  -10.19350758   5.49393097 -46.26103553  42.28823793   7.93187692
#  -18.23037377  35.10131198  18.31652802  -1.9984986   -2.97307442
#    1.1136995   40.58371278 -37.83706692   6.9232108   41.65625912
#  -17.42358958   4.95033603  17.25954943  19.48716371  -6.79137796
#  -13.55865869  13.48423693  10.31685054  25.0970362   20.26969135
#   -9.62980971   2.98785207  -1.75605593  10.31144522  33.05930937]
# Error Record on Training _ After K-Fold CV
# Validation Normalized Estimation Error:  [[0.45410424 0.62560454 0.55552353 0.6542305  0.53076137 0.63255553
#   0.5563917  0.52494102 0.55416287 0.71860796 0.60036734 0.52087626
#   0.71664926 0.57543114 0.70224349 0.41035487 0.47038275 0.5476876 ]
#  [0.52949594 0.74485944 0.4709187  0.4419293  0.62332567 0.74857543
#   0.52822826 0.37496117 0.54568834 0.51700628 0.56183938 0.54136113
#   0.59819289 0.45004554 0.57394921 0.45466182 0.63602791 0.90420799]
#  [0.69149648 0.60893447 0.63324358 0.45550259 0.4510397  0.34477182
#   0.47157915 0.70565276 0.49747556 0.41418668 0.44096037 0.43841948
#   0.68155224 0.55894515 0.72533637 0.52818604 0.5738972  0.42132708]
#  [0.47602059 0.51556202 0.64831209 0.4927446  0.52543282 0.45906102
#   0.4424993  0.40595693 0.68262378 0.58579856 0.63441946 0.48442083
#   0.36397255 0.44519797 0.51403156 0.51578502 0.62550613 0.57301668]
#  [0.4925284  0.44147722 0.71704403 0.5645274  0.42255388 0.63223385
#   0.51033585 0.61654033 0.46279771 0.72236204 0.55033745 0.71335256
#   0.50509586 0.46547495 0.70899351 0.63807411 0.52662527 0.60148877]]
# Validation NMSE Losses:  [[0.46484456 0.64255155 0.67252202 0.76421148 0.56393568 0.65642074
#   0.74330885 0.66081172 0.73196227 0.79909086 0.68895285 0.62354734
#   0.79248233 0.63087042 0.7244139  0.49869961 0.62268908 0.6387787 ]
#  [0.58383901 0.77417907 0.47718689 0.53634203 0.61074643 0.90493182
#   0.52390587 0.44655228 0.5476694  0.55228993 0.63444064 0.51119789
#   0.67664137 0.4971302  0.5360004  0.53581534 0.64724694 0.91470934]
#  [0.72722545 0.68026764 0.60697507 0.53394049 0.51367361 0.40646257
#   0.5560025  0.70586727 0.61501453 0.48305857 0.55283728 0.43366181
#   0.70345851 0.61540936 0.91820255 0.54099604 0.70248916 0.49188672]
#  [0.47236788 0.58853625 0.52973771 0.4827519  0.49631741 0.51219833
#   0.43135583 0.38933832 0.64454318 0.53208929 0.64389782 0.48465797
#   0.33442743 0.43656801 0.51674591 0.53729789 0.54981493 0.58064831]
#  [0.39413954 0.39412022 0.74585301 0.51349506 0.3730093  0.6299545
#   0.45312891 0.6256114  0.42540389 0.67213789 0.52024552 0.75251697
#   0.42141367 0.4623744  0.71121299 0.64835568 0.42355833 0.65432878]]
# Validation Correlations:  [[0.79325276 0.68974098 0.64916092 0.60324282 0.71381423 0.66293127
#   0.64543369 0.68264249 0.593382   0.58648349 0.65828811 0.66987637
#   0.59180617 0.69247544 0.59448233 0.73652024 0.67799258 0.65521667]
#  [0.6727289  0.55053732 0.74205579 0.7063819  0.66056374 0.42430852
#   0.72571968 0.76513985 0.70500822 0.71078127 0.66177934 0.70983845
#   0.60912204 0.73513671 0.70751548 0.70805052 0.62758634 0.39866946]
#  [0.55730715 0.61602939 0.66703039 0.71452459 0.74325578 0.79165015
#   0.7032173  0.57891887 0.67327903 0.75939447 0.71549557 0.79448757
#   0.6139735  0.66832438 0.44156463 0.71148117 0.59457102 0.74431105]
#  [0.75414807 0.68025509 0.7043713  0.75937902 0.74329272 0.73512956
#   0.78116116 0.81016829 0.6242476  0.71405088 0.65105143 0.7554231
#   0.84155736 0.77762158 0.72640176 0.70378056 0.70169125 0.6808886 ]
#  [0.79215529 0.80814866 0.55397138 0.74224577 0.81781594 0.65518941
#   0.76504269 0.66488535 0.77944404 0.625292   0.72993322 0.54396581
#   0.77615705 0.74675011 0.58792751 0.64485982 0.78297725 0.6525718 ]]
# Validation R2 Scores:  [[0.52592653 0.34469138 0.31412588 0.22061604 0.42486808 0.33054684
#   0.24193367 0.32606868 0.25350553 0.18504418 0.29736884 0.36407289
#   0.19178391 0.35660443 0.26120376 0.49139932 0.3649482  0.34853914]
#  [0.41413485 0.22313423 0.52115709 0.46179665 0.38713405 0.09192772
#   0.47427597 0.55189801 0.45042998 0.44579341 0.3633576  0.48702806
#   0.32101042 0.50114457 0.46213947 0.46232517 0.35050686 0.08211626]
#  [0.27243247 0.31941237 0.39273942 0.46580835 0.48608477 0.59334623
#   0.44373596 0.2938007  0.38469617 0.5167142  0.44690267 0.5661342
#   0.29621059 0.38430116 0.08136554 0.45874948 0.29718039 0.5078819 ]
#  [0.52338904 0.40617717 0.46550388 0.51291174 0.49922438 0.4832008
#   0.56476947 0.60716441 0.34966716 0.46313117 0.35031831 0.51098854
#   0.66256855 0.55951048 0.47861237 0.45787578 0.44524631 0.41413597]
#  [0.60528229 0.60530164 0.25305288 0.48575169 0.62644352 0.36912141
#   0.54620639 0.37347088 0.57397207 0.32687614 0.47899132 0.24637915
#   0.57796815 0.53694734 0.28774372 0.35069324 0.57582035 0.34471137]]
# Error Report on Testing _ With best Lambda
# Alpha chosen for model:  0.7
# Test Normalized Estimation Error:  0.4117219604419109
# Test NMSE Loss:  0.4368787572435695
# Test R2 Loss:  0.559549845859027
# Test Correlation:  0.7702582973589334

# %%
# Set up a figure to hold all the subplots
plt.figure(figsize=(15, 10))

# Plot each specified slice in a different subplot
plt.subplot(3, 2, 1)  # 3 rows, 2 columns, 1st subplot
plt.plot(objective_function_values[0, 0, :], label='[0,0,:]')
plt.title('[Sep 1 Fac 1]')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')

plt.subplot(3, 2, 2)  # 3 rows, 2 columns, 2nd subplot
plt.plot(objective_function_values[0, 1, :], label='[0,1,:]')
plt.title('[Sep1 Fac2]')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')

plt.subplot(3, 2, 3)  # 3 rows, 2 columns, 3rd subplot
plt.plot(objective_function_values[0, 2, :], label='[0,2,:]')
plt.title('Core')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')

plt.subplot(3, 2, 4)  # 3 rows, 2 columns, 4th subplot
plt.plot(objective_function_values[1, 0, :], label='[1,0,:]')
plt.title('Sep 2 Fac 1')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')

plt.subplot(3, 2, 5)  # 3 rows, 2 columns, 5th subplot
plt.plot(objective_function_values[1, 1, :], label='[1,1,:]')
plt.title('Sep 2 Fac 2')
plt.xlabel('Iteration')
plt.ylabel('Objective Function Value')

plt.subplot(3, 2, 6)  # 3 rows, 2 columns, 5th subplot
plt.plot(objective_function_values[1, 2, :], label='[1,1,:]')
plt.title('Global Loss')
plt.xlabel('Iteration')
plt.ylabel('Global Function Value')

# Adjust the layout so that all subplots are spaced nicely
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Tensor Pipeline

# %% [markdown]
# ## Install Libraries

# %%
# %pip install dill
# Out:
# Requirement already satisfied: dill in /Users/lakrama/miniconda3/envs/torchtensor/lib/python3.12/site-packages (0.3.8)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import Google Drive Files

# %%
from google.colab import drive
from google.colab import files

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append("/content/gdrive/MyDrive/Colab Notebooks/Tensor_Based_LRR/Proper Experiments/The Pipeline/2D_Separable/Rama")

# %% [markdown]
# ## Import Libraries

# %%
#Import sklearn stuff
import datetime
import numpy as np

#Used to load data from pkl file
import dill

#Import External Files
from KFoldCV import KFoldCV
from train_test import train_test
from DataGenerationB import *

# %% [markdown]
# ## Import Data

# %%
import pickle
pkl_file = "/content/gdrive/MyDrive/Colab Notebooks/Tensor_Based_LRR/Proper Experiments/The Pipeline/Experimental Data/64-64-4-4/Bounded_Var_Time:2024-03-25 16:16:51, intercept:0,n_train:5000, n_test:1000, tensor_dimensions:[64 64], tensor_mode_ranks:[4 4], separation_rank:1.pkl"
file= open(pkl_file, 'rb')
data = pickle.load(file)
file.close()

X_train_Full = data[0]
print(data[0].shape)

Y_train_Full = data[1]
print(data[1].shape)

X_test_Full = data[2]
print(data[2].shape)

Y_test_Full = data[3]
print(data[3].shape)

B_tensored = data[4]
print(data[4].shape)
# Out:
# (5000, 64, 64)
# (5000,)
# (1000, 64, 64)
# (1000,)
# (64, 64)

# %% [markdown]
# ## Subset Data

# %%
n_train =5000
n_test = 400

tensor_dimensions = np.array([16, 16])
tensor_mode_ranks = np.array([4, 4])
separation_rank = 1

#Subset X_train and Y_train
X_train = X_train_Full[0:(n_train),:,:]
Y_train = Y_train_Full[0:(n_train)]

#Subset X_test and Y_test
X_test = X_test_Full[0:(n_test),:,:]
Y_test = Y_test_Full[0:(n_test)]

# %% [markdown]
# ## KFoldCV

# %%
#For now, define finite alpha set that we are searching over
alphas = [0,0.1,0.3, 0.5, 0.7, 0.9, 1, 1.5, 2, 2.5, 3, 5, 4,10,15,20,50,100]

#Define Number of Folds we want
k_folds = 10
hypers = {'max_iter': 200, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank}
lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information = KFoldCV(X_train, Y_train, B_tensored, alphas, k_folds, hypers, intercept= False)
# Out:
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# Fold = 0, Alpha = 0, Normalized Estimation Error: 1.0356563106012021e-08, NMSE: 8.465045480026895e-08, Correlation: 0.9999999577102991, R^2 Score: 0.9999999150361017
# Fold = 0, Alpha = 0.1, Normalized Estimation Error: 1.0335208016522006e-08, NMSE: 8.48220233146135e-08, Correlation: 0.9999999576603952, R^2 Score: 0.9999999148638979
# Fold = 0, Alpha = 0.3, Normalized Estimation Error: 1.1029444482401096e-08, NMSE: 8.656111550560683e-08, Correlation: 0.9999999568876904, R^2 Score: 0.9999999131183662
# Fold = 0, Alpha = 0.5, Normalized Estimation Error: 3.265521677506295e-08, NMSE: 1.0507557894756599e-07, Correlation: 0.9999999484138102, R^2 Score: 0.9999998945353474
# Fold = 0, Alpha = 0.7, Normalized Estimation Error: 1.3516569401533609e-08, NMSE: 8.960849679213264e-08, Correlation: 0.9999999557396053, R^2 Score: 0.9999999100597011
# Fold = 0, Alpha = 0.9, Normalized Estimation Error: 1.3084264093354148e-08, NMSE: 8.795991744027374e-08, Correlation: 0.9999999563418964, R^2 Score: 0.9999999117143848
# Fold = 0, Alpha = 1, Normalized Estimation Error: 1.8558524380384465e-08, NMSE: 9.7363083523341e-08, Correlation: 0.9999999519080776, R^2 Score: 0.9999999022764007
# Fold = 0, Alpha = 1.5, Normalized Estimation Error: 1.7838655499026848e-08, NMSE: 9.395889675025705e-08, Correlation: 0.9999999536362045, R^2 Score: 0.9999999056931925
# Fold = 0, Alpha = 2, Normalized Estimation Error: 2.187298216398629e-08, NMSE: 9.677357957730458e-08, Correlation: 0.9999999527587276, R^2 Score: 0.9999999028680875
# Fold = 0, Alpha = 2.5, Normalized Estimation Error: 3.967464012362545e-08, NMSE: 1.1673765467654565e-07, Correlation: 0.9999999431598243, R^2 Score: 0.9999998828300894
# Fold = 0, Alpha = 3, Normalized Estimation Error: 2.74059702092239e-08, NMSE: 1.0546343638610287e-07, Correlation: 0.9999999485487001, R^2 Score: 0.9999998941460538
# Fold = 0, Alpha = 5, Normalized Estimation Error: 1.0095140712348706e-07, NMSE: 1.8137844626387856e-07, Correlation: 0.9999999141572139, R^2 Score: 0.9999998179499461
# Fold = 0, Alpha = 4, Normalized Estimation Error: 9.674005864739676e-08, NMSE: 1.7331913170051477e-07, Correlation: 0.9999999206254863, R^2 Score: 0.9999998260391026
# Fold = 0, Alpha = 10, Normalized Estimation Error: 1.1010053388347215e-07, NMSE: 1.9546891066458433e-07, Correlation: 0.9999999133451293, R^2 Score: 0.9999998038073076
# Fold = 0, Alpha = 15, Normalized Estimation Error: 2.1942167911382986e-07, NMSE: 2.913668534689144e-07, Correlation: 0.9999998792918675, R^2 Score: 0.999999707554274
# Fold = 0, Alpha = 20, Normalized Estimation Error: 3.4609442897475987e-07, NMSE: 4.2618909647249137e-07, Correlation: 0.9999998257215367, R^2 Score: 0.9999995722328117
# Fold = 0, Alpha = 50, Normalized Estimation Error: 1.3234539547809059e-06, NMSE: 1.4528611335153398e-06, Correlation: 0.999999541008939, R^2 Score: 0.999998541759216
# Fold = 0, Alpha = 100, Normalized Estimation Error: 5.692044075158597e-06, NMSE: 5.9477175257922915e-06, Correlation: 0.9999982620284426, R^2 Score: 0.9999940302592807
# Fold = 1, Alpha = 0, Normalized Estimation Error: 1.0387608973362109e-08, NMSE: 1.0000160121844459e-07, Correlation: 0.9999999506186757, R^2 Score: 0.9999998999662647
# Fold = 1, Alpha = 0.1, Normalized Estimation Error: 1.0395167616721435e-08, NMSE: 1.0004662433272637e-07, Correlation: 0.9999999506333753, R^2 Score: 0.9999998999212271
# Fold = 1, Alpha = 0.3, Normalized Estimation Error: 1.0791958858396855e-08, NMSE: 1.0047446892245827e-07, Correlation: 0.9999999504960453, R^2 Score: 0.9999998994932451
# Fold = 1, Alpha = 0.5, Normalized Estimation Error: 1.1603813109012557e-08, NMSE: 1.006527895931637e-07, Correlation: 0.9999999505525397, R^2 Score: 0.9999998993148671
# Fold = 1, Alpha = 0.7, Normalized Estimation Error: 1.0116803333512314e-07, NMSE: 1.791927192313283e-07, Correlation: 0.9999999122180071, R^2 Score: 0.9999998207496997
# Fold = 1, Alpha = 0.9, Normalized Estimation Error: 1.7050397799494416e-08, NMSE: 1.073213492546341e-07, Correlation: 0.9999999475855422, R^2 Score: 0.9999998926441646
# Fold = 1, Alpha = 1, Normalized Estimation Error: 1.213192881326474e-08, NMSE: 1.0143948933039551e-07, Correlation: 0.9999999502543696, R^2 Score: 0.9999998985279145
# Fold = 1, Alpha = 1.5, Normalized Estimation Error: 2.3103964424415726e-08, NMSE: 1.1225476541027293e-07, Correlation: 0.9999999456104703, R^2 Score: 0.9999998877091631
# Fold = 1, Alpha = 2, Normalized Estimation Error: 2.4398566147720253e-08, NMSE: 1.130794948358237e-07, Correlation: 0.9999999451523198, R^2 Score: 0.9999998868841686
# Fold = 1, Alpha = 2.5, Normalized Estimation Error: 3.1586125448033246e-08, NMSE: 1.1698438151500595e-07, Correlation: 0.9999999437520883, R^2 Score: 0.9999998829780272
# Fold = 1, Alpha = 3, Normalized Estimation Error: 4.3787974129157926e-08, NMSE: 1.2787343699043196e-07, Correlation: 0.9999999380930661, R^2 Score: 0.9999998720854727
# Fold = 1, Alpha = 5, Normalized Estimation Error: 8.402696962866197e-08, NMSE: 1.6013923927645342e-07, Correlation: 0.9999999246832202, R^2 Score: 0.9999998398093023
# Fold = 1, Alpha = 4, Normalized Estimation Error: 6.243412410643191e-08, NMSE: 1.469882156232278e-07, Correlation: 0.9999999306037934, R^2 Score: 0.9999998529645518
# Fold = 1, Alpha = 10, Normalized Estimation Error: 1.765424870869191e-07, NMSE: 2.5698679425814826e-07, Correlation: 0.9999998837806627, R^2 Score: 0.9999997429306268
# Fold = 1, Alpha = 15, Normalized Estimation Error: 2.0803232386072452e-07, NMSE: 2.833128415831102e-07, Correlation: 0.9999998677967938, R^2 Score: 0.9999997165961199
# Fold = 1, Alpha = 20, Normalized Estimation Error: 3.0133701376697233e-07, NMSE: 3.6987903354892146e-07, Correlation: 0.9999998409872677, R^2 Score: 0.9999996300021111
# Fold = 1, Alpha = 50, Normalized Estimation Error: 1.5472582653803806e-06, NMSE: 1.585618308142362e-06, Correlation: 0.9999995779582235, R^2 Score: 0.9999984138721761
# Fold = 1, Alpha = 100, Normalized Estimation Error: 5.862891991465253e-06, NMSE: 5.693784265315818e-06, Correlation: 0.999998797854476, R^2 Score: 0.9999943043861186
# Fold = 2, Alpha = 0, Normalized Estimation Error: 1.0173394046436223e-08, NMSE: 8.49730479537385e-08, Correlation: 0.9999999578887175, R^2 Score: 0.9999999150189649
# Fold = 2, Alpha = 0.1, Normalized Estimation Error: 1.9457100945572868e-08, NMSE: 9.059767538788255e-08, Correlation: 0.9999999551518041, R^2 Score: 0.9999999093938087
# Fold = 2, Alpha = 0.3, Normalized Estimation Error: 1.0309419319169713e-08, NMSE: 8.526183434500395e-08, Correlation: 0.9999999576939423, R^2 Score: 0.9999999147301514
# Fold = 2, Alpha = 0.5, Normalized Estimation Error: 1.097388220115412e-08, NMSE: 8.595767511987063e-08, Correlation: 0.9999999573328519, R^2 Score: 0.9999999140342452
# Fold = 2, Alpha = 0.7, Normalized Estimation Error: 1.2687836972901047e-08, NMSE: 8.759288553211432e-08, Correlation: 0.9999999564568732, R^2 Score: 0.999999912398881
# Fold = 2, Alpha = 0.9, Normalized Estimation Error: 1.5792705506803963e-08, NMSE: 8.862465008648085e-08, Correlation: 0.9999999558845231, R^2 Score: 0.9999999113670195
# Fold = 2, Alpha = 1, Normalized Estimation Error: 1.522731022267792e-08, NMSE: 8.942919733835271e-08, Correlation: 0.999999955505454, R^2 Score: 0.9999999105623966
# Fold = 2, Alpha = 1.5, Normalized Estimation Error: 1.5349386872764115e-08, NMSE: 8.957106397164866e-08, Correlation: 0.9999999554753093, R^2 Score: 0.9999999104205166
# Fold = 2, Alpha = 2, Normalized Estimation Error: 3.873418395219282e-08, NMSE: 1.0488853189408673e-07, Correlation: 0.9999999476498679, R^2 Score: 0.9999998951016089
# Fold = 2, Alpha = 2.5, Normalized Estimation Error: 4.59896374549557e-08, NMSE: 1.1426204918496718e-07, Correlation: 0.9999999429787784, R^2 Score: 0.9999998857272105
# Fold = 2, Alpha = 3, Normalized Estimation Error: 3.420945175786084e-08, NMSE: 1.0378455255212089e-07, Correlation: 0.9999999482321451, R^2 Score: 0.9999998962056921
# Fold = 2, Alpha = 5, Normalized Estimation Error: 5.3502583870878674e-08, NMSE: 1.2127371449189488e-07, Correlation: 0.9999999396012277, R^2 Score: 0.9999998787148862
# Fold = 2, Alpha = 4, Normalized Estimation Error: 5.584422070801799e-08, NMSE: 1.2231051616869363e-07, Correlation: 0.9999999390810236, R^2 Score: 0.999999877677987
# Fold = 2, Alpha = 10, Normalized Estimation Error: 1.580162569069844e-07, NMSE: 2.120046284194546e-07, Correlation: 0.9999998967983724, R^2 Score: 0.9999997879754439
# Fold = 2, Alpha = 15, Normalized Estimation Error: 1.612956244881214e-07, NMSE: 2.066684781011691e-07, Correlation: 0.9999998983734563, R^2 Score: 0.9999997933120958
# Fold = 2, Alpha = 20, Normalized Estimation Error: 3.1496721907218197e-07, NMSE: 3.4757373939850004e-07, Correlation: 0.9999998397195019, R^2 Score: 0.9999996523935898
# Fold = 2, Alpha = 50, Normalized Estimation Error: 1.6119299174051447e-06, NMSE: 1.505616798841818e-06, Correlation: 0.9999994004489978, R^2 Score: 0.9999984942416781
# Fold = 2, Alpha = 100, Normalized Estimation Error: 4.433192387884274e-06, NMSE: 3.8627389200916846e-06, Correlation: 0.9999986614696664, R^2 Score: 0.9999961368979949
# Fold = 3, Alpha = 0, Normalized Estimation Error: 1.0328841313324778e-08, NMSE: 1.0492087342039822e-07, Correlation: 0.9999999477527567, R^2 Score: 0.9999998949525668
# Fold = 3, Alpha = 0.1, Normalized Estimation Error: 1.0355391319901851e-08, NMSE: 1.0502430234868586e-07, Correlation: 0.9999999476625426, R^2 Score: 0.9999998948490131
# Fold = 3, Alpha = 0.3, Normalized Estimation Error: 1.0856978373179849e-08, NMSE: 1.0589769626845193e-07, Correlation: 0.9999999471881266, R^2 Score: 0.9999998939745657
# Fold = 3, Alpha = 0.5, Normalized Estimation Error: 1.1300353396757285e-08, NMSE: 1.069382008114037e-07, Correlation: 0.999999946666863, R^2 Score: 0.999999892932806
# Fold = 3, Alpha = 0.7, Normalized Estimation Error: 1.1755033542126053e-08, NMSE: 1.0766480829592296e-07, Correlation: 0.9999999462924177, R^2 Score: 0.9999998922053221
# Fold = 3, Alpha = 0.9, Normalized Estimation Error: 1.2912827512288601e-08, NMSE: 1.0918984423565177e-07, Correlation: 0.9999999455497426, R^2 Score: 0.9999998906784466
# Fold = 3, Alpha = 1, Normalized Estimation Error: 1.7538405899172515e-08, NMSE: 1.1483430803142144e-07, Correlation: 0.9999999426609216, R^2 Score: 0.9999998850271742
# Fold = 3, Alpha = 1.5, Normalized Estimation Error: 1.9928737142137007e-08, NMSE: 1.1851521173447631e-07, Correlation: 0.9999999409001987, R^2 Score: 0.9999998813418305
# Fold = 3, Alpha = 2, Normalized Estimation Error: 3.631688652900042e-08, NMSE: 1.3829498143839288e-07, Correlation: 0.999999931206795, R^2 Score: 0.9999998615382016
# Fold = 3, Alpha = 2.5, Normalized Estimation Error: 2.8401496900734237e-08, NMSE: 1.2931922709514112e-07, Correlation: 0.9999999358665642, R^2 Score: 0.9999998705247829
# Fold = 3, Alpha = 3, Normalized Estimation Error: 3.088618001798574e-08, NMSE: 1.2973059988019163e-07, Correlation: 0.9999999357338005, R^2 Score: 0.9999998701129139
# Fold = 3, Alpha = 5, Normalized Estimation Error: 1.4229942400956628e-07, NMSE: 2.589380483736413e-07, Correlation: 0.9999998728286843, R^2 Score: 0.9999997407496102
# Fold = 3, Alpha = 4, Normalized Estimation Error: 6.299504841182932e-08, NMSE: 1.664526565721712e-07, Correlation: 0.9999999184110989, R^2 Score: 0.9999998333465616
# Fold = 3, Alpha = 10, Normalized Estimation Error: 2.581241484429157e-07, NMSE: 3.925948259233384e-07, Correlation: 0.9999998085959096, R^2 Score: 0.9999996069316105
# Fold = 3, Alpha = 15, Normalized Estimation Error: 1.9975469000634872e-07, NMSE: 3.132740550012266e-07, Correlation: 0.9999998524207871, R^2 Score: 0.9999996863480612
# Fold = 3, Alpha = 20, Normalized Estimation Error: 2.8037525225856814e-07, NMSE: 4.387426533433413e-07, Correlation: 0.9999998021009803, R^2 Score: 0.9999995607281177
# Fold = 3, Alpha = 50, Normalized Estimation Error: 7.765443137443567e-07, NMSE: 1.033105044941198e-06, Correlation: 0.9999995495282484, R^2 Score: 0.9999989656487823
# Fold = 3, Alpha = 100, Normalized Estimation Error: 4.247758336771285e-06, NMSE: 4.932577623495605e-06, Correlation: 0.9999982032069936, R^2 Score: 0.9999950614725037
# Fold = 4, Alpha = 0, Normalized Estimation Error: 1.0297437936889843e-08, NMSE: 9.113643154379551e-08, Correlation: 0.9999999542410304, R^2 Score: 0.9999999084034473
# Fold = 4, Alpha = 0.1, Normalized Estimation Error: 1.0452905397128733e-08, NMSE: 9.183236137877714e-08, Correlation: 0.9999999538997209, R^2 Score: 0.9999999077040039
# Fold = 4, Alpha = 0.3, Normalized Estimation Error: 1.0634958728959337e-08, NMSE: 9.240935346721905e-08, Correlation: 0.9999999536312435, R^2 Score: 0.9999999071240988
# Fold = 4, Alpha = 0.5, Normalized Estimation Error: 1.1224299823766265e-08, NMSE: 9.227865734527505e-08, Correlation: 0.999999953725639, R^2 Score: 0.9999999072554547
# Fold = 4, Alpha = 0.7, Normalized Estimation Error: 1.1843112093277245e-08, NMSE: 9.488314173675791e-08, Correlation: 0.9999999524300333, R^2 Score: 0.9999999046378211
# Fold = 4, Alpha = 0.9, Normalized Estimation Error: 1.4457594391655537e-08, NMSE: 9.913113972420474e-08, Correlation: 0.9999999503068483, R^2 Score: 0.9999999003683762
# Fold = 4, Alpha = 1, Normalized Estimation Error: 1.261946877837601e-07, NMSE: 2.4119549643205275e-07, Correlation: 0.999999879736757, R^2 Score: 0.9999997575867782
# Fold = 4, Alpha = 1.5, Normalized Estimation Error: 1.8645895321914008e-08, NMSE: 1.0532084284107492e-07, Correlation: 0.9999999474308725, R^2 Score: 0.9999998941474231
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e7e4bce929d7> in <cell line: 7>()
#       5 k_folds = 10
#       6 hypers = {'max_iter': 200, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank}
# ----> 7 lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information = KFoldCV(X_train, Y_train, B_tensored, alphas, k_folds, hypers, intercept= False)
#
# /content/gdrive/MyDrive/Colab Notebooks/Tensor_Based_LRR/Proper Experiments/The Pipeline/2D_Separable/Rama/KFoldCV.py in KFoldCV(X_train, Y_train, B_tensored, alphas, k_folds, hypers, intercept)
#      36       hypers['weight_decay'] = alpha1
#      37
# ---> 38       lsr_ten, objective_function_values = lsr_bcd_regression(lsr_tensors[index1][fold], X_train_updated, Y_train_updated, hypers, intercept = need_intercept)
#      39       expanded_lsr = lsr_ten.expand_to_tensor()
#      40       expanded_lsr = np.reshape(expanded_lsr, X_validation[0].shape, order='F')
#
# /content/gdrive/MyDrive/Colab Notebooks/Tensor_Based_LRR/Proper Experiments/The Pipeline/2D_Separable/Rama/lsr_bcd_regression.py in lsr_bcd_regression(lsr_ten, training_data, training_labels, hypers, intercept)
#      41
#      42                 X, y = training_data, training_labels
# ---> 43                 X_tilde, y_tilde = lsr_ten.bcd_factor_update_x_y(s, k, X, y) #y tilde should now be y-b-<Q,X>
#      44
#      45
#
# /content/gdrive/MyDrive/Colab Notebooks/Tensor_Based_LRR/Proper Experiments/The Pipeline/2D_Separable/Rama/LSR_Tensor_2D_v1.py in bcd_factor_update_x_y(self, s, k, x, y)
#      77
#      78         omega = x_partial_unfold @ kronecker_term @ core_tensor_term
# ---> 79         omega = np.transpose(omega, (0, 2, 1))
#      80         omega = np.reshape(omega, newshape = (omega.shape[0], -1))
#      81
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py in _transpose_dispatcher(a, axes)
#     582
#     583
# --> 584 def _transpose_dispatcher(a, axes=None):
#     585     return (a,)
#     586
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train + Test Block

# %%
hypers = {'max_iter': 200, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank}
normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values = train_test(X_train, Y_train, X_test, Y_test, B_tensored, lambda1, hypers, intercept= False)

# %% [markdown]
# ## Save Results

# %%
#Get current time and store in variable
formatted_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
max_iter = hypers['max_iter']
pkl_file = f"/content/gdrive/MyDrive/Colab Notebooks/Tensor_Based_LRR/Proper Experiments/The Pipeline/Experimental Results/64-64-4-4/New_25_March_2024/Tensor Based/ExecutionTime_intercept_0_{formatted_time}, n_train_{n_train},n_test_{n_test}, tensor_dimensions:{tensor_dimensions}, tensor_mode_= ranks:{tensor_mode_ranks}, separation_rank:{separation_rank}, max_iter={max_iter}.pkl"

# %%
print("Error Record on Training _ After K-Fold CV")
print("Validation Normalized Estimation Error: ", validation_normalized_estimation_error)
print("Validation NMSE Losses: ", validation_nmse_losses)
print("Validation Correlations: ", validation_correlations)
print("Validation R2 Scores: ", validation_R2_scores)

# %%
print("Error Report on Testing _ With best Lambda")
print("Alpha chosen for model: ", lambda1)
print("Test Normalized Estimation Error: ", normalized_estimation_error)
print("Test NMSE Loss: ", test_nmse_loss)
print("Test R2 Loss: ", test_R2_loss)
print("Test Correlation: ", test_correlation)

# %%
with open(pkl_file, "wb") as file:
    dill.dump((X_train_Full, Y_train_Full, X_test_Full, Y_test_Full, B_tensored, lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information, normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values), file)

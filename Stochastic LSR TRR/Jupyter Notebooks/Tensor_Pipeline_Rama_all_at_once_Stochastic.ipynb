# %% [markdown]
# # Tensor Pipeline

# %% [markdown]
# ## Setting Path

# %%
import sys
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Code Files')
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Data')

# %% [markdown]
# ## Import Libraries

# %%
import datetime
import numpy as np
import dill
from KFoldCV import KFoldCV
from train_test import train_test
from sgd_optimization import SGD
from DataGenerationB import *
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import Data

# %%
import pickle
pkl_file = "/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Data_Sets/Synthetic Data/Uncentered X/Bounded_Var_Time:2024-04-15 19:35:40, intercept:5,n_train:5000, n_test:1000, tensor_dimensions:[32 32], tensor_mode_ranks:[4 4], separation_rank:2.pkl"
file= open(pkl_file, 'rb')
data = pickle.load(file)
file.close()

X_train_Full = data[0]
print(data[0].shape)

Y_train_Full = data[1]
print(data[1].shape)

X_test_Full = data[2]
print(data[2].shape)

Y_test_Full = data[3]
print(data[3].shape)

B_tensored = data[4]
print(data[4].shape)
# Out:
# (5000, 32, 32)
# (5000,)
# (1000, 32, 32)
# (1000,)
# (32, 32)

# %% [markdown]
# ## Subset Data

# %%
n_train_all = [500]
n_test = 100

tensor_dimensions = np.array([32, 32])
tensor_mode_ranks = np.array([4, 4])
separation_rank = 2

# %%
for i,n_train in enumerate(n_train_all):
  print('Number of Samples:',n_train,'---------------------------------------------------------------------------------------------------------------------------')

  #Subset X_train and Y_train
  X_train = X_train_Full[0:(n_train),:,:]
  Y_train = Y_train_Full[0:(n_train)]

  #Subset X_test and Y_test
  X_test = X_test_Full[0:(n_test),:,:]
  Y_test = Y_test_Full[0:(n_test)]

  #Preprocessing

  # Reshape the 3D array to a 2D array where each row represents a sample
  # The shape of the original 3D array is (n_samples, n_features_per_sample, n_dimensions)
  # We reshape it to (n_samples, n_features_per_sample * n_dimensions)


  X_train_2D = X_train.reshape(n_train, -1)
  X_test_2D = X_test.reshape(n_test,-1)


  # Initialize StandardScaler
  scaler = StandardScaler(with_std = False) #standard scalar only

  # Fit scaler on train data and transform train data
  X_train_scaled = scaler.fit_transform(X_train_2D)
  # Transform test data using the scaler fitted on train data
  X_test_scaled = scaler.transform(X_test_2D)

  # Reshape the scaled data back to 3D
  X_train = X_train_scaled.reshape(n_train, tensor_dimensions[0],tensor_dimensions[1])
  X_test  = X_test_scaled.reshape(n_test, tensor_dimensions[0],tensor_dimensions[1])

  #average response value
  Y_train_mean = np.mean(Y_train)
  # Mean centering y_train and y_test
  Y_train = Y_train - Y_train_mean


  print("Sample mean for each feature (across samples):",scaler.mean_)
  print("Sample variance for each feature (across samples):",scaler.var_)
  print('Response Average:',Y_train_mean)

  #For now, define finite alpha set that we are searching over
  alphas = [4]#[0,0.1,0.3, 0.5, 0.7, 0.9, 1, 1.5, 2, 2.5, 3, 5, 4,10,15,20,50,100]

  #Define Number of Folds we want
  
  k_folds = 5
  learning_rate = 0.000003
  epochs = 50
  batch_size = 32

  hypers = {'max_iter': 10, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
  lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information,gradient_information = KFoldCV(X_train, Y_train, alphas, k_folds, hypers,B_tensored ,intercept= False) 

  hypers = {'max_iter': 10, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
  normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values,gradient_values = train_test(X_train, Y_train, X_test, Y_test, lambda1, hypers, Y_train_mean,B_tensored,intercept= False)

  #Get current time and store in variable
  formatted_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  max_iter = hypers['max_iter']
  pkl_file = f"/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Experimental Results/Synthetic Data/ExecutionTime_intercept_5_{formatted_time}, n_train_{n_train},n_test_{n_test}, tensor_dimensions:{tensor_dimensions}, tensor_mode_= ranks:{tensor_mode_ranks}, separation_rank:{separation_rank}, max_iter={max_iter}.pkl"

  print("Error Record on Training _ After K-Fold CV")
  print("Validation Normalized Estimation Error: ", validation_normalized_estimation_error)
  print("Validation NMSE Losses: ", validation_nmse_losses)
  print("Validation Correlations: ", validation_correlations)
  print("Validation R2 Scores: ", validation_R2_scores)

  print("Error Report on Testing _ With best Lambda")
  print("Alpha chosen for model: ", lambda1)
  print("Test Normalized Estimation Error: ", normalized_estimation_error)
  print("Test NMSE Loss: ", test_nmse_loss)
  print("Test R2 Loss: ", test_R2_loss)
  print("Test Correlation: ", test_correlation)

  with open(pkl_file, "wb") as file:
    dill.dump((X_train_Full, Y_train_Full, X_test_Full, Y_test_Full, B_tensored, lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information, normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values,gradient_information,gradient_values), file)
# Out:
# Number of Samples: 500 ---------------------------------------------------------------------------------------------------------------------------
# Sample mean for each feature (across samples): [4.97839165 4.97277469 5.02654444 ... 5.02464395 4.98090313 5.01347675]
# Sample variance for each feature (across samples): None
# Response Average: 83.22110233978201
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# Epoch [1/50], Loss: 2050594.5000, Gap to Optimality: 2050594.5000, NMSE: 0.9316658973693848, Correlation: 0.3859909294516067, R2: 0.0682759483597345
# Epoch [2/50], Loss: 1951666.0000, Gap to Optimality: 1951666.0000, NMSE: 0.886716902256012, Correlation: 0.4216265581212148, R2: 0.11322779497712254
# Epoch [3/50], Loss: 1887900.0000, Gap to Optimality: 1887900.0000, NMSE: 0.8577432036399841, Correlation: 0.43538219333501516, R2: 0.14220325017899327
# Epoch [4/50], Loss: 1843164.6250, Gap to Optimality: 1843164.6250, NMSE: 0.8374156951904297, Correlation: 0.44393841974899156, R2: 0.16253202479256057
# Epoch [5/50], Loss: 1810764.3750, Gap to Optimality: 1810764.3750, NMSE: 0.8226926326751709, Correlation: 0.45088928337161305, R2: 0.1772560460212853
# Epoch [6/50], Loss: 1786248.5000, Gap to Optimality: 1786248.5000, NMSE: 0.8115518093109131, Correlation: 0.4564862484216918, R2: 0.18839751995074405
# Epoch [7/50], Loss: 1766841.7500, Gap to Optimality: 1766841.7500, NMSE: 0.8027324676513672, Correlation: 0.46196101162312136, R2: 0.19721753288452726
# Epoch [8/50], Loss: 1751162.5000, Gap to Optimality: 1751162.5000, NMSE: 0.7956066727638245, Correlation: 0.4670448714561628, R2: 0.20434370789774658
# Epoch [9/50], Loss: 1737687.7500, Gap to Optimality: 1737687.7500, NMSE: 0.7894825339317322, Correlation: 0.4714555652238638, R2: 0.21046820555154666
# Epoch [10/50], Loss: 1726434.8750, Gap to Optimality: 1726434.8750, NMSE: 0.7843681573867798, Correlation: 0.4758968014908686, R2: 0.2155829233675325
# Epoch [11/50], Loss: 1716410.1250, Gap to Optimality: 1716410.1250, NMSE: 0.779811680316925, Correlation: 0.479377716644232, R2: 0.22013963368581813
# Epoch [12/50], Loss: 1707422.7500, Gap to Optimality: 1707422.7500, NMSE: 0.7757264971733093, Correlation: 0.4824056843707467, R2: 0.22422513602509975
# Epoch [13/50], Loss: 1699663.3750, Gap to Optimality: 1699663.3750, NMSE: 0.7721993923187256, Correlation: 0.4853261805535508, R2: 0.22775239822235338
# Epoch [14/50], Loss: 1692536.2500, Gap to Optimality: 1692536.2500, NMSE: 0.7689595818519592, Correlation: 0.48780251752253284, R2: 0.2309924884363025
# Epoch [15/50], Loss: 1686100.2500, Gap to Optimality: 1686100.2500, NMSE: 0.7660338282585144, Correlation: 0.49031597454159664, R2: 0.2339183780526375
# Epoch [16/50], Loss: 1680230.5000, Gap to Optimality: 1680230.5000, NMSE: 0.7633655071258545, Correlation: 0.4927422305231888, R2: 0.23658684508861794
# Epoch [17/50], Loss: 1675038.8750, Gap to Optimality: 1675038.8750, NMSE: 0.7610051035881042, Correlation: 0.4947531131734627, R2: 0.23894739410570787
# Epoch [18/50], Loss: 1670052.7500, Gap to Optimality: 1670052.7500, NMSE: 0.7587383985519409, Correlation: 0.4967207649541507, R2: 0.2412143191079129
# Epoch [19/50], Loss: 1665404.8750, Gap to Optimality: 1665404.8750, NMSE: 0.7566251754760742, Correlation: 0.4985439728894582, R2: 0.24332761132180336
# Epoch [20/50], Loss: 1661210.3750, Gap to Optimality: 1661210.3750, NMSE: 0.7547178268432617, Correlation: 0.5001981010987697, R2: 0.24523505184222438
# Epoch [21/50], Loss: 1657177.1250, Gap to Optimality: 1657177.1250, NMSE: 0.7528840899467468, Correlation: 0.5018324132213213, R2: 0.24706895819098573
# Epoch [22/50], Loss: 1653539.5000, Gap to Optimality: 1653539.5000, NMSE: 0.7512300610542297, Correlation: 0.503325427708889, R2: 0.2487230654317203
# Epoch [23/50], Loss: 1650015.2500, Gap to Optimality: 1650015.2500, NMSE: 0.749627411365509, Correlation: 0.5045888717141361, R2: 0.25032587886837443
# Epoch [24/50], Loss: 1646932.2500, Gap to Optimality: 1646932.2500, NMSE: 0.7482252717018127, Correlation: 0.505743417864638, R2: 0.2517280149839004
# Epoch [25/50], Loss: 1643860.7500, Gap to Optimality: 1643860.7500, NMSE: 0.7468284368515015, Correlation: 0.5068427374408662, R2: 0.25312496426618025
# Epoch [26/50], Loss: 1641096.7500, Gap to Optimality: 1641096.7500, NMSE: 0.7455714344978333, Correlation: 0.5080402260164893, R2: 0.2543820286565568
# Epoch [27/50], Loss: 1638495.1250, Gap to Optimality: 1638495.1250, NMSE: 0.7443881630897522, Correlation: 0.5090350655673334, R2: 0.25556539361748287
# Epoch [28/50], Loss: 1635998.2500, Gap to Optimality: 1635998.2500, NMSE: 0.7432523965835571, Correlation: 0.5099442307873376, R2: 0.2567012768973498
# Epoch [29/50], Loss: 1633749.8750, Gap to Optimality: 1633749.8750, NMSE: 0.742229700088501, Correlation: 0.510774274434367, R2: 0.25772397889529985
# Epoch [30/50], Loss: 1631531.5000, Gap to Optimality: 1631531.5000, NMSE: 0.7412204742431641, Correlation: 0.5115401034519499, R2: 0.25873324099965356
# Epoch [31/50], Loss: 1629410.8750, Gap to Optimality: 1629410.8750, NMSE: 0.7402560114860535, Correlation: 0.5124794210912668, R2: 0.25969784245605254
# Epoch [32/50], Loss: 1627423.5000, Gap to Optimality: 1627423.5000, NMSE: 0.7393519282341003, Correlation: 0.5133777529888304, R2: 0.26060198601370443
# Epoch [33/50], Loss: 1625617.6250, Gap to Optimality: 1625617.6250, NMSE: 0.7385303378105164, Correlation: 0.5140142285733228, R2: 0.26142357474312483
# Epoch [34/50], Loss: 1623883.6250, Gap to Optimality: 1623883.6250, NMSE: 0.7377414107322693, Correlation: 0.5148014192119991, R2: 0.262212589200586
# Epoch [35/50], Loss: 1622289.6250, Gap to Optimality: 1622289.6250, NMSE: 0.7370161414146423, Correlation: 0.5154916433314715, R2: 0.26293787930752655
# Epoch [36/50], Loss: 1620774.8750, Gap to Optimality: 1620774.8750, NMSE: 0.7363268136978149, Correlation: 0.5159682445301628, R2: 0.2636272508040637
# Epoch [37/50], Loss: 1619253.5000, Gap to Optimality: 1619253.5000, NMSE: 0.7356346845626831, Correlation: 0.5166135977404632, R2: 0.26431945565926185
# Epoch [38/50], Loss: 1617778.2500, Gap to Optimality: 1617778.2500, NMSE: 0.7349632382392883, Correlation: 0.5171718302505743, R2: 0.2649909086198121
# Epoch [39/50], Loss: 1616503.3750, Gap to Optimality: 1616503.3750, NMSE: 0.7343830466270447, Correlation: 0.5176188867330611, R2: 0.265571170532104
# Epoch [40/50], Loss: 1615224.6250, Gap to Optimality: 1615224.6250, NMSE: 0.7338009476661682, Correlation: 0.518014630966972, R2: 0.2661532953744672
# Epoch [41/50], Loss: 1614105.5000, Gap to Optimality: 1614105.5000, NMSE: 0.7332914471626282, Correlation: 0.5183521592845697, R2: 0.26666283190580653
# Epoch [42/50], Loss: 1612984.8750, Gap to Optimality: 1612984.8750, NMSE: 0.7327812314033508, Correlation: 0.5187008917017601, R2: 0.26717303040285734
# Epoch [43/50], Loss: 1611961.3750, Gap to Optimality: 1611961.3750, NMSE: 0.7323154211044312, Correlation: 0.5191874118831559, R2: 0.26763889848389366
# Epoch [44/50], Loss: 1610915.8750, Gap to Optimality: 1610915.8750, NMSE: 0.7318394184112549, Correlation: 0.5195463448613721, R2: 0.2681149344550915
# Epoch [45/50], Loss: 1609953.1250, Gap to Optimality: 1609953.1250, NMSE: 0.7314009666442871, Correlation: 0.5198498240839621, R2: 0.26855334001082676
# Epoch [46/50], Loss: 1609021.8750, Gap to Optimality: 1609021.8750, NMSE: 0.7309770584106445, Correlation: 0.5202031051212865, R2: 0.2689773881163986
# Epoch [47/50], Loss: 1608223.2500, Gap to Optimality: 1608223.2500, NMSE: 0.7306134700775146, Correlation: 0.520548478462534, R2: 0.2693409562098149
# Epoch [48/50], Loss: 1607470.2500, Gap to Optimality: 1607470.2500, NMSE: 0.7302704453468323, Correlation: 0.520846487603707, R2: 0.2696840002132702
# Epoch [49/50], Loss: 1606600.7500, Gap to Optimality: 1606600.7500, NMSE: 0.7298744916915894, Correlation: 0.5211901549374883, R2: 0.27007998038492464
# Epoch [50/50], Loss: 1605825.2500, Gap to Optimality: 1605825.2500, NMSE: 0.7295213341712952, Correlation: 0.5214987114067895, R2: 0.270433115685348
# Epoch [1/50], Loss: 2058194.5000, Gap to Optimality: 2058194.5000, NMSE: 0.9351189732551575, Correlation: 0.5677446493476126, R2: 0.06482274476899919
# Epoch [2/50], Loss: 1937393.7500, Gap to Optimality: 1937393.7500, NMSE: 0.8802322149276733, Correlation: 0.6345323502553164, R2: 0.11971288364251054
# Epoch [3/50], Loss: 1834127.7500, Gap to Optimality: 1834127.7500, NMSE: 0.833311140537262, Correlation: 0.653651277980998, R2: 0.16663683819194264
# Epoch [4/50], Loss: 1745048.6250, Gap to Optimality: 1745048.6250, NMSE: 0.7928351163864136, Correlation: 0.6631104884586946, R2: 0.207115400818359
# Epoch [5/50], Loss: 1667825.5000, Gap to Optimality: 1667825.5000, NMSE: 0.757745087146759, Correlation: 0.6693213448121691, R2: 0.24220770703605865
# Epoch [6/50], Loss: 1600867.5000, Gap to Optimality: 1600867.5000, NMSE: 0.7273184061050415, Correlation: 0.6741001125740463, R2: 0.27263618881986174
# Epoch [7/50], Loss: 1542419.6250, Gap to Optimality: 1542419.6250, NMSE: 0.7007579803466797, Correlation: 0.678149524759569, R2: 0.29919824333607514
# Epoch [8/50], Loss: 1491509.2500, Gap to Optimality: 1491509.2500, NMSE: 0.6776219606399536, Correlation: 0.6817974464475443, R2: 0.32233576476271797
# Epoch [9/50], Loss: 1446498.0000, Gap to Optimality: 1446498.0000, NMSE: 0.6571658849716187, Correlation: 0.6850052951856324, R2: 0.3427930835428501
# Epoch [10/50], Loss: 1406929.3750, Gap to Optimality: 1406929.3750, NMSE: 0.6391826868057251, Correlation: 0.6880762473309604, R2: 0.36077746304724045
# Epoch [11/50], Loss: 1371686.1250, Gap to Optimality: 1371686.1250, NMSE: 0.6231645345687866, Correlation: 0.6908542042187822, R2: 0.37679655898577513
# Epoch [12/50], Loss: 1340324.7500, Gap to Optimality: 1340324.7500, NMSE: 0.6089101433753967, Correlation: 0.6934982666149133, R2: 0.39105190094266273
# Epoch [13/50], Loss: 1312511.3750, Gap to Optimality: 1312511.3750, NMSE: 0.5962677597999573, Correlation: 0.6960702758548016, R2: 0.4036950385810433
# Epoch [14/50], Loss: 1287420.8750, Gap to Optimality: 1287420.8750, NMSE: 0.5848624110221863, Correlation: 0.6984486179293039, R2: 0.41510106947795433
# Epoch [15/50], Loss: 1264967.7500, Gap to Optimality: 1264967.7500, NMSE: 0.5746557116508484, Correlation: 0.7007784976404225, R2: 0.4253084178343436
# Epoch [16/50], Loss: 1244641.8750, Gap to Optimality: 1244641.8750, NMSE: 0.5654154419898987, Correlation: 0.7029967536725903, R2: 0.4345493243108868
# Epoch [17/50], Loss: 1226108.1250, Gap to Optimality: 1226108.1250, NMSE: 0.5569894909858704, Correlation: 0.7050950100071132, R2: 0.4429758064220841
# Epoch [18/50], Loss: 1209259.3750, Gap to Optimality: 1209259.3750, NMSE: 0.5493291616439819, Correlation: 0.7070691649389974, R2: 0.45063656027779264
# Epoch [19/50], Loss: 1193937.8750, Gap to Optimality: 1193937.8750, NMSE: 0.5423628091812134, Correlation: 0.7090152791723116, R2: 0.4576033042090407
# Epoch [20/50], Loss: 1179852.7500, Gap to Optimality: 1179852.7500, NMSE: 0.5359585285186768, Correlation: 0.7108471742278941, R2: 0.4640080964306518
# Epoch [21/50], Loss: 1166964.2500, Gap to Optimality: 1166964.2500, NMSE: 0.5300978422164917, Correlation: 0.7126516313244853, R2: 0.46986910129273196
# Epoch [22/50], Loss: 1155013.6250, Gap to Optimality: 1155013.6250, NMSE: 0.524663507938385, Correlation: 0.7143326580577917, R2: 0.4753038218109781
# Epoch [23/50], Loss: 1143928.5000, Gap to Optimality: 1143928.5000, NMSE: 0.5196223258972168, Correlation: 0.7159326081193579, R2: 0.48034527976075936
# Epoch [24/50], Loss: 1133699.6250, Gap to Optimality: 1133699.6250, NMSE: 0.5149703621864319, Correlation: 0.7175181591208797, R2: 0.4849975234299648
# Epoch [25/50], Loss: 1124164.2500, Gap to Optimality: 1124164.2500, NMSE: 0.510633647441864, Correlation: 0.7190070592142102, R2: 0.48933447397445196
# Epoch [26/50], Loss: 1115325.0000, Gap to Optimality: 1115325.0000, NMSE: 0.5066132545471191, Correlation: 0.7204707591343432, R2: 0.49335511425987766
# Epoch [27/50], Loss: 1107077.1250, Gap to Optimality: 1107077.1250, NMSE: 0.5028617978096008, Correlation: 0.7218952763620252, R2: 0.4971068612369346
# Epoch [28/50], Loss: 1099342.2500, Gap to Optimality: 1099342.2500, NMSE: 0.4993434250354767, Correlation: 0.7232483449523925, R2: 0.5006254090654173
# Epoch [29/50], Loss: 1092079.6250, Gap to Optimality: 1092079.6250, NMSE: 0.4960396885871887, Correlation: 0.7245311851187812, R2: 0.5039293474051323
# Epoch [30/50], Loss: 1085237.5000, Gap to Optimality: 1085237.5000, NMSE: 0.49292707443237305, Correlation: 0.725773857983939, R2: 0.5070421848850619
# Epoch [31/50], Loss: 1078819.8750, Gap to Optimality: 1078819.8750, NMSE: 0.4900074601173401, Correlation: 0.7269863073558875, R2: 0.5099619388016035
# Epoch [32/50], Loss: 1072752.0000, Gap to Optimality: 1072752.0000, NMSE: 0.4872468411922455, Correlation: 0.728141901296736, R2: 0.5127227568276427
# Epoch [33/50], Loss: 1067007.7500, Gap to Optimality: 1067007.7500, NMSE: 0.48463329672813416, Correlation: 0.7292516934491696, R2: 0.5153364486227112
# Epoch [34/50], Loss: 1061584.8750, Gap to Optimality: 1061584.8750, NMSE: 0.4821659028530121, Correlation: 0.7302956761929693, R2: 0.5178040407175502
# Epoch [35/50], Loss: 1056436.1250, Gap to Optimality: 1056436.1250, NMSE: 0.47982314229011536, Correlation: 0.7313264130154783, R2: 0.5201469111825598
# Epoch [36/50], Loss: 1051551.8750, Gap to Optimality: 1051551.8750, NMSE: 0.47760045528411865, Correlation: 0.7323206635991184, R2: 0.5223697452489257
# Epoch [37/50], Loss: 1046925.7500, Gap to Optimality: 1046925.7500, NMSE: 0.47549527883529663, Correlation: 0.7332641625808743, R2: 0.5244750493784234
# Epoch [38/50], Loss: 1042504.1875, Gap to Optimality: 1042504.1875, NMSE: 0.4734830856323242, Correlation: 0.7341819500237129, R2: 0.5264873567105154
# Epoch [39/50], Loss: 1038297.2500, Gap to Optimality: 1038297.2500, NMSE: 0.47156843543052673, Correlation: 0.7350648888908891, R2: 0.5284021578847008
# Epoch [40/50], Loss: 1034305.7500, Gap to Optimality: 1034305.7500, NMSE: 0.46975183486938477, Correlation: 0.7359379616198173, R2: 0.5302188679887324
# Epoch [41/50], Loss: 1030494.8750, Gap to Optimality: 1030494.8750, NMSE: 0.4680173099040985, Correlation: 0.7367802547328994, R2: 0.5319534877423766
# Epoch [42/50], Loss: 1026853.0000, Gap to Optimality: 1026853.0000, NMSE: 0.4663596749305725, Correlation: 0.7375961106585369, R2: 0.533611259108955
# Epoch [43/50], Loss: 1023362.3750, Gap to Optimality: 1023362.3750, NMSE: 0.46477073431015015, Correlation: 0.7383530918576181, R2: 0.5352002662993067
# Epoch [44/50], Loss: 1020032.1875, Gap to Optimality: 1020032.1875, NMSE: 0.46325474977493286, Correlation: 0.739096016017773, R2: 0.5367163513716076
# Epoch [45/50], Loss: 1016823.1875, Gap to Optimality: 1016823.1875, NMSE: 0.46179383993148804, Correlation: 0.7398060220092194, R2: 0.5381773526766249
# Epoch [46/50], Loss: 1013770.6250, Gap to Optimality: 1013770.6250, NMSE: 0.4604041874408722, Correlation: 0.7405067244884244, R2: 0.5395670969634847
# Epoch [47/50], Loss: 1010834.1875, Gap to Optimality: 1010834.1875, NMSE: 0.4590672552585602, Correlation: 0.7411754229283131, R2: 0.5409041265577508
# Epoch [48/50], Loss: 1008015.0625, Gap to Optimality: 1008015.0625, NMSE: 0.45778369903564453, Correlation: 0.7418089339331396, R2: 0.5421877554698687
# Epoch [49/50], Loss: 1005327.7500, Gap to Optimality: 1005327.7500, NMSE: 0.4565601050853729, Correlation: 0.7424456358642869, R2: 0.543411407932183
# Epoch [50/50], Loss: 1002726.0000, Gap to Optimality: 1002726.0000, NMSE: 0.45537540316581726, Correlation: 0.7430445057439798, R2: 0.5445962086449514
# Epoch [1/50], Loss: 774583.3125, Gap to Optimality: 774583.3125, NMSE: 0.742452085018158, Correlation: 0.7783199478053161, R2: 0.2575369836734016
# Epoch [2/50], Loss: 600748.3125, Gap to Optimality: 600748.3125, NMSE: 0.5758203864097595, Correlation: 0.8192077583481832, R2: 0.4241712023894625
# Epoch [3/50], Loss: 491197.7188, Gap to Optimality: 491197.7188, NMSE: 0.4708053171634674, Correlation: 0.8322706478178393, R2: 0.5291877847797212
# Epoch [4/50], Loss: 420691.5312, Gap to Optimality: 420691.5312, NMSE: 0.4032151401042938, Correlation: 0.8398643846040712, R2: 0.5967789356708051
# Epoch [5/50], Loss: 373545.6562, Gap to Optimality: 373545.6562, NMSE: 0.3580167591571808, Correlation: 0.8454582603310495, R2: 0.6419780201446099
# Epoch [6/50], Loss: 341886.7500, Gap to Optimality: 341886.7500, NMSE: 0.3276638388633728, Correlation: 0.8500964120943239, R2: 0.6723313445882946
# Epoch [7/50], Loss: 319398.5625, Gap to Optimality: 319398.5625, NMSE: 0.3061019480228424, Correlation: 0.8538790723093602, R2: 0.6938935579865616
# Epoch [8/50], Loss: 303051.4375, Gap to Optimality: 303051.4375, NMSE: 0.29042693972587585, Correlation: 0.8569078956430581, R2: 0.709568780126568
# Epoch [9/50], Loss: 291069.9062, Gap to Optimality: 291069.9062, NMSE: 0.27893736958503723, Correlation: 0.8596135586024511, R2: 0.7210585452942113
# Epoch [10/50], Loss: 282061.0312, Gap to Optimality: 282061.0312, NMSE: 0.27029770612716675, Correlation: 0.8619032245564318, R2: 0.7296983316965329
# Epoch [11/50], Loss: 275064.7812, Gap to Optimality: 275064.7812, NMSE: 0.26358774304389954, Correlation: 0.8638916949766894, R2: 0.7364083716515732
# Epoch [12/50], Loss: 269511.6875, Gap to Optimality: 269511.6875, NMSE: 0.25826144218444824, Correlation: 0.8655737139413074, R2: 0.74173478567708
# Epoch [13/50], Loss: 265085.3438, Gap to Optimality: 265085.3438, NMSE: 0.25401571393013, Correlation: 0.867146808690747, R2: 0.7459805779948367
# Epoch [14/50], Loss: 261357.8438, Gap to Optimality: 261357.8438, NMSE: 0.25043994188308716, Correlation: 0.8684362477671222, R2: 0.7495564104290064
# Epoch [15/50], Loss: 258330.0625, Gap to Optimality: 258330.0625, NMSE: 0.24753528833389282, Correlation: 0.8696082742293052, R2: 0.7524610900837579
# Epoch [16/50], Loss: 255786.1875, Gap to Optimality: 255786.1875, NMSE: 0.24509471654891968, Correlation: 0.8706266246821786, R2: 0.7549016998096469
# Epoch [17/50], Loss: 253604.7188, Gap to Optimality: 253604.7188, NMSE: 0.2430015504360199, Correlation: 0.8714483923790808, R2: 0.75699489633929
# Epoch [18/50], Loss: 251726.7031, Gap to Optimality: 251726.7031, NMSE: 0.2411995381116867, Correlation: 0.8722423991385172, R2: 0.7587969412782309
# Epoch [19/50], Loss: 250121.2188, Gap to Optimality: 250121.2188, NMSE: 0.23965895175933838, Correlation: 0.8729461461898596, R2: 0.7603375204408152
# Epoch [20/50], Loss: 248709.4219, Gap to Optimality: 248709.4219, NMSE: 0.2383042275905609, Correlation: 0.8735963854835904, R2: 0.7616922781443576
# Epoch [21/50], Loss: 247458.6719, Gap to Optimality: 247458.6719, NMSE: 0.23710386455059052, Correlation: 0.8741463765888862, R2: 0.7628926697498692
# Epoch [22/50], Loss: 246337.0156, Gap to Optimality: 246337.0156, NMSE: 0.23602725565433502, Correlation: 0.8746390608992497, R2: 0.7639692897645147
# Epoch [23/50], Loss: 245352.2812, Gap to Optimality: 245352.2812, NMSE: 0.23508208990097046, Correlation: 0.875104995428157, R2: 0.7649144516804657
# Epoch [24/50], Loss: 244478.5938, Gap to Optimality: 244478.5938, NMSE: 0.2342435121536255, Correlation: 0.8755180422356678, R2: 0.7657530616902359
# Epoch [25/50], Loss: 243705.0000, Gap to Optimality: 243705.0000, NMSE: 0.23350103199481964, Correlation: 0.8759082421908214, R2: 0.7664955355322847
# Epoch [26/50], Loss: 242992.8906, Gap to Optimality: 242992.8906, NMSE: 0.23281745612621307, Correlation: 0.876258353194503, R2: 0.767179123326915
# Epoch [27/50], Loss: 242342.1562, Gap to Optimality: 242342.1562, NMSE: 0.232192724943161, Correlation: 0.8765699517872213, R2: 0.7678038648063749
# Epoch [28/50], Loss: 241754.5938, Gap to Optimality: 241754.5938, NMSE: 0.23162859678268433, Correlation: 0.8768493115354731, R2: 0.7683680312916658
# Epoch [29/50], Loss: 241230.0938, Gap to Optimality: 241230.0938, NMSE: 0.23112501204013824, Correlation: 0.8771114902205381, R2: 0.7688716086726048
# Epoch [30/50], Loss: 240750.2656, Gap to Optimality: 240750.2656, NMSE: 0.2306642383337021, Correlation: 0.8773449504999883, R2: 0.7693323625589302
# Epoch [31/50], Loss: 240316.4375, Gap to Optimality: 240316.4375, NMSE: 0.2302476167678833, Correlation: 0.8775565162382544, R2: 0.7697490087106589
# Epoch [32/50], Loss: 239898.2188, Gap to Optimality: 239898.2188, NMSE: 0.22984610497951508, Correlation: 0.8777804752390752, R2: 0.7701505335909049
# Epoch [33/50], Loss: 239522.0469, Gap to Optimality: 239522.0469, NMSE: 0.2294849157333374, Correlation: 0.8779819225896759, R2: 0.7705117207253382
# Epoch [34/50], Loss: 239175.0312, Gap to Optimality: 239175.0312, NMSE: 0.22915153205394745, Correlation: 0.8781417664259825, R2: 0.7708451079832536
# Epoch [35/50], Loss: 238859.0000, Gap to Optimality: 238859.0000, NMSE: 0.22884801030158997, Correlation: 0.8783016708977358, R2: 0.7711486352435333
# Epoch [36/50], Loss: 238564.1719, Gap to Optimality: 238564.1719, NMSE: 0.22856485843658447, Correlation: 0.8784573342717876, R2: 0.7714318076458185
# Epoch [37/50], Loss: 238294.7188, Gap to Optimality: 238294.7188, NMSE: 0.22830599546432495, Correlation: 0.8785916032841234, R2: 0.7716906707896133
# Epoch [38/50], Loss: 238042.7344, Gap to Optimality: 238042.7344, NMSE: 0.2280638962984085, Correlation: 0.8787208190170948, R2: 0.7719327648333737
# Epoch [39/50], Loss: 237798.6094, Gap to Optimality: 237798.6094, NMSE: 0.2278294861316681, Correlation: 0.878857751491906, R2: 0.7721671784239711
# Epoch [40/50], Loss: 237580.4531, Gap to Optimality: 237580.4531, NMSE: 0.22761988639831543, Correlation: 0.8789712479203892, R2: 0.7723767800632995
# Epoch [41/50], Loss: 237381.7344, Gap to Optimality: 237381.7344, NMSE: 0.22742894291877747, Correlation: 0.8790685193102057, R2: 0.7725677290325712
# Epoch [42/50], Loss: 237193.7812, Gap to Optimality: 237193.7812, NMSE: 0.22724829614162445, Correlation: 0.8791674663825884, R2: 0.77274839110829
# Epoch [43/50], Loss: 237024.2344, Gap to Optimality: 237024.2344, NMSE: 0.2270854264497757, Correlation: 0.8792627309440786, R2: 0.772911240001918
# Epoch [44/50], Loss: 236853.7344, Gap to Optimality: 236853.7344, NMSE: 0.22692152857780457, Correlation: 0.8793453901365801, R2: 0.7730751507063809
# Epoch [45/50], Loss: 236702.2031, Gap to Optimality: 236702.2031, NMSE: 0.22677573561668396, Correlation: 0.8794132029991906, R2: 0.7732209453976671
# Epoch [46/50], Loss: 236557.2344, Gap to Optimality: 236557.2344, NMSE: 0.2266363650560379, Correlation: 0.8794857569741604, R2: 0.7733603214740543
# Epoch [47/50], Loss: 236424.2344, Gap to Optimality: 236424.2344, NMSE: 0.22650836408138275, Correlation: 0.8795474025651535, R2: 0.7734883264139221
# Epoch [48/50], Loss: 236301.4062, Gap to Optimality: 236301.4062, NMSE: 0.22639034688472748, Correlation: 0.8796175408901883, R2: 0.7736063452773261
# Epoch [49/50], Loss: 236183.6719, Gap to Optimality: 236183.6719, NMSE: 0.22627712786197662, Correlation: 0.879680444395508, R2: 0.7737195616328378
# Epoch [50/50], Loss: 236076.1250, Gap to Optimality: 236076.1250, NMSE: 0.2261737585067749, Correlation: 0.879740346098797, R2: 0.7738229353213261
# Epoch [1/50], Loss: 864312.1250, Gap to Optimality: 864312.1250, NMSE: 0.8284600377082825, Correlation: 0.8019505011888761, R2: 0.17152778361257126
# Epoch [2/50], Loss: 735724.6875, Gap to Optimality: 735724.6875, NMSE: 0.7052008509635925, Correlation: 0.8431302411703202, R2: 0.2947888366332436
# Epoch [3/50], Loss: 634858.3750, Gap to Optimality: 634858.3750, NMSE: 0.6085112690925598, Correlation: 0.8542294330207533, R2: 0.3914798699513341
# Epoch [4/50], Loss: 555253.0000, Gap to Optimality: 555253.0000, NMSE: 0.5321993827819824, Correlation: 0.8599781179580348, R2: 0.46779281028556374
# Epoch [5/50], Loss: 492088.2188, Gap to Optimality: 492088.2188, NMSE: 0.47164565324783325, Correlation: 0.8640018764421219, R2: 0.5283474442539116
# Epoch [6/50], Loss: 441804.8438, Gap to Optimality: 441804.8438, NMSE: 0.4234388470649719, Correlation: 0.8673435698493583, R2: 0.57655496043171
# Epoch [7/50], Loss: 401412.2812, Gap to Optimality: 401412.2812, NMSE: 0.3847125172615051, Correlation: 0.8703613501630877, R2: 0.6152818388991972
# Epoch [8/50], Loss: 368715.6562, Gap to Optimality: 368715.6562, NMSE: 0.35336318612098694, Correlation: 0.8730292324239, R2: 0.6466316360427016
# Epoch [9/50], Loss: 342122.9688, Gap to Optimality: 342122.9688, NMSE: 0.3278648853302002, Correlation: 0.8755102280335798, R2: 0.6721303141515726
# Epoch [10/50], Loss: 320293.0000, Gap to Optimality: 320293.0000, NMSE: 0.30693212151527405, Correlation: 0.8778612441868786, R2: 0.6930633975457154
# Epoch [11/50], Loss: 302197.3438, Gap to Optimality: 302197.3438, NMSE: 0.2895791530609131, Correlation: 0.8800435888203149, R2: 0.710416619118361
# Epoch [12/50], Loss: 287118.0938, Gap to Optimality: 287118.0938, NMSE: 0.2751179337501526, Correlation: 0.8821331272777844, R2: 0.7248780219178652
# Epoch [13/50], Loss: 274440.2500, Gap to Optimality: 274440.2500, NMSE: 0.2629588842391968, Correlation: 0.8840769162598572, R2: 0.7370372471075513
# Epoch [14/50], Loss: 263624.2812, Gap to Optimality: 263624.2812, NMSE: 0.25258490443229675, Correlation: 0.8859346069441287, R2: 0.7474113817075448
# Epoch [15/50], Loss: 254361.5938, Gap to Optimality: 254361.5938, NMSE: 0.24370014667510986, Correlation: 0.887692341244258, R2: 0.7562962648979026
# Epoch [16/50], Loss: 246359.8438, Gap to Optimality: 246359.8438, NMSE: 0.23602443933486938, Correlation: 0.8893803107732722, R2: 0.7639721121755051
# Epoch [17/50], Loss: 239385.8594, Gap to Optimality: 239385.8594, NMSE: 0.22933416068553925, Correlation: 0.8909680455662582, R2: 0.7706624766656203
# Epoch [18/50], Loss: 233273.5156, Gap to Optimality: 233273.5156, NMSE: 0.22347013652324677, Correlation: 0.8925038397133505, R2: 0.7765265889114996
# Epoch [19/50], Loss: 227841.2188, Gap to Optimality: 227841.2188, NMSE: 0.21825821697711945, Correlation: 0.8939319990956867, R2: 0.7817385716669845
# Epoch [20/50], Loss: 223023.0156, Gap to Optimality: 223023.0156, NMSE: 0.21363525092601776, Correlation: 0.8952968783305595, R2: 0.7863616282383654
# Epoch [21/50], Loss: 218675.9062, Gap to Optimality: 218675.9062, NMSE: 0.20946401357650757, Correlation: 0.896597617377167, R2: 0.7905329247894398
# Epoch [22/50], Loss: 214746.0625, Gap to Optimality: 214746.0625, NMSE: 0.20569300651550293, Correlation: 0.8978346140900653, R2: 0.7943039902858817
# Epoch [23/50], Loss: 211172.4375, Gap to Optimality: 211172.4375, NMSE: 0.20226365327835083, Correlation: 0.8990168995295383, R2: 0.7977333923214117
# Epoch [24/50], Loss: 207907.0469, Gap to Optimality: 207907.0469, NMSE: 0.19912990927696228, Correlation: 0.9001455534822385, R2: 0.8008671647914757
# Epoch [25/50], Loss: 204911.1094, Gap to Optimality: 204911.1094, NMSE: 0.1962546706199646, Correlation: 0.9012158208128125, R2: 0.80374246512622
# Epoch [26/50], Loss: 202154.0469, Gap to Optimality: 202154.0469, NMSE: 0.19360855221748352, Correlation: 0.9022415607320563, R2: 0.8063886162612823
# Epoch [27/50], Loss: 199598.4688, Gap to Optimality: 199598.4688, NMSE: 0.19115570187568665, Correlation: 0.9032033315953462, R2: 0.8088415034334006
# Epoch [28/50], Loss: 197222.2344, Gap to Optimality: 197222.2344, NMSE: 0.18887494504451752, Correlation: 0.9041524062428093, R2: 0.8111223062003179
# Epoch [29/50], Loss: 195010.5781, Gap to Optimality: 195010.5781, NMSE: 0.18675199151039124, Correlation: 0.9050335393382414, R2: 0.8132452647146666
# Epoch [30/50], Loss: 192939.0312, Gap to Optimality: 192939.0312, NMSE: 0.18476347625255585, Correlation: 0.9058729125633606, R2: 0.815233808280172
# Epoch [31/50], Loss: 191000.6875, Gap to Optimality: 191000.6875, NMSE: 0.1829027533531189, Correlation: 0.906672727290841, R2: 0.8170945827474687
# Epoch [32/50], Loss: 189178.3281, Gap to Optimality: 189178.3281, NMSE: 0.1811533123254776, Correlation: 0.9074506482096105, R2: 0.8188440351382817
# Epoch [33/50], Loss: 187464.5312, Gap to Optimality: 187464.5312, NMSE: 0.1795080155134201, Correlation: 0.9081844631938865, R2: 0.8204893551000307
# Epoch [34/50], Loss: 185844.9531, Gap to Optimality: 185844.9531, NMSE: 0.17795304954051971, Correlation: 0.9088781329610353, R2: 0.822044337939269
# Epoch [35/50], Loss: 184315.7812, Gap to Optimality: 184315.7812, NMSE: 0.1764848828315735, Correlation: 0.9095407642554394, R2: 0.8235125297553113
# Epoch [36/50], Loss: 182877.7500, Gap to Optimality: 182877.7500, NMSE: 0.17510421574115753, Correlation: 0.9101890780872423, R2: 0.8248932179185169
# Epoch [37/50], Loss: 181501.9219, Gap to Optimality: 181501.9219, NMSE: 0.173783078789711, Correlation: 0.9107847471205965, R2: 0.8262143845587897
# Epoch [38/50], Loss: 180198.0312, Gap to Optimality: 180198.0312, NMSE: 0.17253103852272034, Correlation: 0.9113703233186932, R2: 0.8274664424384137
# Epoch [39/50], Loss: 178961.3906, Gap to Optimality: 178961.3906, NMSE: 0.17134347558021545, Correlation: 0.9119254642509075, R2: 0.8286540087142562
# Epoch [40/50], Loss: 177785.0469, Gap to Optimality: 177785.0469, NMSE: 0.17021387815475464, Correlation: 0.912467597398179, R2: 0.8297836362771073
# Epoch [41/50], Loss: 176670.8125, Gap to Optimality: 176670.8125, NMSE: 0.16914376616477966, Correlation: 0.9129703178032762, R2: 0.8308537627647016
# Epoch [42/50], Loss: 175610.8750, Gap to Optimality: 175610.8750, NMSE: 0.16812583804130554, Correlation: 0.9134651988073407, R2: 0.8318716931798213
# Epoch [43/50], Loss: 174596.9688, Gap to Optimality: 174596.9688, NMSE: 0.1671520322561264, Correlation: 0.9139296086247042, R2: 0.83284551895357
# Epoch [44/50], Loss: 173624.2812, Gap to Optimality: 173624.2812, NMSE: 0.16621780395507812, Correlation: 0.9143832676116069, R2: 0.8337797634351525
# Epoch [45/50], Loss: 172699.8438, Gap to Optimality: 172699.8438, NMSE: 0.16532982885837555, Correlation: 0.9148123258544477, R2: 0.8346677502276548
# Epoch [46/50], Loss: 171813.2656, Gap to Optimality: 171813.2656, NMSE: 0.16447827219963074, Correlation: 0.9152364385776534, R2: 0.8355193303380235
# Epoch [47/50], Loss: 170966.9844, Gap to Optimality: 170966.9844, NMSE: 0.1636652946472168, Correlation: 0.9156346342992558, R2: 0.8363323182662488
# Epoch [48/50], Loss: 170156.0625, Gap to Optimality: 170156.0625, NMSE: 0.16288632154464722, Correlation: 0.9160218785708079, R2: 0.837111291750038
# Epoch [49/50], Loss: 169376.0781, Gap to Optimality: 169376.0781, NMSE: 0.1621369868516922, Correlation: 0.916385303127211, R2: 0.8378606516715286
# Epoch [50/50], Loss: 168626.4688, Gap to Optimality: 168626.4688, NMSE: 0.16141670942306519, Correlation: 0.9167324435419633, R2: 0.8385809213074814
# Epoch [1/50], Loss: 185575.7969, Gap to Optimality: 185575.7969, NMSE: 0.9616172313690186, Correlation: 0.21588023162855152, R2: 0.03831431272074681
# Epoch [2/50], Loss: 178350.1875, Gap to Optimality: 178350.1875, NMSE: 0.9241741895675659, Correlation: 0.34805702666086974, R2: 0.07576000787004
# Epoch [3/50], Loss: 172572.9688, Gap to Optimality: 172572.9688, NMSE: 0.8942358493804932, Correlation: 0.48227246911306254, R2: 0.10570043803473128
# Epoch [4/50], Loss: 167841.7188, Gap to Optimality: 167841.7188, NMSE: 0.8697170615196228, Correlation: 0.4903268917005831, R2: 0.13022098679513128
# Epoch [5/50], Loss: 163919.2344, Gap to Optimality: 163919.2344, NMSE: 0.849388599395752, Correlation: 0.5003556642273986, R2: 0.15055091134434695
# Epoch [6/50], Loss: 160421.9062, Gap to Optimality: 160421.9062, NMSE: 0.8312630653381348, Correlation: 0.518662777724835, R2: 0.1686776795111854
# Epoch [7/50], Loss: 157368.9531, Gap to Optimality: 157368.9531, NMSE: 0.8154399991035461, Correlation: 0.5253612634491946, R2: 0.18450187435551502
# Epoch [8/50], Loss: 154650.5469, Gap to Optimality: 154650.5469, NMSE: 0.801350474357605, Correlation: 0.5366953467546802, R2: 0.19859242742705618
# Epoch [9/50], Loss: 152166.5938, Gap to Optimality: 152166.5938, NMSE: 0.788475513458252, Correlation: 0.5417089749055297, R2: 0.2114683053908143
# Epoch [10/50], Loss: 149954.9844, Gap to Optimality: 149954.9844, NMSE: 0.7770119309425354, Correlation: 0.5467668875197071, R2: 0.222932781344785
# Epoch [11/50], Loss: 147979.7500, Gap to Optimality: 147979.7500, NMSE: 0.7667728662490845, Correlation: 0.5493694965863645, R2: 0.23317251417992668
# Epoch [12/50], Loss: 146264.5000, Gap to Optimality: 146264.5000, NMSE: 0.7578811049461365, Correlation: 0.549343764383144, R2: 0.2420649138277874
# Epoch [13/50], Loss: 144526.5625, Gap to Optimality: 144526.5625, NMSE: 0.7488716840744019, Correlation: 0.5620613577921898, R2: 0.2510749430240026
# Epoch [14/50], Loss: 142991.3281, Gap to Optimality: 142991.3281, NMSE: 0.7409125566482544, Correlation: 0.5624409244399834, R2: 0.2590345996877157
# Epoch [15/50], Loss: 141619.0781, Gap to Optimality: 141619.0781, NMSE: 0.733798086643219, Correlation: 0.5651954065350053, R2: 0.26614959345644384
# Epoch [16/50], Loss: 140394.7031, Gap to Optimality: 140394.7031, NMSE: 0.7274499535560608, Correlation: 0.5657551568882245, R2: 0.27249823120582006
# Epoch [17/50], Loss: 139357.0312, Gap to Optimality: 139357.0312, NMSE: 0.722069263458252, Correlation: 0.5645974033121326, R2: 0.2778792802412221
# Epoch [18/50], Loss: 138276.4375, Gap to Optimality: 138276.4375, NMSE: 0.7164661884307861, Correlation: 0.5686477130396442, R2: 0.2834827981841894
# Epoch [19/50], Loss: 137367.0781, Gap to Optimality: 137367.0781, NMSE: 0.7117505669593811, Correlation: 0.56927866070992, R2: 0.28819880388654195
# Epoch [20/50], Loss: 136512.4531, Gap to Optimality: 136512.4531, NMSE: 0.7073183655738831, Correlation: 0.5709539916461719, R2: 0.2926312024066978
# Epoch [21/50], Loss: 135798.8125, Gap to Optimality: 135798.8125, NMSE: 0.7036170959472656, Correlation: 0.5709333655475083, R2: 0.2963327477742954
# Epoch [22/50], Loss: 135067.4375, Gap to Optimality: 135067.4375, NMSE: 0.6998239159584045, Correlation: 0.5732618384467011, R2: 0.30012618766141186
# Epoch [23/50], Loss: 134471.7031, Gap to Optimality: 134471.7031, NMSE: 0.6967337727546692, Correlation: 0.5732202005143842, R2: 0.30321663841637203
# Epoch [24/50], Loss: 133853.0000, Gap to Optimality: 133853.0000, NMSE: 0.6935245990753174, Correlation: 0.5757196657004529, R2: 0.30642596548827494
# Epoch [25/50], Loss: 133330.0938, Gap to Optimality: 133330.0938, NMSE: 0.6908119320869446, Correlation: 0.5764860380561841, R2: 0.30913879920512755
# Epoch [26/50], Loss: 132860.4219, Gap to Optimality: 132860.4219, NMSE: 0.6883749961853027, Correlation: 0.5758762355778101, R2: 0.31157593397851835
# Epoch [27/50], Loss: 132399.2188, Gap to Optimality: 132399.2188, NMSE: 0.6859822273254395, Correlation: 0.5769152492852249, R2: 0.31396887529935613
# Epoch [28/50], Loss: 132031.8438, Gap to Optimality: 132031.8438, NMSE: 0.684075653553009, Correlation: 0.5766091052086674, R2: 0.31587564689759906
# Epoch [29/50], Loss: 131643.5469, Gap to Optimality: 131643.5469, NMSE: 0.682060718536377, Correlation: 0.5772540868500573, R2: 0.317890687306719
# Epoch [30/50], Loss: 131357.1250, Gap to Optimality: 131357.1250, NMSE: 0.6805739402770996, Correlation: 0.5783716751717372, R2: 0.31937752865972957
# Epoch [31/50], Loss: 131021.3906, Gap to Optimality: 131021.3906, NMSE: 0.6788315773010254, Correlation: 0.5778777906854662, R2: 0.32112006600004983
# Epoch [32/50], Loss: 130741.3906, Gap to Optimality: 130741.3906, NMSE: 0.6773781776428223, Correlation: 0.5780459276898637, R2: 0.3225735541180995
# Epoch [33/50], Loss: 130474.5234, Gap to Optimality: 130474.5234, NMSE: 0.6759929656982422, Correlation: 0.5792035460601068, R2: 0.3239588658255287
# Epoch [34/50], Loss: 130275.6953, Gap to Optimality: 130275.6953, NMSE: 0.6749603748321533, Correlation: 0.5794731719274147, R2: 0.32499153884148646
# Epoch [35/50], Loss: 130049.2969, Gap to Optimality: 130049.2969, NMSE: 0.6737848520278931, Correlation: 0.578830535693864, R2: 0.32616713745072357
# Epoch [36/50], Loss: 129836.8516, Gap to Optimality: 129836.8516, NMSE: 0.6726818680763245, Correlation: 0.5793750654026915, R2: 0.3272702262434496
# Epoch [37/50], Loss: 129648.8359, Gap to Optimality: 129648.8359, NMSE: 0.6717054843902588, Correlation: 0.5798031967603058, R2: 0.3282466781532737
# Epoch [38/50], Loss: 129494.1719, Gap to Optimality: 129494.1719, NMSE: 0.6709020137786865, Correlation: 0.5800188664486594, R2: 0.3290502065996195
# Epoch [39/50], Loss: 129344.9219, Gap to Optimality: 129344.9219, NMSE: 0.6701266765594482, Correlation: 0.5801454185373911, R2: 0.329825574489667
# Epoch [40/50], Loss: 129207.4922, Gap to Optimality: 129207.4922, NMSE: 0.6694124937057495, Correlation: 0.5800855214748548, R2: 0.3305397737950925
# Epoch [41/50], Loss: 129075.6406, Gap to Optimality: 129075.6406, NMSE: 0.6687275767326355, Correlation: 0.5804247088591328, R2: 0.3312247701154676
# Epoch [42/50], Loss: 129048.2109, Gap to Optimality: 129048.2109, NMSE: 0.6685837507247925, Correlation: 0.5804644254231652, R2: 0.3313685842534362
# Epoch [43/50], Loss: 128893.4062, Gap to Optimality: 128893.4062, NMSE: 0.6677798628807068, Correlation: 0.5806429197970827, R2: 0.33217261624612204
# Epoch [44/50], Loss: 128763.4844, Gap to Optimality: 128763.4844, NMSE: 0.6671048998832703, Correlation: 0.5806959196507593, R2: 0.33284755396061994
# Epoch [45/50], Loss: 128681.7969, Gap to Optimality: 128681.7969, NMSE: 0.6666800379753113, Correlation: 0.5805446495347928, R2: 0.3332724707345738
# Epoch [46/50], Loss: 128654.0234, Gap to Optimality: 128654.0234, NMSE: 0.6665346026420593, Correlation: 0.580247528631962, R2: 0.33341792769233125
# Epoch [47/50], Loss: 128501.3047, Gap to Optimality: 128501.3047, NMSE: 0.6657418012619019, Correlation: 0.5810118779170411, R2: 0.3342107840346348
# Epoch [48/50], Loss: 128451.4766, Gap to Optimality: 128451.4766, NMSE: 0.6654821634292603, Correlation: 0.5811315877985022, R2: 0.3344703898665803
# Epoch [49/50], Loss: 128398.1328, Gap to Optimality: 128398.1328, NMSE: 0.6652043461799622, Correlation: 0.5811286842965784, R2: 0.33474828418034563
# Epoch [50/50], Loss: 128329.1562, Gap to Optimality: 128329.1562, NMSE: 0.6648456454277039, Correlation: 0.5812376900827441, R2: 0.33510702173694396
# Epoch [1/50], Loss: 318165.7500, Gap to Optimality: 318165.7500, NMSE: 0.9019331932067871, Correlation: 0.5561709248640178, R2: 0.09806622579450575
# Epoch [2/50], Loss: 282994.6875, Gap to Optimality: 282994.6875, NMSE: 0.8022268414497375, Correlation: 0.709088706314963, R2: 0.19777261326184203
# Epoch [3/50], Loss: 254713.4531, Gap to Optimality: 254713.4531, NMSE: 0.722050130367279, Correlation: 0.7480124364024019, R2: 0.2779494196529321
# Epoch [4/50], Loss: 231862.7031, Gap to Optimality: 231862.7031, NMSE: 0.6572666168212891, Correlation: 0.7644484592635814, R2: 0.34273294550426203
# Epoch [5/50], Loss: 213287.5156, Gap to Optimality: 213287.5156, NMSE: 0.6046027541160583, Correlation: 0.774240870429362, R2: 0.3953968355796972
# Epoch [6/50], Loss: 198049.2500, Gap to Optimality: 198049.2500, NMSE: 0.5613979697227478, Correlation: 0.781172968841572, R2: 0.43860161023182154
# Epoch [7/50], Loss: 185439.7969, Gap to Optimality: 185439.7969, NMSE: 0.5256451964378357, Correlation: 0.786722884859281, R2: 0.47435443617098727
# Epoch [8/50], Loss: 174922.9688, Gap to Optimality: 174922.9688, NMSE: 0.49582454562187195, Correlation: 0.7914025021029758, R2: 0.5041751040329638
# Epoch [9/50], Loss: 166075.2500, Gap to Optimality: 166075.2500, NMSE: 0.470735639333725, Correlation: 0.7956290152263228, R2: 0.5292640523294704
# Epoch [10/50], Loss: 158582.2344, Gap to Optimality: 158582.2344, NMSE: 0.4494871199131012, Correlation: 0.7994605244251564, R2: 0.5505125980084935
# Epoch [11/50], Loss: 152198.8125, Gap to Optimality: 152198.8125, NMSE: 0.43138423562049866, Correlation: 0.8030683828693472, R2: 0.5686154809816396
# Epoch [12/50], Loss: 146673.2344, Gap to Optimality: 146673.2344, NMSE: 0.41571342945098877, Correlation: 0.8064320024515819, R2: 0.584286316616073
# Epoch [13/50], Loss: 141885.0469, Gap to Optimality: 141885.0469, NMSE: 0.40213319659233093, Correlation: 0.8094842167002371, R2: 0.5978665433043243
# Epoch [14/50], Loss: 137699.6875, Gap to Optimality: 137699.6875, NMSE: 0.39026209712028503, Correlation: 0.8123964010674747, R2: 0.6097376535733372
# Epoch [15/50], Loss: 133976.5000, Gap to Optimality: 133976.5000, NMSE: 0.3797012269496918, Correlation: 0.8150886476267957, R2: 0.6202984924823216
# Epoch [16/50], Loss: 130712.4375, Gap to Optimality: 130712.4375, NMSE: 0.37044236063957214, Correlation: 0.8177130179988102, R2: 0.6295573624667901
# Epoch [17/50], Loss: 127771.0391, Gap to Optimality: 127771.0391, NMSE: 0.3620982766151428, Correlation: 0.8201403989950014, R2: 0.6379014716654756
# Epoch [18/50], Loss: 125135.4531, Gap to Optimality: 125135.4531, NMSE: 0.35462135076522827, Correlation: 0.8224453580684515, R2: 0.6453783914964091
# Epoch [19/50], Loss: 122765.1250, Gap to Optimality: 122765.1250, NMSE: 0.3478967249393463, Correlation: 0.8246850442414334, R2: 0.6521030539964112
# Epoch [20/50], Loss: 120594.2422, Gap to Optimality: 120594.2422, NMSE: 0.3417375087738037, Correlation: 0.8267578042047877, R2: 0.6582622811477463
# Epoch [21/50], Loss: 118616.7422, Gap to Optimality: 118616.7422, NMSE: 0.3361267149448395, Correlation: 0.8287747042340636, R2: 0.6638730529766432
# Epoch [22/50], Loss: 116798.8047, Gap to Optimality: 116798.8047, NMSE: 0.33096843957901, Correlation: 0.8306593544491145, R2: 0.6690313337884057
# Epoch [23/50], Loss: 115129.3594, Gap to Optimality: 115129.3594, NMSE: 0.3262312412261963, Correlation: 0.8324516838939648, R2: 0.6737685441107248
# Epoch [24/50], Loss: 113594.0156, Gap to Optimality: 113594.0156, NMSE: 0.3218744099140167, Correlation: 0.8341332304678913, R2: 0.6781253854024007
# Epoch [25/50], Loss: 112162.8750, Gap to Optimality: 112162.8750, NMSE: 0.3178130090236664, Correlation: 0.8357323148758932, R2: 0.682186768963834
# Epoch [26/50], Loss: 110835.1172, Gap to Optimality: 110835.1172, NMSE: 0.3140449523925781, Correlation: 0.8372763767507712, R2: 0.685954828895905
# Epoch [27/50], Loss: 109594.2422, Gap to Optimality: 109594.2422, NMSE: 0.31052324175834656, Correlation: 0.8387419750827508, R2: 0.6894765694868448
# Epoch [28/50], Loss: 108437.1484, Gap to Optimality: 108437.1484, NMSE: 0.3072391748428345, Correlation: 0.8401299710508108, R2: 0.6927606237892225
# Epoch [29/50], Loss: 107350.7188, Gap to Optimality: 107350.7188, NMSE: 0.30415546894073486, Correlation: 0.8414296419205926, R2: 0.6958443266319394
# Epoch [30/50], Loss: 106333.6172, Gap to Optimality: 106333.6172, NMSE: 0.30126845836639404, Correlation: 0.8426973237797314, R2: 0.6987313373966673
# Epoch [31/50], Loss: 105377.3672, Gap to Optimality: 105377.3672, NMSE: 0.29855406284332275, Correlation: 0.8439004263011143, R2: 0.7014457283881266
# Epoch [32/50], Loss: 104475.2578, Gap to Optimality: 104475.2578, NMSE: 0.29599326848983765, Correlation: 0.8450493066598571, R2: 0.7040065265166685
# Epoch [33/50], Loss: 103622.1641, Gap to Optimality: 103622.1641, NMSE: 0.29357150197029114, Correlation: 0.8461360787535261, R2: 0.7064283291461078
# Epoch [34/50], Loss: 102817.5938, Gap to Optimality: 102817.5938, NMSE: 0.2912873327732086, Correlation: 0.8471773156982776, R2: 0.7087124828898856
# Epoch [35/50], Loss: 102059.0078, Gap to Optimality: 102059.0078, NMSE: 0.28913360834121704, Correlation: 0.848169626529857, R2: 0.7108662139521545
# Epoch [36/50], Loss: 101335.7969, Gap to Optimality: 101335.7969, NMSE: 0.2870802581310272, Correlation: 0.849126833009272, R2: 0.7129195571334841
# Epoch [37/50], Loss: 100649.7422, Gap to Optimality: 100649.7422, NMSE: 0.28513234853744507, Correlation: 0.8500452053410573, R2: 0.7148674824298966
# Epoch [38/50], Loss: 99998.4688, Gap to Optimality: 99998.4688, NMSE: 0.2832830250263214, Correlation: 0.8509118053815781, R2: 0.7167167808534278
# Epoch [39/50], Loss: 99378.7656, Gap to Optimality: 99378.7656, NMSE: 0.28152331709861755, Correlation: 0.8517416283573799, R2: 0.7184764871148983
# Epoch [40/50], Loss: 98788.7891, Gap to Optimality: 98788.7891, NMSE: 0.2798479199409485, Correlation: 0.8525280103344571, R2: 0.7201518890781633
# Epoch [41/50], Loss: 98223.7734, Gap to Optimality: 98223.7734, NMSE: 0.2782433331012726, Correlation: 0.8532984270694158, R2: 0.721756483523918
# Epoch [42/50], Loss: 97688.5312, Gap to Optimality: 97688.5312, NMSE: 0.2767232358455658, Correlation: 0.854017017334736, R2: 0.7232765881692083
# Epoch [43/50], Loss: 97177.1797, Gap to Optimality: 97177.1797, NMSE: 0.27527090907096863, Correlation: 0.8547229774238421, R2: 0.7247288842826127
# Epoch [44/50], Loss: 96687.1953, Gap to Optimality: 96687.1953, NMSE: 0.2738792300224304, Correlation: 0.8553966023744293, R2: 0.7261205988383851
# Epoch [45/50], Loss: 96218.7969, Gap to Optimality: 96218.7969, NMSE: 0.27254876494407654, Correlation: 0.8560380730051507, R2: 0.7274510459530112
# Epoch [46/50], Loss: 95768.9062, Gap to Optimality: 95768.9062, NMSE: 0.2712707817554474, Correlation: 0.8566448238642845, R2: 0.7287290410920692
# Epoch [47/50], Loss: 95339.7031, Gap to Optimality: 95339.7031, NMSE: 0.2700515687465668, Correlation: 0.8572463929425345, R2: 0.72994825482416
# Epoch [48/50], Loss: 94928.0859, Gap to Optimality: 94928.0859, NMSE: 0.26888224482536316, Correlation: 0.8578234920795923, R2: 0.731117567109229
# Epoch [49/50], Loss: 94532.2969, Gap to Optimality: 94532.2969, NMSE: 0.2677578032016754, Correlation: 0.8583686822649487, R2: 0.7322420230518852
# Epoch [50/50], Loss: 94152.7734, Gap to Optimality: 94152.7734, NMSE: 0.2666795551776886, Correlation: 0.8589012725537933, R2: 0.7333202917939432
# Epoch [1/50], Loss: 344971.2812, Gap to Optimality: 344971.2812, NMSE: 0.977922797203064, Correlation: 0.35100972531472285, R2: 0.022076552765791346
# Epoch [2/50], Loss: 335101.9688, Gap to Optimality: 335101.9688, NMSE: 0.9499444365501404, Correlation: 0.59375913512803, R2: 0.0500549447598756
# Epoch [3/50], Loss: 325637.3125, Gap to Optimality: 325637.3125, NMSE: 0.9231123924255371, Correlation: 0.70032891248302, R2: 0.07688699910328811
# Epoch [4/50], Loss: 316553.1562, Gap to Optimality: 316553.1562, NMSE: 0.8973585963249207, Correlation: 0.752045754333843, R2: 0.10264083616383779
# Epoch [5/50], Loss: 307834.5938, Gap to Optimality: 307834.5938, NMSE: 0.8726404905319214, Correlation: 0.7805803930977453, R2: 0.1273589219301896
# Epoch [6/50], Loss: 299467.3125, Gap to Optimality: 299467.3125, NMSE: 0.8489177823066711, Correlation: 0.7980825505361049, R2: 0.15108165930550588
# Epoch [7/50], Loss: 291432.3438, Gap to Optimality: 291432.3438, NMSE: 0.8261366486549377, Correlation: 0.8097277492225389, R2: 0.17386277114687
# Epoch [8/50], Loss: 283715.8438, Gap to Optimality: 283715.8438, NMSE: 0.8042577505111694, Correlation: 0.817960407804419, R2: 0.19574164169866604
# Epoch [9/50], Loss: 276302.5312, Gap to Optimality: 276302.5312, NMSE: 0.7832379937171936, Correlation: 0.8241017839088469, R2: 0.21676145181903073
# Epoch [10/50], Loss: 269181.8438, Gap to Optimality: 269181.8438, NMSE: 0.7630472779273987, Correlation: 0.828860421981904, R2: 0.23695217000760327
# Epoch [11/50], Loss: 262341.6562, Gap to Optimality: 262341.6562, NMSE: 0.7436514496803284, Correlation: 0.8326816276069395, R2: 0.2563480703942903
# Epoch [12/50], Loss: 255770.0625, Gap to Optimality: 255770.0625, NMSE: 0.7250166535377502, Correlation: 0.8358274459525677, R2: 0.2749828359229397
# Epoch [13/50], Loss: 249455.6250, Gap to Optimality: 249455.6250, NMSE: 0.7071105241775513, Correlation: 0.8384975662440214, R2: 0.2928889963933293
# Epoch [14/50], Loss: 243388.3594, Gap to Optimality: 243388.3594, NMSE: 0.6899047493934631, Correlation: 0.840798166101924, R2: 0.31009474380254964
# Epoch [15/50], Loss: 237555.4531, Gap to Optimality: 237555.4531, NMSE: 0.6733631491661072, Correlation: 0.8428115818172814, R2: 0.32663636921881956
# Epoch [16/50], Loss: 231943.4219, Gap to Optimality: 231943.4219, NMSE: 0.6574474573135376, Correlation: 0.8445957782756851, R2: 0.34255212538373747
# Epoch [17/50], Loss: 226549.7812, Gap to Optimality: 226549.7812, NMSE: 0.6421505212783813, Correlation: 0.8462070920872389, R2: 0.3578490228838269
# Epoch [18/50], Loss: 221361.1562, Gap to Optimality: 221361.1562, NMSE: 0.6274346113204956, Correlation: 0.8476705398812711, R2: 0.37256497480342377
# Epoch [19/50], Loss: 216371.9219, Gap to Optimality: 216371.9219, NMSE: 0.6132838129997253, Correlation: 0.849024775319786, R2: 0.3867158442349623
# ...
# Epoch [9/50], Loss: 127970.6016, Gap to Optimality: 127970.6016, NMSE: 0.649709165096283, Correlation: 0.710747789312895, R2: 0.35028981742419785
# Epoch [10/50], Loss: 124013.8281, Gap to Optimality: 124013.8281, NMSE: 0.6296132206916809, Correlation: 0.7142896172823924, R2: 0.3703858105989115
# Epoch [11/50], Loss: 120477.9688, Gap to Optimality: 120477.9688, NMSE: 0.6116542220115662, Correlation: 0.71729289728822, R2: 0.38834481041862956
# Epoch [12/50], Loss: 117303.7109, Gap to Optimality: 117303.7109, NMSE: 0.5955312252044678, Correlation: 0.7199374043653471, R2: 0.4044678456331503
# Epoch [13/50], Loss: 114458.8984, Gap to Optimality: 114458.8984, NMSE: 0.5810809135437012, Correlation: 0.7222852599299452, R2: 0.41891820150953274
# Epoch [14/50], Loss: 111908.0078, Gap to Optimality: 111908.0078, NMSE: 0.5681230425834656, Correlation: 0.7244142222869496, R2: 0.4318761099878382
# Epoch [15/50], Loss: 109603.8750, Gap to Optimality: 109603.8750, NMSE: 0.5564180016517639, Correlation: 0.7263623885730869, R2: 0.4435811607042912
# Epoch [16/50], Loss: 107530.5078, Gap to Optimality: 107530.5078, NMSE: 0.5458847880363464, Correlation: 0.7281699133081364, R2: 0.45411435169983594
# Epoch [17/50], Loss: 105649.0547, Gap to Optimality: 105649.0547, NMSE: 0.5363261699676514, Correlation: 0.7298375373284239, R2: 0.4636730430002467
# Epoch [18/50], Loss: 103944.0156, Gap to Optimality: 103944.0156, NMSE: 0.5276631712913513, Correlation: 0.7314195636760376, R2: 0.47233601986252394
# Epoch [19/50], Loss: 102395.6328, Gap to Optimality: 102395.6328, NMSE: 0.519795835018158, Correlation: 0.7329076313259903, R2: 0.48020339845733007
# Epoch [20/50], Loss: 100990.4062, Gap to Optimality: 100990.4062, NMSE: 0.51265549659729, Correlation: 0.7343369494154482, R2: 0.4873437078999545
# Epoch [21/50], Loss: 99696.5234, Gap to Optimality: 99696.5234, NMSE: 0.5060805082321167, Correlation: 0.7356783343133235, R2: 0.4939187256590809
# Epoch [22/50], Loss: 98516.3828, Gap to Optimality: 98516.3828, NMSE: 0.5000832080841064, Correlation: 0.7369687617787243, R2: 0.4999160032468316
# Epoch [23/50], Loss: 97435.8125, Gap to Optimality: 97435.8125, NMSE: 0.494591623544693, Correlation: 0.7382056918903165, R2: 0.5054076072566225
# Epoch [24/50], Loss: 96441.7344, Gap to Optimality: 96441.7344, NMSE: 0.4895392954349518, Correlation: 0.7393978295181449, R2: 0.5104599207234928
# Epoch [25/50], Loss: 95526.1016, Gap to Optimality: 95526.1016, NMSE: 0.48488542437553406, Correlation: 0.7405430080563282, R2: 0.5151137971672861
# Epoch [26/50], Loss: 94681.4844, Gap to Optimality: 94681.4844, NMSE: 0.480592280626297, Correlation: 0.7416458189248115, R2: 0.5194069742669924
# Epoch [27/50], Loss: 93896.8828, Gap to Optimality: 93896.8828, NMSE: 0.4766039550304413, Correlation: 0.7427015844953481, R2: 0.5233953427160583
# Epoch [28/50], Loss: 93168.3906, Gap to Optimality: 93168.3906, NMSE: 0.4729006588459015, Correlation: 0.7437208065878651, R2: 0.5270986044432704
# Epoch [29/50], Loss: 92490.8203, Gap to Optimality: 92490.8203, NMSE: 0.4694560170173645, Correlation: 0.7447012860870006, R2: 0.5305432581673892
# Epoch [30/50], Loss: 91858.1406, Gap to Optimality: 91858.1406, NMSE: 0.46623939275741577, Correlation: 0.745661519086663, R2: 0.5337598926315181
# Epoch [31/50], Loss: 91270.2578, Gap to Optimality: 91270.2578, NMSE: 0.4632503390312195, Correlation: 0.7465929211928143, R2: 0.5367489282407671
# Epoch [32/50], Loss: 90719.7344, Gap to Optimality: 90719.7344, NMSE: 0.4604512155056, Correlation: 0.7475045120684586, R2: 0.539548054296442
# Epoch [33/50], Loss: 90200.7656, Gap to Optimality: 90200.7656, NMSE: 0.4578123390674591, Correlation: 0.748378308613136, R2: 0.5421869640872872
# Epoch [34/50], Loss: 89714.9453, Gap to Optimality: 89714.9453, NMSE: 0.4553418755531311, Correlation: 0.749229941605124, R2: 0.5446574099959209
# Epoch [35/50], Loss: 89255.1484, Gap to Optimality: 89255.1484, NMSE: 0.45300358533859253, Correlation: 0.750046016028552, R2: 0.5469957217329893
# Epoch [36/50], Loss: 88822.9531, Gap to Optimality: 88822.9531, NMSE: 0.45080557465553284, Correlation: 0.7508439131043663, R2: 0.5491937155118803
# Epoch [37/50], Loss: 88413.4297, Gap to Optimality: 88413.4297, NMSE: 0.4487227499485016, Correlation: 0.7516136178456205, R2: 0.5512765264571144
# Epoch [38/50], Loss: 88024.6797, Gap to Optimality: 88024.6797, NMSE: 0.44674551486968994, Correlation: 0.7523601932439837, R2: 0.5532538152281781
# Epoch [39/50], Loss: 87657.4766, Gap to Optimality: 87657.4766, NMSE: 0.4448777735233307, Correlation: 0.75308508532354, R2: 0.5551215361956794
# Epoch [40/50], Loss: 87309.1094, Gap to Optimality: 87309.1094, NMSE: 0.4431057572364807, Correlation: 0.7537880427752754, R2: 0.55689355861847
# Epoch [41/50], Loss: 86976.7969, Gap to Optimality: 86976.7969, NMSE: 0.44141533970832825, Correlation: 0.7544831139249043, R2: 0.5585839877457426
# Epoch [42/50], Loss: 86661.3438, Gap to Optimality: 86661.3438, NMSE: 0.4398106038570404, Correlation: 0.7551565720614487, R2: 0.5601887179037179
# Epoch [43/50], Loss: 86361.0156, Gap to Optimality: 86361.0156, NMSE: 0.4382827579975128, Correlation: 0.7558234344758213, R2: 0.5617165809559858
# Epoch [44/50], Loss: 86072.4922, Gap to Optimality: 86072.4922, NMSE: 0.43681493401527405, Correlation: 0.7564612612273044, R2: 0.5631844002868392
# Epoch [45/50], Loss: 85796.9844, Gap to Optimality: 85796.9844, NMSE: 0.4354131817817688, Correlation: 0.7570800902725517, R2: 0.5645861560135352
# Epoch [46/50], Loss: 85533.1094, Gap to Optimality: 85533.1094, NMSE: 0.43407052755355835, Correlation: 0.7576777202485364, R2: 0.5659287635025495
# Epoch [47/50], Loss: 85280.2812, Gap to Optimality: 85280.2812, NMSE: 0.43278414011001587, Correlation: 0.7582650045163611, R2: 0.5672152120282881
# Epoch [48/50], Loss: 85037.7109, Gap to Optimality: 85037.7109, NMSE: 0.43154987692832947, Correlation: 0.7588399890509978, R2: 0.5684494675040392
# Epoch [49/50], Loss: 84804.1719, Gap to Optimality: 84804.1719, NMSE: 0.43036147952079773, Correlation: 0.759399574502148, R2: 0.5696378451362469
# Epoch [50/50], Loss: 84578.5391, Gap to Optimality: 84578.5391, NMSE: 0.429213285446167, Correlation: 0.7599402307091564, R2: 0.5707860475410669
# Epoch [1/50], Loss: 182761.1562, Gap to Optimality: 182761.1562, NMSE: 0.9279353618621826, Correlation: 0.5256588226565686, R2: 0.07206321133754168
# Epoch [2/50], Loss: 172519.0312, Gap to Optimality: 172519.0312, NMSE: 0.8759301900863647, Correlation: 0.6492395397352654, R2: 0.124068477434638
# Epoch [3/50], Loss: 163431.3281, Gap to Optimality: 163431.3281, NMSE: 0.8297855257987976, Correlation: 0.6919409004586616, R2: 0.17021319469163498
# Epoch [4/50], Loss: 155364.4531, Gap to Optimality: 155364.4531, NMSE: 0.7888230681419373, Correlation: 0.7105179182385504, R2: 0.21117563578542253
# Epoch [5/50], Loss: 148185.7188, Gap to Optimality: 148185.7188, NMSE: 0.7523694038391113, Correlation: 0.7201536374252805, R2: 0.24762940379247345
# Epoch [6/50], Loss: 141799.3750, Gap to Optimality: 141799.3750, NMSE: 0.7199384570121765, Correlation: 0.7258924125121758, R2: 0.2800603936661459
# Epoch [7/50], Loss: 136114.3125, Gap to Optimality: 136114.3125, NMSE: 0.691067636013031, Correlation: 0.7297346014627876, R2: 0.3089312105516967
# Epoch [8/50], Loss: 131019.9844, Gap to Optimality: 131019.9844, NMSE: 0.6651960015296936, Correlation: 0.732485085540105, R2: 0.3348030146352705
# Epoch [9/50], Loss: 126482.2812, Gap to Optimality: 126482.2812, NMSE: 0.6421502828598022, Correlation: 0.7346421170678116, R2: 0.3578487651919595
# Epoch [10/50], Loss: 122422.1328, Gap to Optimality: 122422.1328, NMSE: 0.6215290427207947, Correlation: 0.7363579461668104, R2: 0.3784699764779327
# Epoch [11/50], Loss: 118786.7969, Gap to Optimality: 118786.7969, NMSE: 0.6030646562576294, Correlation: 0.7377952068456779, R2: 0.39693440827598725
# Epoch [12/50], Loss: 115535.3594, Gap to Optimality: 115535.3594, NMSE: 0.5865494608879089, Correlation: 0.7390688075208248, R2: 0.41344960252129537
# Epoch [13/50], Loss: 112612.2422, Gap to Optimality: 112612.2422, NMSE: 0.571701169013977, Correlation: 0.7402387273266638, R2: 0.42829793614785705
# Epoch [14/50], Loss: 109998.1484, Gap to Optimality: 109998.1484, NMSE: 0.5584220290184021, Correlation: 0.7412923054120348, R2: 0.4415771465942039
# Epoch [15/50], Loss: 107644.3750, Gap to Optimality: 107644.3750, NMSE: 0.5464646220207214, Correlation: 0.742258919910557, R2: 0.4535345145069303
# Epoch [16/50], Loss: 105524.0078, Gap to Optimality: 105524.0078, NMSE: 0.5356924533843994, Correlation: 0.7431755925443835, R2: 0.46430674207462075
# Epoch [17/50], Loss: 103610.3672, Gap to Optimality: 103610.3672, NMSE: 0.5259698629379272, Correlation: 0.7440267757344335, R2: 0.47402928192124716
# Epoch [18/50], Loss: 101876.4922, Gap to Optimality: 101876.4922, NMSE: 0.5171602964401245, Correlation: 0.7448023952654508, R2: 0.48283896921188396
# Epoch [19/50], Loss: 100319.0859, Gap to Optimality: 100319.0859, NMSE: 0.509246826171875, Correlation: 0.7455746797929301, R2: 0.49075242656509077
# Epoch [20/50], Loss: 98906.7969, Gap to Optimality: 98906.7969, NMSE: 0.5020701289176941, Correlation: 0.7462960230672225, R2: 0.49792907767622707
# Epoch [21/50], Loss: 97626.3594, Gap to Optimality: 97626.3594, NMSE: 0.4955631494522095, Correlation: 0.7469916159011549, R2: 0.5044360709727381
# Epoch [22/50], Loss: 96462.4688, Gap to Optimality: 96462.4688, NMSE: 0.48964813351631165, Correlation: 0.7476666078894626, R2: 0.5103511380083303
# Epoch [23/50], Loss: 95402.0547, Gap to Optimality: 95402.0547, NMSE: 0.4842585325241089, Correlation: 0.7483213637208108, R2: 0.5157406709393149
# Epoch [24/50], Loss: 94437.3594, Gap to Optimality: 94437.3594, NMSE: 0.47935518622398376, Correlation: 0.7489476990006431, R2: 0.5206440626676582
# Epoch [25/50], Loss: 93554.7109, Gap to Optimality: 93554.7109, NMSE: 0.474868506193161, Correlation: 0.7495472290801343, R2: 0.5251307671852519
# Epoch [26/50], Loss: 92747.2891, Gap to Optimality: 92747.2891, NMSE: 0.4707639515399933, Correlation: 0.7501270713916528, R2: 0.5292353389988844
# Epoch [27/50], Loss: 92012.7891, Gap to Optimality: 92012.7891, NMSE: 0.4670298397541046, Correlation: 0.7507110754155006, R2: 0.5329694695176593
# Epoch [28/50], Loss: 91336.8750, Gap to Optimality: 91336.8750, NMSE: 0.46359333395957947, Correlation: 0.7512694383349271, R2: 0.5364059347977301
# Epoch [29/50], Loss: 90713.8125, Gap to Optimality: 90713.8125, NMSE: 0.46042534708976746, Correlation: 0.7518103402626622, R2: 0.5395739625610987
# Epoch [30/50], Loss: 90139.6016, Gap to Optimality: 90139.6016, NMSE: 0.457505464553833, Correlation: 0.7523487203292888, R2: 0.5424938507002237
# Epoch [31/50], Loss: 89609.7188, Gap to Optimality: 89609.7188, NMSE: 0.45481085777282715, Correlation: 0.7528712483003444, R2: 0.5451884519684246
# Epoch [32/50], Loss: 89117.0078, Gap to Optimality: 89117.0078, NMSE: 0.4523050785064697, Correlation: 0.7533736763665615, R2: 0.5476942601483688
# Epoch [33/50], Loss: 88659.5703, Gap to Optimality: 88659.5703, NMSE: 0.44997844099998474, Correlation: 0.7538657638005912, R2: 0.5500208672111322
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 56
#      53 batch_size = 32
#      55 hypers = {'max_iter': 10, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
# ---> 56 lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information,gradient_information = KFoldCV(X_train, Y_train, alphas, k_folds, hypers,B_tensored ,intercept= False)
#      58 hypers = {'max_iter': 10, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
#      59 normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values,gradient_values = train_test(X_train, Y_train, X_test, Y_test, lambda1, hypers, Y_train_mean,B_tensored,intercept= False)
#
# File ~/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Code Files/KFoldCV.py:43, in KFoldCV(X_train, Y_train, alphas, k_folds, hypers, B_tensored, intercept)
#      40 for index1, alpha1 in enumerate(alphas):
#      41   hypers['weight_decay'] = alpha1
# ---> 43   lsr_ten, objective_function_values, gradient_values = lsr_bcd_regression(lsr_tensors[index1][fold], X_train_updated, Y_train_updated, hypers, intercept = need_intercept)
#      44   expanded_lsr = lsr_ten.expand_to_tensor()
#      45   expanded_lsr = np.reshape(expanded_lsr, X_validation[0].shape, order='F')
#
# File ~/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Code Files/lsr_bcd_regression.py:59, in lsr_bcd_regression(lsr_ten, training_data, training_labels, hypers, intercept)
#      57 #Solve the sub-problem pertaining to the factor tensor
#      58 hypers = {'lambda': lambda1, 'lr': lr, 'epochs': epochs, 'batch_size': batch_size, 'bias': b_intercept}
# ---> 59 weights, bias, loss_values, gap_to_optimality, nmse_values, corr_values, R2_values = SGD(X_tilde, y_tilde.reshape(-1,1), cost_function_code = 1, hypers = hypers , optimizer_code = 0, p_star = 0)
#      61 #Retrieve Original and Updated Factor Matrices
#      62 Bk = lsr_ten.get_factor_matrix(s, k)
#
# File ~/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Code Files/sgd_optimization.py:100, in SGD(X, Y, cost_function_code, hypers, optimizer_code, p_star, W_true)
#      97 #Training Loop
#      98 for epoch in range(epochs):
# --> 100     for X_sample, Y_sample in dataloader:
#     101
#     102         # Shuffle dataset
#     103         #indices = torch.randperm(X.size(0))
#     104         #X_shuffled = X[indices]
#     105         #y_shuffled = Y[indices]
#     106
#     107         #Get X and Y sample
#     108         #X_sample = X_shuffled[0: batch_size]
#     109         #Y_sample = y_shuffled[0: batch_size]
#     111         Y_sample = Y_sample.reshape(-1,1)
#     114         # Compute stochastic loss
#
# File ~/miniconda3/envs/torchtensor/lib/python3.12/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/torchtensor/lib/python3.12/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/torchtensor/lib/python3.12/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/torchtensor/lib/python3.12/site-packages/torch/utils/data/dataset.py:206, in TensorDataset.__getitem__(self, index)
#     205 def __getitem__(self, index):
# --> 206     return tuple(tensor[index] for tensor in self.tensors)
#
# File ~/miniconda3/envs/torchtensor/lib/python3.12/site-packages/torch/utils/data/dataset.py:206, in <genexpr>(.0)
#     205 def __getitem__(self, index):
# --> 206     return tuple(tensor[index] for tensor in self.tensors)
#
# KeyboardInterrupt:

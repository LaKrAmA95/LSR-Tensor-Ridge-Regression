# %% [markdown]
# # Tensor Pipeline

# %% [markdown]
# ## Setting Path

# %%
import sys
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Code Files')
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Data')

# %% [markdown]
# ## Import Libraries

# %%
import datetime
import numpy as np
import dill
from KFoldCV import KFoldCV
from train_test import train_test
from sgd_optimization import SGD
from DataGenerationB import *
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import Data

# %%
import pickle
pkl_file = "/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Closed_Form_Solver/Data/Bounded_Var_Time:2024-04-15 19:35:40, intercept:5,n_train:5000, n_test:1000, tensor_dimensions:[32 32], tensor_mode_ranks:[4 4], separation_rank:2.pkl"
file= open(pkl_file, 'rb')
data = pickle.load(file)
file.close()

X_train_Full = data[0]
print(data[0].shape)

Y_train_Full = data[1]
print(data[1].shape)

X_test_Full = data[2]
print(data[2].shape)

Y_test_Full = data[3]
print(data[3].shape)

B_tensored = data[4]
print(data[4].shape)
# Out:
# (5000, 32, 32)
# (5000,)
# (1000, 32, 32)
# (1000,)
# (32, 32)

# %% [markdown]
# ## Subset Data

# %%
n_train_all = [1100]
n_test = 100

tensor_dimensions = np.array([32, 32])
tensor_mode_ranks = np.array([4, 4])
separation_rank = 2

# %%
for i,n_train in enumerate(n_train_all):
  print('Number of Samples:',n_train,'---------------------------------------------------------------------------------------------------------------------------')

  #Subset X_train and Y_train
  X_train = X_train_Full[0:(n_train),:,:]
  Y_train = Y_train_Full[0:(n_train)]

  #Subset X_test and Y_test
  X_test = X_test_Full[0:(n_test),:,:]
  Y_test = Y_test_Full[0:(n_test)]

  #Preprocessing

  # Reshape the 3D array to a 2D array where each row represents a sample
  # The shape of the original 3D array is (n_samples, n_features_per_sample, n_dimensions)
  # We reshape it to (n_samples, n_features_per_sample * n_dimensions)


  X_train_2D = X_train.reshape(n_train, -1)
  X_test_2D = X_test.reshape(n_test,-1)


  # Initialize StandardScaler
  scaler = StandardScaler(with_std = False) #standard scalar only

  # Fit scaler on train data and transform train data
  X_train_scaled = scaler.fit_transform(X_train_2D)
  # Transform test data using the scaler fitted on train data
  X_test_scaled = scaler.transform(X_test_2D)

  # Reshape the scaled data back to 3D
  X_train = X_train_scaled.reshape(n_train, tensor_dimensions[0],tensor_dimensions[1])
  X_test  = X_test_scaled.reshape(n_test, tensor_dimensions[0],tensor_dimensions[1])

  #average response value
  Y_train_mean = np.mean(Y_train)
  # Mean centering y_train and y_test
  Y_train = Y_train - Y_train_mean


  print("Sample mean for each feature (across samples):",scaler.mean_)
  print("Sample variance for each feature (across samples):",scaler.var_)
  print('Response Average:',Y_train_mean)

  #For now, define finite alpha set that we are searching over
  alphas = [0,0.1,0.3, 0.5, 0.7, 0.9, 1, 1.5, 2, 2.5, 3, 5, 4,10,15,20,50,100]

  #Define Number of Folds we want
  
  k_folds = 5
  learning_rate = 0.0000025
  epochs = 50
  batch_size = 32

  hypers = {'max_iter': 15, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
  lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information = KFoldCV(X_train, Y_train, alphas, k_folds, hypers,B_tensored ,intercept= False) 

  hypers = {'max_iter': 15, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
  normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values = train_test(X_train, Y_train, X_test, Y_test, B_tensored, lambda1, hypers, Y_train_mean,intercept= False)

  #Get current time and store in variable
  formatted_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  max_iter = hypers['max_iter']
  pkl_file = f"/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Closed_Form_Solver/Experimental Results/ExecutionTime_intercept_5_{formatted_time}, n_train_{n_train},n_test_{n_test}, tensor_dimensions:{tensor_dimensions}, tensor_mode_= ranks:{tensor_mode_ranks}, separation_rank:{separation_rank}, max_iter={max_iter}.pkl"

  print("Error Record on Training _ After K-Fold CV")
  print("Validation Normalized Estimation Error: ", validation_normalized_estimation_error)
  print("Validation NMSE Losses: ", validation_nmse_losses)
  print("Validation Correlations: ", validation_correlations)
  print("Validation R2 Scores: ", validation_R2_scores)

  print("Error Report on Testing _ With best Lambda")
  print("Alpha chosen for model: ", lambda1)
  print("Test Normalized Estimation Error: ", normalized_estimation_error)
  print("Test NMSE Loss: ", test_nmse_loss)
  print("Test R2 Loss: ", test_R2_loss)
  print("Test Correlation: ", test_correlation)

  with open(pkl_file, "wb") as file:
    dill.dump((X_train_Full, Y_train_Full, X_test_Full, Y_test_Full, B_tensored, lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information, normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values), file)
# Out:
# Number of Samples: 1100 ---------------------------------------------------------------------------------------------------------------------------
# Sample mean for each feature (across samples): [4.99229076 4.99583242 5.01768396 ... 5.00785591 4.99100698 4.99667398]
# Sample variance for each feature (across samples): None
# Response Average: 83.27834777294153
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# Fold = 0, Alpha = 0, Normalized Estimation Error: 0.09264783377828414, NMSE: 0.0900065330688289, Correlation: 0.9542582579743183, R^2 Score: 0.9098524840882655
# Fold = 0, Alpha = 0.1, Normalized Estimation Error: 0.0935077018303087, NMSE: 0.09429588398987218, Correlation: 0.9518610882439518, R^2 Score: 0.9055564144895168
# Fold = 0, Alpha = 0.3, Normalized Estimation Error: 0.0948375640844342, NMSE: 0.09536048473411597, Correlation: 0.9511970418395059, R^2 Score: 0.9044901461947702
# Fold = 0, Alpha = 0.5, Normalized Estimation Error: 0.0909700894278278, NMSE: 0.08904076522703328, Correlation: 0.9545272121767505, R^2 Score: 0.9108197646724286
# Fold = 0, Alpha = 0.7, Normalized Estimation Error: 0.050293239757494015, NMSE: 0.04997069773967743, Correlation: 0.9747748163293962, R^2 Score: 0.9499510300417501
# Fold = 0, Alpha = 0.9, Normalized Estimation Error: 0.07148225841063181, NMSE: 0.06892885494775902, Correlation: 0.965009444999576, R^2 Score: 0.9309631774903604
# Fold = 0, Alpha = 1, Normalized Estimation Error: 0.04961549880291128, NMSE: 0.047908091950601424, Correlation: 0.9759023236106781, R^2 Score: 0.9520168666188369
# Fold = 0, Alpha = 1.5, Normalized Estimation Error: 0.07665049438904091, NMSE: 0.07756363016602633, Correlation: 0.9605016749188766, R^2 Score: 0.9223148770854581
# Fold = 0, Alpha = 2, Normalized Estimation Error: 0.11535122066811981, NMSE: 0.12179084001391947, Correlation: 0.9370711837126258, R^2 Score: 0.8780183914020724
# Fold = 0, Alpha = 2.5, Normalized Estimation Error: 0.09297702240140417, NMSE: 0.0915352026517418, Correlation: 0.9530954102548844, R^2 Score: 0.908321420054902
# Fold = 0, Alpha = 3, Normalized Estimation Error: 0.050764353455262735, NMSE: 0.051252586012899976, Correlation: 0.9742131492093882, R^2 Score: 0.9486671338670243
# Fold = 0, Alpha = 5, Normalized Estimation Error: 0.06320525096529792, NMSE: 0.059820514950125143, Correlation: 0.9700031146445071, R^2 Score: 0.9400857844486608
# Fold = 0, Alpha = 4, Normalized Estimation Error: 0.06414911466777119, NMSE: 0.06341751513323624, Correlation: 0.9679581746485398, R^2 Score: 0.9364831500599597
# Fold = 0, Alpha = 10, Normalized Estimation Error: 0.06408044754587727, NMSE: 0.06373442561328281, Correlation: 0.9682002976808511, R^2 Score: 0.9361657431832751
# Fold = 0, Alpha = 15, Normalized Estimation Error: 0.07453593362545609, NMSE: 0.07371273964219913, Correlation: 0.9632605009823761, R^2 Score: 0.9261717994991411
# Fold = 0, Alpha = 20, Normalized Estimation Error: 0.23466124481590014, NMSE: 0.2377209713716513, Correlation: 0.8733946035726915, R^2 Score: 0.761906671453602
# Fold = 0, Alpha = 50, Normalized Estimation Error: 0.11899856470917518, NMSE: 0.11963850718147848, Correlation: 0.9401617029751286, R^2 Score: 0.880174095567585
# Fold = 0, Alpha = 100, Normalized Estimation Error: 0.2372042156473425, NMSE: 0.23842464321830825, Correlation: 0.8741205289703665, R^2 Score: 0.7612018974018714
# Fold = 1, Alpha = 0, Normalized Estimation Error: 0.05727269794278513, NMSE: 0.06375371519949943, Correlation: 0.9675882319007545, R^2 Score: 0.9360361663623766
# Fold = 1, Alpha = 0.1, Normalized Estimation Error: 0.04948370260104294, NMSE: 0.05273126821670298, Correlation: 0.9734335048574215, R^2 Score: 0.9470949409432916
# Fold = 1, Alpha = 0.3, Normalized Estimation Error: 0.05506210575341007, NMSE: 0.05674711261226318, Correlation: 0.9711755993063994, R^2 Score: 0.943065861194317
# Fold = 1, Alpha = 0.5, Normalized Estimation Error: 0.04895565693230659, NMSE: 0.05487874312049791, Correlation: 0.9723151508297523, R^2 Score: 0.9449403884272934
# Fold = 1, Alpha = 0.7, Normalized Estimation Error: 0.09107923330531333, NMSE: 0.09372920369805786, Correlation: 0.9525611078369645, R^2 Score: 0.9059618851455333
# Fold = 1, Alpha = 0.9, Normalized Estimation Error: 0.04984176756087673, NMSE: 0.05458164719871518, Correlation: 0.9723525477899495, R^2 Score: 0.9452384635128922
# Fold = 1, Alpha = 1, Normalized Estimation Error: 0.23837018397266602, NMSE: 0.22071394830636745, Correlation: 0.88772412459773, R^2 Score: 0.7785586263201436
# Fold = 1, Alpha = 1.5, Normalized Estimation Error: 0.18976811834674007, NMSE: 0.18430877278120814, Correlation: 0.9043949292170899, R^2 Score: 0.815083785419547
# Fold = 1, Alpha = 2, Normalized Estimation Error: 0.08860943019667021, NMSE: 0.08992143115350054, Correlation: 0.9542503726536878, R^2 Score: 0.9097822072837463
# Fold = 1, Alpha = 2.5, Normalized Estimation Error: 0.05193755791364613, NMSE: 0.054809652124072586, Correlation: 0.9721763210217632, R^2 Score: 0.94500970713268
# Fold = 1, Alpha = 3, Normalized Estimation Error: 0.09968072196275689, NMSE: 0.10406885167463295, Correlation: 0.9466143264125877, R^2 Score: 0.8955881599284901
# Fold = 1, Alpha = 5, Normalized Estimation Error: 0.11087883894579495, NMSE: 0.11869350334762123, Correlation: 0.9397915607978397, R^2 Score: 0.8809153085708556
# Fold = 1, Alpha = 4, Normalized Estimation Error: 0.05321287739611073, NMSE: 0.05692227113982658, Correlation: 0.9711684666527411, R^2 Score: 0.942890125382181
# Fold = 1, Alpha = 10, Normalized Estimation Error: 0.0624931896847503, NMSE: 0.06621774869929371, Correlation: 0.9663548174668474, R^2 Score: 0.9335640119418039
# Fold = 1, Alpha = 15, Normalized Estimation Error: 0.07632593415556664, NMSE: 0.08353304826584544, Correlation: 0.9573855089614877, R^2 Score: 0.9161916448978639
# Fold = 1, Alpha = 20, Normalized Estimation Error: 0.22416526295917855, NMSE: 0.21085725109122108, Correlation: 0.8910737756061371, R^2 Score: 0.7884478090746413
# Fold = 1, Alpha = 50, Normalized Estimation Error: 0.23510565962678814, NMSE: 0.21253485358703775, Correlation: 0.8881881773356983, R^2 Score: 0.7867646775643177
# Fold = 1, Alpha = 100, Normalized Estimation Error: 0.1212227368006713, NMSE: 0.11219808972274238, Correlation: 0.9462982952657878, R^2 Score: 0.8874321296723272
# Fold = 2, Alpha = 0, Normalized Estimation Error: 0.05396286550657046, NMSE: 0.04580686756510151, Correlation: 0.9768328562833523, R^2 Score: 0.954181470195541
# Fold = 2, Alpha = 0.1, Normalized Estimation Error: 0.1664761588103203, NMSE: 0.13729698468713175, Correlation: 0.9295232911635681, R^2 Score: 0.8626680600674301
# Fold = 2, Alpha = 0.3, Normalized Estimation Error: 0.05609466228928729, NMSE: 0.04897804813759735, Correlation: 0.9752240020651105, R^2 Score: 0.9510094822535643
# Fold = 2, Alpha = 0.5, Normalized Estimation Error: 0.12584627254981282, NMSE: 0.10424176406267759, Correlation: 0.9464755577498165, R^2 Score: 0.895731696414579
# Fold = 2, Alpha = 0.7, Normalized Estimation Error: 0.045820206696280376, NMSE: 0.03796159569782096, Correlation: 0.9808846269093298, R^2 Score: 0.9620287394366478
# Fold = 2, Alpha = 0.9, Normalized Estimation Error: 0.06319158274152237, NMSE: 0.05473998505198743, Correlation: 0.9723152526750918, R^2 Score: 0.9452460783738253
# Fold = 2, Alpha = 1, Normalized Estimation Error: 0.24429884826288437, NMSE: 0.2304135621400322, Correlation: 0.8808129350472008, R^2 Score: 0.7695277755183642
# Fold = 2, Alpha = 1.5, Normalized Estimation Error: 0.04793684150640352, NMSE: 0.039803972883444665, Correlation: 0.9799695155052924, R^2 Score: 0.9601858931893994
# Fold = 2, Alpha = 2, Normalized Estimation Error: 0.05289991829652814, NMSE: 0.04382271656408905, Correlation: 0.9778729461862122, R^2 Score: 0.9561661263532062
# Fold = 2, Alpha = 2.5, Normalized Estimation Error: 0.06040200226284101, NMSE: 0.052269936608733726, Correlation: 0.9735339518547006, R^2 Score: 0.9477167556812146
# Fold = 2, Alpha = 3, Normalized Estimation Error: 0.086672935144957, NMSE: 0.07586216663759293, Correlation: 0.9614022760109912, R^2 Score: 0.9241185191679961
# Fold = 2, Alpha = 5, Normalized Estimation Error: 0.08638948388289779, NMSE: 0.0744653371778102, Correlation: 0.962071822297264, R^2 Score: 0.9255157042547921
# Fold = 2, Alpha = 4, Normalized Estimation Error: 0.05077105293906838, NMSE: 0.04349140878789, Correlation: 0.9780947916726473, R^2 Score: 0.9564975184789972
# Fold = 2, Alpha = 10, Normalized Estimation Error: 0.10179394543308669, NMSE: 0.07605976570852724, Correlation: 0.9612502787910829, R^2 Score: 0.9239208697891542
# Fold = 2, Alpha = 15, Normalized Estimation Error: 0.05982247760049198, NMSE: 0.05189940452946906, Correlation: 0.9739016045738664, R^2 Score: 0.9480873820964167
# Fold = 2, Alpha = 20, Normalized Estimation Error: 0.11219821640236166, NMSE: 0.10305314730779315, Correlation: 0.9474185506623721, R^2 Score: 0.8969206157863817
# Fold = 2, Alpha = 50, Normalized Estimation Error: 0.083795178154258, NMSE: 0.07226256004317752, Correlation: 0.9663024764437952, R^2 Score: 0.9277190422073887
# Fold = 2, Alpha = 100, Normalized Estimation Error: 0.24200429939425697, NMSE: 0.22284094819973707, Correlation: 0.8818369214363542, R^2 Score: 0.7771023174149031
# Fold = 3, Alpha = 0, Normalized Estimation Error: 0.09182765237284078, NMSE: 0.08028352426434221, Correlation: 0.9601068820271897, R^2 Score: 0.9188184451541523
# Fold = 3, Alpha = 0.1, Normalized Estimation Error: 0.05609075880119407, NMSE: 0.05024675831201673, Correlation: 0.9755904955777172, R^2 Score: 0.9491911945432026
# Fold = 3, Alpha = 0.3, Normalized Estimation Error: 0.09294439382829864, NMSE: 0.0828777288372756, Correlation: 0.9587960670248346, R^2 Score: 0.9161952224848845
# Fold = 3, Alpha = 0.5, Normalized Estimation Error: 0.06505948332600286, NMSE: 0.056162292834695336, Correlation: 0.9725326812013366, R^2 Score: 0.94320949039287
# Fold = 3, Alpha = 0.7, Normalized Estimation Error: 0.05032920735929928, NMSE: 0.04443828762240726, Correlation: 0.9779006612158198, R^2 Score: 0.9550646372723288
# Fold = 3, Alpha = 0.9, Normalized Estimation Error: 0.07336206056670369, NMSE: 0.06533271366000781, Correlation: 0.9676295841741562, R^2 Score: 0.9339364916299064
# Fold = 3, Alpha = 1, Normalized Estimation Error: 0.05895740095064751, NMSE: 0.05223076577508441, Correlation: 0.9747229294217253, R^2 Score: 0.9471849944896614
# Fold = 3, Alpha = 1.5, Normalized Estimation Error: 0.1256910110983368, NMSE: 0.11539447885650808, Correlation: 0.9402495431997359, R^2 Score: 0.8833147485734086
# Fold = 3, Alpha = 2, Normalized Estimation Error: 0.05745128617417388, NMSE: 0.04997292655967467, Correlation: 0.9756431822123668, R^2 Score: 0.9494680893061691
# Fold = 3, Alpha = 2.5, Normalized Estimation Error: 0.09272927313319244, NMSE: 0.08082369701979066, Correlation: 0.9599234357771919, R^2 Score: 0.918272230167024
# Fold = 3, Alpha = 3, Normalized Estimation Error: 0.09325683709939894, NMSE: 0.08176498528036184, Correlation: 0.9598377211854051, R^2 Score: 0.9173204129012583
# Fold = 3, Alpha = 5, Normalized Estimation Error: 0.06435582339783338, NMSE: 0.057676472473536376, Correlation: 0.9721532504309252, R^2 Score: 0.9416783735351658
# Fold = 3, Alpha = 4, Normalized Estimation Error: 0.22974315528332187, NMSE: 0.1981677108078373, Correlation: 0.8960769720521847, R^2 Score: 0.7996156368191751
# Fold = 3, Alpha = 10, Normalized Estimation Error: 0.0949927454403849, NMSE: 0.08230150599395127, Correlation: 0.9596276388973436, R^2 Score: 0.9167778908067775
# Fold = 3, Alpha = 15, Normalized Estimation Error: 0.05878772872473349, NMSE: 0.05339571567140472, Correlation: 0.9750285893862906, R^2 Score: 0.9460070137673727
# Fold = 3, Alpha = 20, Normalized Estimation Error: 0.09825905018925656, NMSE: 0.08655710011632117, Correlation: 0.958849209423725, R^2 Score: 0.9124746947175112
# Fold = 3, Alpha = 50, Normalized Estimation Error: 0.0972422687569112, NMSE: 0.09028119311802406, Correlation: 0.9589909228228096, R^2 Score: 0.9087089449819449
# Fold = 3, Alpha = 100, Normalized Estimation Error: 0.23805298479369763, NMSE: 0.21827209786288654, Correlation: 0.8948444697934381, R^2 Score: 0.7792863673294882
# Fold = 4, Alpha = 0, Normalized Estimation Error: 0.07859024023512977, NMSE: 0.08387734248773829, Correlation: 0.9570051439550356, R^2 Score: 0.9150398214809926
# Fold = 4, Alpha = 0.1, Normalized Estimation Error: 0.0464749328417265, NMSE: 0.050680564644478364, Correlation: 0.9743618831554719, R^2 Score: 0.9486651616285002
# Fold = 4, Alpha = 0.3, Normalized Estimation Error: 0.04523744027749663, NMSE: 0.04928597384802759, Correlation: 0.9751556665074547, R^2 Score: 0.9500777562519499
# Fold = 4, Alpha = 0.5, Normalized Estimation Error: 0.09133529945627554, NMSE: 0.09547505046511737, Correlation: 0.9518456778536576, R^2 Score: 0.903292389922661
# Fold = 4, Alpha = 0.7, Normalized Estimation Error: 0.07216996000094995, NMSE: 0.07607573463399206, Correlation: 0.9609207280657756, R^2 Score: 0.9229421461890801
# Fold = 4, Alpha = 0.9, Normalized Estimation Error: 0.05765215616896406, NMSE: 0.06385105140666959, Correlation: 0.9678808797863707, R^2 Score: 0.9353246470948934
# Fold = 4, Alpha = 1, Normalized Estimation Error: 0.07292992830102006, NMSE: 0.0751302015028547, Correlation: 0.9614514901405617, R^2 Score: 0.923899885922296
# Fold = 4, Alpha = 1.5, Normalized Estimation Error: 0.054798469837473364, NMSE: 0.0589765364296014, Correlation: 0.9702206596580746, R^2 Score: 0.9402620908712723
# Fold = 4, Alpha = 2, Normalized Estimation Error: 0.08929670327361597, NMSE: 0.09079881517133462, Correlation: 0.9531657399349052, R^2 Score: 0.9080289942734098
# Fold = 4, Alpha = 2.5, Normalized Estimation Error: 0.08840106231447284, NMSE: 0.09442507028359319, Correlation: 0.9516941802549141, R^2 Score: 0.9043559250922064
# Fold = 4, Alpha = 3, Normalized Estimation Error: 0.0954620765329687, NMSE: 0.10015519090406162, Correlation: 0.9483538642885364, R^2 Score: 0.8985518300122793
# Fold = 4, Alpha = 5, Normalized Estimation Error: 0.09506177807277244, NMSE: 0.09983271774766347, Correlation: 0.9486913789655003, R^2 Score: 0.8988784662184655
# Fold = 4, Alpha = 4, Normalized Estimation Error: 0.04763043076854298, NMSE: 0.05284313204537185, Correlation: 0.9733641783497401, R^2 Score: 0.9464746760099775
# Fold = 4, Alpha = 10, Normalized Estimation Error: 0.10004340222972037, NMSE: 0.10660728814487323, Correlation: 0.9458367524813512, R^2 Score: 0.8920164377699525
# Fold = 4, Alpha = 15, Normalized Estimation Error: 0.22996536595514733, NMSE: 0.2672023412689916, Correlation: 0.8540839050014088, R^2 Score: 0.7293481416840439
# Fold = 4, Alpha = 20, Normalized Estimation Error: 0.09546810641815133, NMSE: 0.09963362245287115, Correlation: 0.9496324350857215, R^2 Score: 0.8990801317849482
# Fold = 4, Alpha = 50, Normalized Estimation Error: 0.07697993363274924, NMSE: 0.0814188472204651, Correlation: 0.9623889578236361, R^2 Score: 0.9175300553224641
# Fold = 4, Alpha = 100, Normalized Estimation Error: 0.23237547389529, NMSE: 0.26831705247035637, Correlation: 0.8571380203658231, R^2 Score: 0.7282190398329818
# intercept is not initialized
# (32, 32)
# ---------------------------Testing with Best Lambda------------------------------
# Error Record on Training _ After K-Fold CV
# Validation Normalized Estimation Error:  [[0.09264783 0.0935077  0.09483756 0.09097009 0.05029324 0.07148226
#   0.0496155  0.07665049 0.11535122 0.09297702 0.05076435 0.06320525
#   0.06414911 0.06408045 0.07453593 0.23466124 0.11899856 0.23720422]
#  [0.0572727  0.0494837  0.05506211 0.04895566 0.09107923 0.04984177
#   0.23837018 0.18976812 0.08860943 0.05193756 0.09968072 0.11087884
#   0.05321288 0.06249319 0.07632593 0.22416526 0.23510566 0.12122274]
#  [0.05396287 0.16647616 0.05609466 0.12584627 0.04582021 0.06319158
#   0.24429885 0.04793684 0.05289992 0.060402   0.08667294 0.08638948
#   0.05077105 0.10179395 0.05982248 0.11219822 0.08379518 0.2420043 ]
#  [0.09182765 0.05609076 0.09294439 0.06505948 0.05032921 0.07336206
#   0.0589574  0.12569101 0.05745129 0.09272927 0.09325684 0.06435582
#   0.22974316 0.09499275 0.05878773 0.09825905 0.09724227 0.23805298]
#  [0.07859024 0.04647493 0.04523744 0.0913353  0.07216996 0.05765216
#   0.07292993 0.05479847 0.0892967  0.08840106 0.09546208 0.09506178
#   0.04763043 0.1000434  0.22996537 0.09546811 0.07697993 0.23237547]]
# Validation NMSE Losses:  [[0.09000653 0.09429588 0.09536048 0.08904077 0.0499707  0.06892885
#   0.04790809 0.07756363 0.12179084 0.0915352  0.05125259 0.05982051
#   0.06341752 0.06373443 0.07371274 0.23772097 0.11963851 0.23842464]
#  [0.06375372 0.05273127 0.05674711 0.05487874 0.0937292  0.05458165
#   0.22071395 0.18430877 0.08992143 0.05480965 0.10406885 0.1186935
#   0.05692227 0.06621775 0.08353305 0.21085725 0.21253485 0.11219809]
#  [0.04580687 0.13729698 0.04897805 0.10424176 0.0379616  0.05473999
#   0.23041356 0.03980397 0.04382272 0.05226994 0.07586217 0.07446534
#   0.04349141 0.07605977 0.0518994  0.10305315 0.07226256 0.22284095]
#  [0.08028352 0.05024676 0.08287773 0.05616229 0.04443829 0.06533271
#   0.05223077 0.11539448 0.04997293 0.0808237  0.08176499 0.05767647
#   0.19816771 0.08230151 0.05339572 0.0865571  0.09028119 0.2182721 ]
#  [0.08387734 0.05068056 0.04928597 0.09547505 0.07607573 0.06385105
#   0.0751302  0.05897654 0.09079882 0.09442507 0.10015519 0.09983272
#   0.05284313 0.10660729 0.26720234 0.09963362 0.08141885 0.26831705]]
# Validation Correlations:  [[0.95425826 0.95186109 0.95119704 0.95452721 0.97477482 0.96500944
#   0.97590232 0.96050167 0.93707118 0.95309541 0.97421315 0.97000311
#   0.96795817 0.9682003  0.9632605  0.8733946  0.9401617  0.87412053]
#  [0.96758823 0.9734335  0.9711756  0.97231515 0.95256111 0.97235255
#   0.88772412 0.90439493 0.95425037 0.97217632 0.94661433 0.93979156
#   0.97116847 0.96635482 0.95738551 0.89107378 0.88818818 0.9462983 ]
#  [0.97683286 0.92952329 0.975224   0.94647556 0.98088463 0.97231525
#   0.88081294 0.97996952 0.97787295 0.97353395 0.96140228 0.96207182
#   0.97809479 0.96125028 0.9739016  0.94741855 0.96630248 0.88183692]
#  [0.96010688 0.9755905  0.95879607 0.97253268 0.97790066 0.96762958
#   0.97472293 0.94024954 0.97564318 0.95992344 0.95983772 0.97215325
#   0.89607697 0.95962764 0.97502859 0.95884921 0.95899092 0.89484447]
#  [0.95700514 0.97436188 0.97515567 0.95184568 0.96092073 0.96788088
#   0.96145149 0.97022066 0.95316574 0.95169418 0.94835386 0.94869138
#   0.97336418 0.94583675 0.85408391 0.94963244 0.96238896 0.85713802]]
# Validation R2 Scores:  [[0.90985248 0.90555641 0.90449015 0.91081976 0.94995103 0.93096318
#   0.95201687 0.92231488 0.87801839 0.90832142 0.94866713 0.94008578
#   0.93648315 0.93616574 0.9261718  0.76190667 0.8801741  0.7612019 ]
#  [0.93603617 0.94709494 0.94306586 0.94494039 0.90596189 0.94523846
#   0.77855863 0.81508379 0.90978221 0.94500971 0.89558816 0.88091531
#   0.94289013 0.93356401 0.91619164 0.78844781 0.78676468 0.88743213]
#  [0.95418147 0.86266806 0.95100948 0.8957317  0.96202874 0.94524608
#   0.76952778 0.96018589 0.95616613 0.94771676 0.92411852 0.9255157
#   0.95649752 0.92392087 0.94808738 0.89692062 0.92771904 0.77710232]
#  [0.91881845 0.94919119 0.91619522 0.94320949 0.95506464 0.93393649
#   0.94718499 0.88331475 0.94946809 0.91827223 0.91732041 0.94167837
#   0.79961564 0.91677789 0.94600701 0.91247469 0.90870894 0.77928637]
#  [0.91503982 0.94866516 0.95007776 0.90329239 0.92294215 0.93532465
#   0.92389989 0.94026209 0.90802899 0.90435593 0.89855183 0.89887847
#   0.94647468 0.89201644 0.72934814 0.89908013 0.91753006 0.72821904]]
# Error Report on Testing _ With best Lambda
# Alpha chosen for model:  0.7
# Test Normalized Estimation Error:  0.05038619257826734
# Test NMSE Loss:  0.0033464589686245435
# Test R2 Loss:  0.9536033981476855
# Test Correlation:  0.9765429754729015

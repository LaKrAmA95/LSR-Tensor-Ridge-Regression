# %% [markdown]
# # Tensor Pipeline

# %% [markdown]
# ## Setting Path

# %%
import sys
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Code Files')
sys.path.append('/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Stochastic LSR TRR/Data')

# %% [markdown]
# ## Import Libraries

# %%
import datetime
import numpy as np
import dill
from KFoldCV import KFoldCV
from train_test import train_test
from sgd_optimization import SGD
from DataGenerationB import *
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import Data

# %%
import pickle
pkl_file = "/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Closed_Form_Solver/Data/Bounded_Var_Time:2024-04-15 19:35:40, intercept:5,n_train:5000, n_test:1000, tensor_dimensions:[32 32], tensor_mode_ranks:[4 4], separation_rank:2.pkl"
file= open(pkl_file, 'rb')
data = pickle.load(file)
file.close()

X_train_Full = data[0]
print(data[0].shape)

Y_train_Full = data[1]
print(data[1].shape)

X_test_Full = data[2]
print(data[2].shape)

Y_test_Full = data[3]
print(data[3].shape)

B_tensored = data[4]
print(data[4].shape)
# Out:
# (5000, 32, 32)
# (5000,)
# (1000, 32, 32)
# (1000,)
# (32, 32)

# %% [markdown]
# ## Subset Data

# %%
n_train_all = [1100]
n_test = 100

tensor_dimensions = np.array([32, 32])
tensor_mode_ranks = np.array([4, 4])
separation_rank = 2

# %%
for i,n_train in enumerate(n_train_all):
  print('Number of Samples:',n_train,'---------------------------------------------------------------------------------------------------------------------------')

  #Subset X_train and Y_train
  X_train = X_train_Full[0:(n_train),:,:]
  Y_train = Y_train_Full[0:(n_train)]

  #Subset X_test and Y_test
  X_test = X_test_Full[0:(n_test),:,:]
  Y_test = Y_test_Full[0:(n_test)]

  #Preprocessing

  # Reshape the 3D array to a 2D array where each row represents a sample
  # The shape of the original 3D array is (n_samples, n_features_per_sample, n_dimensions)
  # We reshape it to (n_samples, n_features_per_sample * n_dimensions)


  X_train_2D = X_train.reshape(n_train, -1)
  X_test_2D = X_test.reshape(n_test,-1)


  # Initialize StandardScaler
  scaler = StandardScaler(with_std = False) #standard scalar only

  # Fit scaler on train data and transform train data
  X_train_scaled = scaler.fit_transform(X_train_2D)
  # Transform test data using the scaler fitted on train data
  X_test_scaled = scaler.transform(X_test_2D)

  # Reshape the scaled data back to 3D
  X_train = X_train_scaled.reshape(n_train, tensor_dimensions[0],tensor_dimensions[1])
  X_test  = X_test_scaled.reshape(n_test, tensor_dimensions[0],tensor_dimensions[1])

  #average response value
  Y_train_mean = np.mean(Y_train)
  # Mean centering y_train and y_test
  Y_train = Y_train - Y_train_mean


  print("Sample mean for each feature (across samples):",scaler.mean_)
  print("Sample variance for each feature (across samples):",scaler.var_)
  print('Response Average:',Y_train_mean)

  #For now, define finite alpha set that we are searching over
  alphas = [0,0.1,0.3, 0.5, 0.7, 0.9, 1, 1.5, 2, 2.5, 3, 5, 4,10,15,20,50,100]

  #Define Number of Folds we want
  
  k_folds = 5
  learning_rate = 0.000002
  epochs = 100
  batch_size = 32

  hypers = {'max_iter': 50, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
  lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information = KFoldCV(X_train, Y_train, alphas, k_folds, hypers,B_tensored ,intercept= False) 

  hypers = {'max_iter': 50, 'threshold': 1e-4, 'ranks': tuple(tensor_mode_ranks), 'separation_rank': separation_rank,'learning_rate':learning_rate,'epochs':epochs,'batch_size': batch_size}
  normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values = train_test(X_train, Y_train, X_test, Y_test, B_tensored, lambda1, hypers, Y_train_mean,intercept= False)

  #Get current time and store in variable
  formatted_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
  max_iter = hypers['max_iter']
  pkl_file = f"/Users/lakrama/Neuro Project Codes/LSR-Tensor-Ridge-Regression/Closed_Form_Solver/Experimental Results/ExecutionTime_intercept_5_{formatted_time}, n_train_{n_train},n_test_{n_test}, tensor_dimensions:{tensor_dimensions}, tensor_mode_= ranks:{tensor_mode_ranks}, separation_rank:{separation_rank}, max_iter={max_iter}.pkl"

  print("Error Record on Training _ After K-Fold CV")
  print("Validation Normalized Estimation Error: ", validation_normalized_estimation_error)
  print("Validation NMSE Losses: ", validation_nmse_losses)
  print("Validation Correlations: ", validation_correlations)
  print("Validation R2 Scores: ", validation_R2_scores)

  print("Error Report on Testing _ With best Lambda")
  print("Alpha chosen for model: ", lambda1)
  print("Test Normalized Estimation Error: ", normalized_estimation_error)
  print("Test NMSE Loss: ", test_nmse_loss)
  print("Test R2 Loss: ", test_R2_loss)
  print("Test Correlation: ", test_correlation)

  with open(pkl_file, "wb") as file:
    dill.dump((X_train_Full, Y_train_Full, X_test_Full, Y_test_Full, B_tensored, lambda1, validation_normalized_estimation_error, validation_nmse_losses, validation_correlations, validation_R2_scores, objective_function_information, normalized_estimation_error, test_nmse_loss, test_R2_loss, test_correlation, objective_function_values), file)
# Out:
# Number of Samples: 1100 ---------------------------------------------------------------------------------------------------------------------------
# Sample mean for each feature (across samples): [4.99229076 4.99583242 5.01768396 ... 5.00785591 4.99100698 4.99667398]
# Sample variance for each feature (across samples): None
# Response Average: 83.27834777294153
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# intercept is not initialized
# Fold = 0, Alpha = 0, Normalized Estimation Error: 0.03891116965062509, NMSE: 0.042769660495195, Correlation: 0.9780781685163401, R^2 Score: 0.9566097047353067
# Fold = 0, Alpha = 0.1, Normalized Estimation Error: 0.039266709434701626, NMSE: 0.042482280397797265, Correlation: 0.9782234380520594, R^2 Score: 0.9569012550336937
# Fold = 0, Alpha = 0.3, Normalized Estimation Error: 0.03987150898244673, NMSE: 0.042286733268755754, Correlation: 0.9783185744666744, R^2 Score: 0.9570996397664467
# Fold = 0, Alpha = 0.5, Normalized Estimation Error: 0.03983633857068739, NMSE: 0.04226268215139704, Correlation: 0.9783292292059343, R^2 Score: 0.9571240398919459
# Fold = 0, Alpha = 0.7, Normalized Estimation Error: 0.03925679242145922, NMSE: 0.04243031340068269, Correlation: 0.9782454779205734, R^2 Score: 0.9569539761290383
# Fold = 0, Alpha = 0.9, Normalized Estimation Error: 0.045590749521071006, NMSE: 0.045714141670454615, Correlation: 0.9765721253251077, R^2 Score: 0.9536224959027699
# Fold = 0, Alpha = 1, Normalized Estimation Error: 0.03938893617076375, NMSE: 0.04276531929474236, Correlation: 0.9780737508034898, R^2 Score: 0.9566141089313481
# Fold = 0, Alpha = 1.5, Normalized Estimation Error: 0.03908125639609367, NMSE: 0.04235280552514493, Correlation: 0.9782879076139666, R^2 Score: 0.9570326087290165
# Fold = 0, Alpha = 2, Normalized Estimation Error: 0.03920437776528225, NMSE: 0.04220364996774073, Correlation: 0.978359699471482, R^2 Score: 0.9571839286974522
# Fold = 0, Alpha = 2.5, Normalized Estimation Error: 0.03845693088917782, NMSE: 0.041990043595386356, Correlation: 0.9784689811182087, R^2 Score: 0.9574006347329821
# Fold = 0, Alpha = 3, Normalized Estimation Error: 0.039800143944267244, NMSE: 0.04234986737285416, Correlation: 0.9782898529015843, R^2 Score: 0.9570355895171254
# Fold = 0, Alpha = 5, Normalized Estimation Error: 0.04076035661336599, NMSE: 0.04245284762056616, Correlation: 0.9782321244348862, R^2 Score: 0.9569311149128635
# Fold = 0, Alpha = 4, Normalized Estimation Error: 0.04026986282391594, NMSE: 0.042175820322216756, Correlation: 0.9783801320967327, R^2 Score: 0.9572121621817122
# Fold = 0, Alpha = 10, Normalized Estimation Error: 0.041402269758946994, NMSE: 0.042381979656997644, Correlation: 0.9783584757049878, R^2 Score: 0.9570030112484538
# Fold = 0, Alpha = 15, Normalized Estimation Error: 0.04086212807706205, NMSE: 0.04218690292076351, Correlation: 0.9786474418530396, R^2 Score: 0.9572009187624828
# Fold = 0, Alpha = 20, Normalized Estimation Error: 0.04147899688851915, NMSE: 0.04339222545838567, Correlation: 0.9781241552696276, R^2 Score: 0.9559781056704199
# Fold = 0, Alpha = 50, Normalized Estimation Error: 0.05547648122369012, NMSE: 0.05288626391595612, Correlation: 0.9753550606294977, R^2 Score: 0.9463462982826896
# Fold = 0, Alpha = 100, Normalized Estimation Error: 0.2471087592149576, NMSE: 0.20393857838616272, Correlation: 0.8964737840120415, R^2 Score: 0.793102048751789
# Fold = 1, Alpha = 0, Normalized Estimation Error: 0.06390618106346947, NMSE: 0.06091880803300859, Correlation: 0.9692229305793958, R^2 Score: 0.9390178678022987
# Fold = 1, Alpha = 0.1, Normalized Estimation Error: 0.04008041317082635, NMSE: 0.03759337039518134, Correlation: 0.9811065450311044, R^2 Score: 0.9623675518740632
# Fold = 1, Alpha = 0.3, Normalized Estimation Error: 0.06888005844582404, NMSE: 0.06420380031956174, Correlation: 0.9678230319911262, R^2 Score: 0.9357294608167505
# Fold = 1, Alpha = 0.5, Normalized Estimation Error: 0.04816208120373115, NMSE: 0.04587291175055562, Correlation: 0.9770121471336868, R^2 Score: 0.9540794040626978
# Fold = 1, Alpha = 0.7, Normalized Estimation Error: 0.0416299852007407, NMSE: 0.03889865446474003, Correlation: 0.98049860384168, R^2 Score: 0.961060910981775
# Fold = 1, Alpha = 0.9, Normalized Estimation Error: 0.060868505527176556, NMSE: 0.058686345452613406, Correlation: 0.970367436460549, R^2 Score: 0.9412526509932356
# Fold = 1, Alpha = 1, Normalized Estimation Error: 0.1128244590445019, NMSE: 0.10111878090604025, Correlation: 0.948421932882217, R^2 Score: 0.8987761076752965
# Fold = 1, Alpha = 1.5, Normalized Estimation Error: 0.0488950404916877, NMSE: 0.04643344373740175, Correlation: 0.9767407685647651, R^2 Score: 0.9535182894114661
# Fold = 1, Alpha = 2, Normalized Estimation Error: 0.04337876598260044, NMSE: 0.04093082495694055, Correlation: 0.9795504430972372, R^2 Score: 0.9590266280795802
# Fold = 1, Alpha = 2.5, Normalized Estimation Error: 0.040075019751385034, NMSE: 0.03792074514326646, Correlation: 0.9809743147591261, R^2 Score: 0.9620398368249589
# Fold = 1, Alpha = 3, Normalized Estimation Error: 0.03889058000166631, NMSE: 0.03726458324830909, Correlation: 0.9812747918963456, R^2 Score: 0.9626966807901215
# Fold = 1, Alpha = 5, Normalized Estimation Error: 0.040134968094977894, NMSE: 0.03792230774027568, Correlation: 0.981076746724029, R^2 Score: 0.962038272603654
# Fold = 1, Alpha = 4, Normalized Estimation Error: 0.09315955160118866, NMSE: 0.09051271492909248, Correlation: 0.9536487993840254, R^2 Score: 0.9093931984948233
# Fold = 1, Alpha = 10, Normalized Estimation Error: 0.04120321549372269, NMSE: 0.03845028237948073, Correlation: 0.9809223249841901, R^2 Score: 0.961509749142926
# Fold = 1, Alpha = 15, Normalized Estimation Error: 0.04373374999084424, NMSE: 0.04063509878702638, Correlation: 0.9801008760347832, R^2 Score: 0.959322661652303
# Fold = 1, Alpha = 20, Normalized Estimation Error: 0.04381129437507323, NMSE: 0.04052804035836147, Correlation: 0.9804541061653461, R^2 Score: 0.959429831366559
# Fold = 1, Alpha = 50, Normalized Estimation Error: 0.06389572462211042, NMSE: 0.06131112509175655, Correlation: 0.9724568418940683, R^2 Score: 0.9386251429359976
# Fold = 1, Alpha = 100, Normalized Estimation Error: 0.2377802192887526, NMSE: 0.24141955903218057, Correlation: 0.8730187066784901, R^2 Score: 0.7583294890465684
# Fold = 2, Alpha = 0, Normalized Estimation Error: 0.041284017975758765, NMSE: 0.04400677359970379, Correlation: 0.9777529478087739, R^2 Score: 0.9558349935239766
# Fold = 2, Alpha = 0.1, Normalized Estimation Error: 0.03981859623603241, NMSE: 0.04251070508663947, Correlation: 0.978498752584807, R^2 Score: 0.9573364413730983
# Fold = 2, Alpha = 0.3, Normalized Estimation Error: 0.04284311594107669, NMSE: 0.0439709867151961, Correlation: 0.9778834478855546, R^2 Score: 0.9558709090855312
# Fold = 2, Alpha = 0.5, Normalized Estimation Error: 0.04059019818533425, NMSE: 0.04343248914595088, Correlation: 0.9783607112385996, R^2 Score: 0.9564113429025924
# Fold = 2, Alpha = 0.7, Normalized Estimation Error: 0.04052795901932888, NMSE: 0.043117096631256215, Correlation: 0.9782245046913649, R^2 Score: 0.9567278694578152
# Fold = 2, Alpha = 0.9, Normalized Estimation Error: 0.0470850078733989, NMSE: 0.05158225987046495, Correlation: 0.973890631169353, R^2 Score: 0.9482322684696353
# Fold = 2, Alpha = 1, Normalized Estimation Error: 0.039519333119310704, NMSE: 0.041648729812508334, Correlation: 0.9789701430642486, R^2 Score: 0.958201516007073
# Fold = 2, Alpha = 1.5, Normalized Estimation Error: 0.040565580914215735, NMSE: 0.043270700242647585, Correlation: 0.9781049112477878, R^2 Score: 0.9565737135418748
# Fold = 2, Alpha = 2, Normalized Estimation Error: 0.04006412893983156, NMSE: 0.0424985744680809, Correlation: 0.978545052875895, R^2 Score: 0.9573486156090937
# Fold = 2, Alpha = 2.5, Normalized Estimation Error: 0.04052554860257929, NMSE: 0.04295981442814163, Correlation: 0.9784510899068757, R^2 Score: 0.9568857171924003
# Fold = 2, Alpha = 3, Normalized Estimation Error: 0.03947667953908457, NMSE: 0.04161109763411456, Correlation: 0.97898784224162, R^2 Score: 0.9582392834975414
# Fold = 2, Alpha = 5, Normalized Estimation Error: 0.039632949235347555, NMSE: 0.042114002948554725, Correlation: 0.9787372468960471, R^2 Score: 0.9577345699125122
# Fold = 2, Alpha = 4, Normalized Estimation Error: 0.05588200143959053, NMSE: 0.06137905674770069, Correlation: 0.9689695136933046, R^2 Score: 0.9384002457573337
# Fold = 2, Alpha = 10, Normalized Estimation Error: 0.04084088014503504, NMSE: 0.043853313971050426, Correlation: 0.9780527751613435, R^2 Score: 0.9559890049394676
# Fold = 2, Alpha = 15, Normalized Estimation Error: 0.039737230437577056, NMSE: 0.04139370559056883, Correlation: 0.9793686516831143, R^2 Score: 0.9584574572063973
# Fold = 2, Alpha = 20, Normalized Estimation Error: 0.04546868333116563, NMSE: 0.04885365029229812, Correlation: 0.9760684594664171, R^2 Score: 0.9509706891679227
# Fold = 2, Alpha = 50, Normalized Estimation Error: 0.05137608629960538, NMSE: 0.056184968379782145, Correlation: 0.9743005925981759, R^2 Score: 0.9436130102397475
# Fold = 2, Alpha = 100, Normalized Estimation Error: 0.2290415862336288, NMSE: 0.27653780970870023, Correlation: 0.8519026240765624, R^2 Score: 0.7224678576133499
# Fold = 3, Alpha = 0, Normalized Estimation Error: 0.05589190582003256, NMSE: 0.06407896754071953, Correlation: 0.968084181073082, R^2 Score: 0.935605595965288
# Fold = 3, Alpha = 0.1, Normalized Estimation Error: 0.03934015033585935, NMSE: 0.03742135998324961, Correlation: 0.9814680034368359, R^2 Score: 0.9623944288309811
# Fold = 3, Alpha = 0.3, Normalized Estimation Error: 0.040852467264330845, NMSE: 0.037416151699014966, Correlation: 0.9815541401873952, R^2 Score: 0.962399662753627
# Fold = 3, Alpha = 0.5, Normalized Estimation Error: 0.06857191175254006, NMSE: 0.06844242986652864, Correlation: 0.9656666170144262, R^2 Score: 0.9312206539666541
# Fold = 3, Alpha = 0.7, Normalized Estimation Error: 0.039546160309369666, NMSE: 0.03689872311800464, Correlation: 0.9816287926355044, R^2 Score: 0.9629196384396196
# Fold = 3, Alpha = 0.9, Normalized Estimation Error: 0.043530004034901565, NMSE: 0.04132092793108926, Correlation: 0.9795379711993185, R^2 Score: 0.958475664786688
# Fold = 3, Alpha = 1, Normalized Estimation Error: 0.06373406061991663, NMSE: 0.06194344898185369, Correlation: 0.9694822084606468, R^2 Score: 0.9377516268734147
# Fold = 3, Alpha = 1.5, Normalized Estimation Error: 0.042372655384084544, NMSE: 0.03996443893384394, Correlation: 0.9801650170088116, R^2 Score: 0.9598388312656383
# Fold = 3, Alpha = 2, Normalized Estimation Error: 0.0401342400928753, NMSE: 0.03768073302624742, Correlation: 0.981283938051256, R^2 Score: 0.962133778992703
# Fold = 3, Alpha = 2.5, Normalized Estimation Error: 0.03876651764629988, NMSE: 0.037387617790887326, Correlation: 0.9814631393785522, R^2 Score: 0.96242833712338
# Fold = 3, Alpha = 3, Normalized Estimation Error: 0.03877941473647657, NMSE: 0.0364471606195254, Correlation: 0.9819075848286795, R^2 Score: 0.9633734238092968
# Fold = 3, Alpha = 5, Normalized Estimation Error: 0.04262366583664149, NMSE: 0.04029906691545787, Correlation: 0.979934547818652, R^2 Score: 0.9595025560371763
# Fold = 3, Alpha = 4, Normalized Estimation Error: 0.04611478405636113, NMSE: 0.04084552509058939, Correlation: 0.9794165878566164, R^2 Score: 0.9589534078553625
# Fold = 3, Alpha = 10, Normalized Estimation Error: 0.04106139987410695, NMSE: 0.03725307012467235, Correlation: 0.9813143066047536, R^2 Score: 0.9625635471168099
# Fold = 3, Alpha = 15, Normalized Estimation Error: 0.03973239088071243, NMSE: 0.03628808073057863, Correlation: 0.9817970552017731, R^2 Score: 0.963533286788302
# Fold = 3, Alpha = 20, Normalized Estimation Error: 0.04716674270768153, NMSE: 0.04315653951853833, Correlation: 0.9783335676262103, R^2 Score: 0.9566310171784399
# Fold = 3, Alpha = 50, Normalized Estimation Error: 0.04932534121260132, NMSE: 0.0434735382186172, Correlation: 0.9793925768329634, R^2 Score: 0.9563124580137906
# Fold = 3, Alpha = 100, Normalized Estimation Error: 0.082059787737434, NMSE: 0.07769208470622826, Correlation: 0.9658656256267302, R^2 Score: 0.9219254665785186
# Fold = 4, Alpha = 0, Normalized Estimation Error: 0.03811159734500792, NMSE: 0.033779150423962186, Correlation: 0.982859003875883, R^2 Score: 0.9658712501349809
# Fold = 4, Alpha = 0.1, Normalized Estimation Error: 0.03792115917580731, NMSE: 0.03421947923947289, Correlation: 0.9826600734293104, R^2 Score: 0.96542636410871
# Fold = 4, Alpha = 0.3, Normalized Estimation Error: 0.03745258525300182, NMSE: 0.03336569062020607, Correlation: 0.9830895131047116, R^2 Score: 0.9662889890669708
# Fold = 4, Alpha = 0.5, Normalized Estimation Error: 0.038913324162208815, NMSE: 0.03444114065410004, Correlation: 0.9826153728927333, R^2 Score: 0.9652024085953359
# Fold = 4, Alpha = 0.7, Normalized Estimation Error: 0.03783050940041997, NMSE: 0.03437023471948963, Correlation: 0.9825874223652493, R^2 Score: 0.9652740483753746
# Fold = 4, Alpha = 0.9, Normalized Estimation Error: 0.04320530253417544, NMSE: 0.03955484319124866, Correlation: 0.9804234894039895, R^2 Score: 0.9600357814722732
# Fold = 4, Alpha = 1, Normalized Estimation Error: 0.03893585757293795, NMSE: 0.03477975639167738, Correlation: 0.982471828306142, R^2 Score: 0.9648602883328933
# Fold = 4, Alpha = 1.5, Normalized Estimation Error: 0.03880691655347961, NMSE: 0.033830992927112856, Correlation: 0.982962712324464, R^2 Score: 0.9658188710845844
# Fold = 4, Alpha = 2, Normalized Estimation Error: 0.03926861308360217, NMSE: 0.03651272915335342, Correlation: 0.9815454381582022, R^2 Score: 0.9631093800606658
# Fold = 4, Alpha = 2.5, Normalized Estimation Error: 0.03746415693860882, NMSE: 0.03342572769922959, Correlation: 0.9830521846446045, R^2 Score: 0.9662283306304233
# Fold = 4, Alpha = 3, Normalized Estimation Error: 0.06692150017082829, NMSE: 0.06319825653678939, Correlation: 0.9675914278430483, R^2 Score: 0.9361476691338172
# Fold = 4, Alpha = 5, Normalized Estimation Error: 0.04803340222786877, NMSE: 0.04323648437667702, Correlation: 0.9782388132489429, R^2 Score: 0.9563160369099262
# Fold = 4, Alpha = 4, Normalized Estimation Error: 0.03725246277076173, NMSE: 0.03386549979041425, Correlation: 0.9828271378085869, R^2 Score: 0.9657840070903319
# Fold = 4, Alpha = 10, Normalized Estimation Error: 0.038904361141173564, NMSE: 0.03376353757226018, Correlation: 0.9831769998791935, R^2 Score: 0.9658870245728732
# Fold = 4, Alpha = 15, Normalized Estimation Error: 0.041618725334414255, NMSE: 0.036862271259832116, Correlation: 0.9820403435867847, R^2 Score: 0.9627562203461798
# Fold = 4, Alpha = 20, Normalized Estimation Error: 0.04186515626607678, NMSE: 0.03625823594106263, Correlation: 0.982675688657839, R^2 Score: 0.9633665071664576
# Fold = 4, Alpha = 50, Normalized Estimation Error: 0.056462656490781755, NMSE: 0.049405405728545085, Correlation: 0.9791043011129176, R^2 Score: 0.9500832699186779
# Fold = 4, Alpha = 100, Normalized Estimation Error: 0.09892173769045164, NMSE: 0.08722111961722924, Correlation: 0.9666346859559718, R^2 Score: 0.9118761799215741
# intercept is not initialized
# (32, 32)
# ---------------------------Testing with Best Lambda------------------------------
# Error Record on Training _ After K-Fold CV
# Validation Normalized Estimation Error:  [[0.03891117 0.03926671 0.03987151 0.03983634 0.03925679 0.04559075
#   0.03938894 0.03908126 0.03920438 0.03845693 0.03980014 0.04076036
#   0.04026986 0.04140227 0.04086213 0.041479   0.05547648 0.24710876]
#  [0.06390618 0.04008041 0.06888006 0.04816208 0.04162999 0.06086851
#   0.11282446 0.04889504 0.04337877 0.04007502 0.03889058 0.04013497
#   0.09315955 0.04120322 0.04373375 0.04381129 0.06389572 0.23778022]
#  [0.04128402 0.0398186  0.04284312 0.0405902  0.04052796 0.04708501
#   0.03951933 0.04056558 0.04006413 0.04052555 0.03947668 0.03963295
#   0.055882   0.04084088 0.03973723 0.04546868 0.05137609 0.22904159]
#  [0.05589191 0.03934015 0.04085247 0.06857191 0.03954616 0.04353
#   0.06373406 0.04237266 0.04013424 0.03876652 0.03877941 0.04262367
#   0.04611478 0.0410614  0.03973239 0.04716674 0.04932534 0.08205979]
#  [0.0381116  0.03792116 0.03745259 0.03891332 0.03783051 0.0432053
#   0.03893586 0.03880692 0.03926861 0.03746416 0.0669215  0.0480334
#   0.03725246 0.03890436 0.04161873 0.04186516 0.05646266 0.09892174]]
# Validation NMSE Losses:  [[0.04276966 0.04248228 0.04228673 0.04226268 0.04243031 0.04571414
#   0.04276532 0.04235281 0.04220365 0.04199004 0.04234987 0.04245285
#   0.04217582 0.04238198 0.0421869  0.04339223 0.05288626 0.20393858]
#  [0.06091881 0.03759337 0.0642038  0.04587291 0.03889865 0.05868635
#   0.10111878 0.04643344 0.04093082 0.03792075 0.03726458 0.03792231
#   0.09051271 0.03845028 0.0406351  0.04052804 0.06131113 0.24141956]
#  [0.04400677 0.04251071 0.04397099 0.04343249 0.0431171  0.05158226
#   0.04164873 0.0432707  0.04249857 0.04295981 0.0416111  0.042114
#   0.06137906 0.04385331 0.04139371 0.04885365 0.05618497 0.27653781]
#  [0.06407897 0.03742136 0.03741615 0.06844243 0.03689872 0.04132093
#   0.06194345 0.03996444 0.03768073 0.03738762 0.03644716 0.04029907
#   0.04084553 0.03725307 0.03628808 0.04315654 0.04347354 0.07769208]
#  [0.03377915 0.03421948 0.03336569 0.03444114 0.03437023 0.03955484
#   0.03477976 0.03383099 0.03651273 0.03342573 0.06319826 0.04323648
#   0.0338655  0.03376354 0.03686227 0.03625824 0.04940541 0.08722112]]
# Validation Correlations:  [[0.97807817 0.97822344 0.97831857 0.97832923 0.97824548 0.97657213
#   0.97807375 0.97828791 0.9783597  0.97846898 0.97828985 0.97823212
#   0.97838013 0.97835848 0.97864744 0.97812416 0.97535506 0.89647378]
#  [0.96922293 0.98110655 0.96782303 0.97701215 0.9804986  0.97036744
#   0.94842193 0.97674077 0.97955044 0.98097431 0.98127479 0.98107675
#   0.9536488  0.98092232 0.98010088 0.98045411 0.97245684 0.87301871]
#  [0.97775295 0.97849875 0.97788345 0.97836071 0.9782245  0.97389063
#   0.97897014 0.97810491 0.97854505 0.97845109 0.97898784 0.97873725
#   0.96896951 0.97805278 0.97936865 0.97606846 0.97430059 0.85190262]
#  [0.96808418 0.981468   0.98155414 0.96566662 0.98162879 0.97953797
#   0.96948221 0.98016502 0.98128394 0.98146314 0.98190758 0.97993455
#   0.97941659 0.98131431 0.98179706 0.97833357 0.97939258 0.96586563]
#  [0.982859   0.98266007 0.98308951 0.98261537 0.98258742 0.98042349
#   0.98247183 0.98296271 0.98154544 0.98305218 0.96759143 0.97823881
#   0.98282714 0.983177   0.98204034 0.98267569 0.9791043  0.96663469]]
# Validation R2 Scores:  [[0.9566097  0.95690126 0.95709964 0.95712404 0.95695398 0.9536225
#   0.95661411 0.95703261 0.95718393 0.95740063 0.95703559 0.95693111
#   0.95721216 0.95700301 0.95720092 0.95597811 0.9463463  0.79310205]
#  [0.93901787 0.96236755 0.93572946 0.9540794  0.96106091 0.94125265
#   0.89877611 0.95351829 0.95902663 0.96203984 0.96269668 0.96203827
#   0.9093932  0.96150975 0.95932266 0.95942983 0.93862514 0.75832949]
#  [0.95583499 0.95733644 0.95587091 0.95641134 0.95672787 0.94823227
#   0.95820152 0.95657371 0.95734862 0.95688572 0.95823928 0.95773457
#   0.93840025 0.955989   0.95845746 0.95097069 0.94361301 0.72246786]
#  [0.9356056  0.96239443 0.96239966 0.93122065 0.96291964 0.95847566
#   0.93775163 0.95983883 0.96213378 0.96242834 0.96337342 0.95950256
#   0.95895341 0.96256355 0.96353329 0.95663102 0.95631246 0.92192547]
#  [0.96587125 0.96542636 0.96628899 0.96520241 0.96527405 0.96003578
#   0.96486029 0.96581887 0.96310938 0.96622833 0.93614767 0.95631604
#   0.96578401 0.96588702 0.96275622 0.96336651 0.95008327 0.91187618]]
# Error Report on Testing _ With best Lambda
# Alpha chosen for model:  2.5
# Test Normalized Estimation Error:  0.03586784602058642
# Test NMSE Loss:  0.0024571046325226626
# Test R2 Loss:  0.9659337507456462
# Test Correlation:  0.983278581002634
